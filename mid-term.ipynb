# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import os
from glob import glob
import pandas as pd
import tensorflow as tf
import cv2 as cv
from sklearn.utils import shuffle 
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils.np_utils import to_categorical
from keras.regularizers import l2
from tensorflow.python.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.python.keras.layers import  Dropout, Conv2D, MaxPooling2D,MaxPool2D,GlobalAveragePooling2D,BatchNormalization
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.callbacks import ModelCheckpoint, LearningRateScheduler,ReduceLROnPlateau,EarlyStopping
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model,Sequential
from keras.optimizers import adam_v2
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import CategoricalCrossentropy

import warnings
warnings.filterwarnings("ignore")

# %%
train_path="../input/coviddata/train"
test_path="../input/coviddata/test"
print("Test images dataset"+str(os.listdir(train_path)))
print("Test images dataset"+str(os.listdir(test_path)))
# Out:
# Test images dataset['Normal', 'Viral Pneumonia', 'Covid']
# Test images dataset['Normal', 'Viral Pneumonia', 'Covid']

# %%
IMAGE_SIZE=[244,244]
label=['Covid','Normal','Viral Pneumonia']

# %%
folder=glob(train_path+'/*')
folder
# Out:
# ['../input/coviddata/train/Normal',
#  '../input/coviddata/train/Viral Pneumonia',
#  '../input/coviddata/train/Covid']

# %%
from tqdm import tqdm
class_names = label
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (244,244)

# %%
def load_data():
    """
        Load the data:
            - 14,034 images to train the network.
            - 3,000 images to evaluate how accurately the network learned to classify images.
    """
    
    datasets = [train_path, test_path]
    output = []
    
    # Iterate through training and test sets
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
                image = cv.imread(img_path)
                image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
                image = cv.resize(image, IMAGE_SIZE) 
                
                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(x_train, y_train), (x_test, y_test) = load_data()
x_train, y_train = shuffle(x_train,y_train, random_state=25)
n_train = y_train.shape[0]
n_test = y_test.shape[0]
# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:04<00:00, 16.99it/s]
# 100%|██████████| 70/70 [00:01<00:00, 44.46it/s]
# 100%|██████████| 111/111 [00:04<00:00, 27.52it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 28.53it/s]
# 100%|██████████| 20/20 [00:00<00:00, 73.54it/s]
# 100%|██████████| 26/26 [00:00<00:00, 95.59it/s]
# Number of training examples: 251
# Number of testing examples: 66
# Each image is of size: (244, 244)

# %%
_, train_counts = np.unique(y_train, return_counts=True)
_, test_counts = np.unique(y_test, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=label
            ).plot.bar()

plt.show()

plt.pie(train_counts,
        explode=(0, 0, 0) , 
        labels=label,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %%
def display_random_images(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

display_random_images(label,x_train,y_train)

# %%
def display_examples(class_names, images, labels):
    """
        Display 25 images from the images array with its corresponding labels
    """
    
    fig = plt.figure(figsize=(10,10))
    fig.suptitle("Some examples of images of the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()
    
display_examples(label,x_train,y_train)

# %%
data_augmentation=False
batch_sizes=[32,64,120]
epoch_num=[20,50,100]
data_aug=[True,False]

# %% [markdown]
# ### Plotting accuracy and loss

# %%
def plot_accuracy_loss(history):
    """
        Plot the accuracy and the loss during the training of the nn.
    """
    fig = plt.figure(figsize=(20,20))

    # Plot accuracy
    plt.subplot(221)
    plt.plot(history.history['accuracy'],'bo--', label = "acc")
    plt.plot(history.history['val_accuracy'], 'ro--', label = "val_acc")
    plt.title("train_acc vs val_acc")
    plt.ylabel("accuracy")
    plt.xlabel("epochs")
    plt.legend()

    # Plot loss function
    plt.subplot(222)
    plt.plot(history.history['loss'],'bo--', label = "loss")
    plt.plot(history.history['val_loss'], 'ro--', label = "val_loss")
    plt.title("train_loss vs val_loss")
    plt.ylabel("loss")
    plt.xlabel("epochs")

    plt.legend()
    plt.show()

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (251, 244, 244, 3)
# (66, 244, 244, 3)
# (251,)
# (66,)

# %% [markdown]
# #### Data Augmentation

# %%
def data_augmen(batch_size,epochs,data_augmentation):
    if data_augmentation==False:
        print('No data augmentation.')
#         model.fit(x_train, y_train,
#                   batch_size=batch_size,
#                   epochs=epochs,
#                   validation_data=(x_test, y_test),
#                   shuffle=True,
#                   callbacks=callbacks)
    else:
        print('Using real-time data augmentation.')
        # This will do preprocessing and realtime data augmentation:
        datagen = ImageDataGenerator(
            # set input mean to 0 over the dataset
            featurewise_center=False,
            # set each sample mean to 0
            samplewise_center=False,
            # divide inputs by std of dataset
            featurewise_std_normalization=False,
            # divide each input by its std
            samplewise_std_normalization=False,
            # apply ZCA whitening
            zca_whitening=False,
            # epsilon for ZCA whitening
            zca_epsilon=1e-06,
            # randomly rotate images in the range (deg 0 to 180)
            rotation_range=0,
            # randomly shift images horizontally
            width_shift_range=0.1,
            # randomly shift images vertically
            height_shift_range=0.1,
            # set range for random shear
            shear_range=0.,
            # set range for random zoom
            zoom_range=0.,
            # set range for random channel shifts
            channel_shift_range=0.,
            # set mode for filling points outside the input boundaries
            fill_mode='nearest',
            # value used for fill_mode = "constant"
            cval=0.,
            # randomly flip images
            horizontal_flip=True,
            # randomly flip images
            vertical_flip=False,
            # set rescaling factor (applied before any other transformation)
            rescale=None,
            # set function that will be applied on each input
            preprocessing_function=None,
            # image data format, either "channels_first" or "channels_last"
            data_format=None,
            # fraction of images reserved for validation (strictly between 0 and 1)
            validation_split=0.0)

# %% [markdown]
# ### CNN- Model

# %%
#Model 1
def build_model_1():
    model=Sequential()
    model.add(Conv2D(16,(3,3),activation='relu',input_shape=(244,244,3)))
    model.add(MaxPool2D(2,2))
    model.add(Dropout(0.2))

    model.add(Conv2D(32,(3,3),activation='relu'))
    model.add(MaxPool2D(2,2))
    model.add(Dropout(0.3))

    model.add(Conv2D(64,(3,3),activation='relu'))
    model.add(MaxPool2D(2,2))
    model.add(Dropout(0.3))

    model.add(Conv2D(64,(3,3),activation='relu'))
    model.add(MaxPool2D(2,2))
    model.add(Dropout(0.3))

    model.add(Conv2D(64,(3,3),activation='relu'))
    model.add(MaxPool2D(2,2))
    model.add(Dropout(0.3))

    model.add(Flatten())
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(1,activation='sigmoid'))



    model.compile(optimizer = "rmsprop", loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
for batch_size in batch_sizes:
    for epochs in epoch_num:
        for data_au in data_aug:
            (x_train, y_train), (x_test, y_test) = load_data()
            x_train, y_train = shuffle(x_train,y_train, random_state=25)
            n_train = y_train.shape[0]
            n_test = y_test.shape[0]
            # Normalize data.
            x_train = x_train.astype('float32') / 255
            x_test = x_test.astype('float32') / 255

            model=build_model_1()
            data_augmen(batch_size,epochs,data_au)
            print("Batch_size:",batch_size)
            print("Epochs:",epochs)
            print("Data Augmentation:",data_au)
            
            model.compile(optimizer = "rmsprop", loss='binary_crossentropy', metrics=['accuracy'])

            early_stop = EarlyStopping(monitor='val_loss',patience=2)
            history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, 
                                validation_data=(x_test,y_test), verbose=2)
            plot_accuracy_loss(history)

# %% [markdown]
# ### Model 2

# %%
# Model 2
def build_model_2():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (244,244, 3)), 
        BatchNormalization(),
        tf.keras.layers.MaxPooling2D(2,2),
        BatchNormalization(),
        tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
        BatchNormalization(),
        tf.keras.layers.MaxPooling2D(2,2),
        BatchNormalization(),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation=tf.nn.relu),
        tf.keras.layers.Dense(6, activation=tf.nn.softmax)
    ])
    return model

# %%
for batch in batch_sizes:
    for epoch in epoch_num:
        for data_au in data_aug:
            
            (x_train, y_train), (x_test, y_test) = load_data()
            x_train, y_train = shuffle(x_train,y_train, random_state=25)
            n_train = y_train.shape[0]
            n_test = y_test.shape[0]
            # Normalize data.
            x_train = x_train.astype('float32') / 255
            x_test = x_test.astype('float32') / 255

            model=build_model_2()

            data_augmen(batch,epoch,data_au)
            print("Batch_size:",batch)
            print("Epochs:",epoch)
            print("Data Augmentation:",data_au)

            model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])            
            history = model.fit(x_train,y_train, batch_size=batch, epochs=epoch, validation_split = 0.2)
            plot_accuracy_loss(history)

# %% [markdown]
# #### Model 3- CNN

# %%
#Model 3
def build_model_3():
    model = Sequential([
        Conv2D(filters=128, kernel_size=(5, 5), padding='valid', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Conv2D(filters=64, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Conv2D(filters=32, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Flatten(),

        Dense(units=256, activation='relu'),
        Dropout(0.5),
        Dense(units=3, activation='softmax')
    ])
    return model

# %%
counter=0
for batch in batch_sizes:
    for epoch in epoch_num:
        IMG_WIDTH = 244
        IMG_HEIGHT = 244
        BATCH_SIZE = batch
        train_path="../input/coviddata/train"
        test_path="../input/coviddata/test"
        train_datagen = ImageDataGenerator(rescale=1.0/255,
                                          zoom_range=0.2,
                                          width_shift_range=0.2,
                                          height_shift_range=0.2,
                                          fill_mode='nearest')
        train_generator = train_datagen.flow_from_directory(train_path,
                                                           target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                           batch_size=BATCH_SIZE,
                                                           class_mode='categorical',
                                                           shuffle=True)
        validation_datagen = ImageDataGenerator(rescale=1.0/255,
                                                shear_range = 0.3,
                                                horizontal_flip=True,
                                                zoom_range = 0.3)
        validation_generator = validation_datagen.flow_from_directory(test_path,
                                                                     target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                                     batch_size=BATCH_SIZE,
                                                                     class_mode='categorical',
                                                                     shuffle=True)
        labels = {value: key for key, value in train_generator.class_indices.items()}

        print("Label Mappings for classes present in the training and validation datasets\n")
        for key, value in labels.items():
            print(f"{key} : {value}")
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
        optimizer = adam_v2.Adam(learning_rate=0.001)
        model=build_model_3()
        if counter==0:
            model.summary()
        
        print("Batch Sizes:",batch)
        print("Epochs:",epoch)
        model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

        history = model.fit(train_generator, epochs=epoch, validation_data=validation_generator,
                               verbose=2,
                               callbacks=[reduce_lr])
        plot_accuracy_loss(history)
        counter+=1
# Out:
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Covid
# 1 : Normal
# 2 : Viral Pneumonia
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_201 (Conv2D)          (None, 240, 240, 128)     9728
# _________________________________________________________________
# activation_69 (Activation)   (None, 240, 240, 128)     0
# _________________________________________________________________
# module_wrapper_214 (ModuleWr (None, 120, 120, 128)     0
# _________________________________________________________________
# batch_normalization_141 (Bat (None, 120, 120, 128)     512
# _________________________________________________________________
# conv2d_202 (Conv2D)          (None, 118, 118, 64)      73792
# _________________________________________________________________
# activation_70 (Activation)   (None, 118, 118, 64)      0
# _________________________________________________________________
# module_wrapper_215 (ModuleWr (None, 59, 59, 64)        0
# _________________________________________________________________
# batch_normalization_142 (Bat (None, 59, 59, 64)        256
# _________________________________________________________________
# conv2d_203 (Conv2D)          (None, 57, 57, 32)        18464
# _________________________________________________________________
# activation_71 (Activation)   (None, 57, 57, 32)        0
# _________________________________________________________________
# module_wrapper_216 (ModuleWr (None, 28, 28, 32)        0
# _________________________________________________________________
# batch_normalization_143 (Bat (None, 28, 28, 32)        128
# _________________________________________________________________
# flatten_43 (Flatten)         (None, 25088)             0
# _________________________________________________________________
# dense_83 (Dense)             (None, 256)               6422784
# _________________________________________________________________
# module_wrapper_217 (ModuleWr (None, 256)               0
# _________________________________________________________________
# dense_84 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 6,526,435
# Trainable params: 6,525,987
# Non-trainable params: 448
# _________________________________________________________________
# Batch Sizes: 32
# Epochs: 20
# Epoch 1/20
# 8/8 - 15s - loss: 2.8154 - accuracy: 0.6614 - val_loss: 8.0262 - val_accuracy: 0.3030
# Epoch 2/20
# 8/8 - 14s - loss: 2.3195 - accuracy: 0.7450 - val_loss: 9.1052 - val_accuracy: 0.3030
# Epoch 3/20
# 8/8 - 14s - loss: 1.8810 - accuracy: 0.7530 - val_loss: 4.5051 - val_accuracy: 0.3636
# Epoch 4/20
# 8/8 - 15s - loss: 2.1522 - accuracy: 0.8207 - val_loss: 1.1480 - val_accuracy: 0.6970
# Epoch 5/20
# 8/8 - 13s - loss: 1.5726 - accuracy: 0.8048 - val_loss: 1.7828 - val_accuracy: 0.5303
# Epoch 6/20
# 8/8 - 14s - loss: 1.5810 - accuracy: 0.8008 - val_loss: 0.8850 - val_accuracy: 0.6970
# Epoch 7/20
# 8/8 - 14s - loss: 1.2975 - accuracy: 0.7928 - val_loss: 1.7783 - val_accuracy: 0.6212
# Epoch 8/20
# 8/8 - 14s - loss: 1.4880 - accuracy: 0.7888 - val_loss: 3.8322 - val_accuracy: 0.5455
# Epoch 9/20
# 8/8 - 14s - loss: 1.3908 - accuracy: 0.7849 - val_loss: 2.8212 - val_accuracy: 0.5606
# Epoch 10/20
# 8/8 - 14s - loss: 0.7591 - accuracy: 0.8367 - val_loss: 3.1028 - val_accuracy: 0.5000
# Epoch 11/20
# 8/8 - 15s - loss: 1.0273 - accuracy: 0.8287 - val_loss: 9.1956 - val_accuracy: 0.4091
# Epoch 12/20
# 8/8 - 14s - loss: 0.8313 - accuracy: 0.8327 - val_loss: 13.5431 - val_accuracy: 0.3939
# Epoch 13/20
# 8/8 - 14s - loss: 1.0491 - accuracy: 0.8406 - val_loss: 13.6944 - val_accuracy: 0.3939
# Epoch 14/20
# 8/8 - 14s - loss: 0.4491 - accuracy: 0.8805 - val_loss: 12.9375 - val_accuracy: 0.3939
# Epoch 15/20
# 8/8 - 14s - loss: 0.6134 - accuracy: 0.8884 - val_loss: 16.7745 - val_accuracy: 0.3939
# Epoch 16/20
# 8/8 - 14s - loss: 0.6636 - accuracy: 0.8685 - val_loss: 18.7174 - val_accuracy: 0.3939
# Epoch 17/20
# 8/8 - 14s - loss: 0.4175 - accuracy: 0.9084 - val_loss: 18.3627 - val_accuracy: 0.3939
# Epoch 18/20
# 8/8 - 15s - loss: 0.5084 - accuracy: 0.8805 - val_loss: 19.4809 - val_accuracy: 0.3939
# Epoch 19/20
# 8/8 - 14s - loss: 0.3249 - accuracy: 0.8924 - val_loss: 21.0720 - val_accuracy: 0.3939
# Epoch 20/20
# 8/8 - 14s - loss: 0.5545 - accuracy: 0.8924 - val_loss: 19.9711 - val_accuracy: 0.3939
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Covid
# 1 : Normal
# 2 : Viral Pneumonia
# Batch Sizes: 32
# Epochs: 50
# Epoch 1/50
# 8/8 - 15s - loss: 2.4649 - accuracy: 0.6375 - val_loss: 5.8658 - val_accuracy: 0.3030
# Epoch 2/50
# 8/8 - 15s - loss: 1.6968 - accuracy: 0.7689 - val_loss: 7.6377 - val_accuracy: 0.3030
# Epoch 3/50
# 8/8 - 14s - loss: 1.4148 - accuracy: 0.7928 - val_loss: 5.5737 - val_accuracy: 0.3636
# Epoch 4/50
# 8/8 - 14s - loss: 1.2041 - accuracy: 0.8526 - val_loss: 1.6962 - val_accuracy: 0.5455
# Epoch 5/50
# 8/8 - 14s - loss: 0.8287 - accuracy: 0.8127 - val_loss: 1.1784 - val_accuracy: 0.5909
# Epoch 6/50
# 8/8 - 14s - loss: 1.5703 - accuracy: 0.7729 - val_loss: 1.2716 - val_accuracy: 0.6515
# Epoch 7/50
# 8/8 - 14s - loss: 1.3658 - accuracy: 0.8048 - val_loss: 9.6674 - val_accuracy: 0.3939
# Epoch 8/50
# 8/8 - 14s - loss: 1.6124 - accuracy: 0.7649 - val_loss: 12.9939 - val_accuracy: 0.3939
# Epoch 9/50
# 8/8 - 14s - loss: 0.6734 - accuracy: 0.8805 - val_loss: 13.6094 - val_accuracy: 0.3939
# Epoch 10/50
# 8/8 - 14s - loss: 0.9293 - accuracy: 0.8526 - val_loss: 8.5432 - val_accuracy: 0.4394
# Epoch 11/50
# 8/8 - 14s - loss: 0.9557 - accuracy: 0.8287 - val_loss: 11.9911 - val_accuracy: 0.3939
# Epoch 12/50
# 8/8 - 14s - loss: 0.4966 - accuracy: 0.8765 - val_loss: 15.3008 - val_accuracy: 0.3939
# Epoch 13/50
# 8/8 - 14s - loss: 0.8514 - accuracy: 0.8167 - val_loss: 21.6199 - val_accuracy: 0.3939
# Epoch 14/50
# 8/8 - 14s - loss: 0.4403 - accuracy: 0.8645 - val_loss: 23.4773 - val_accuracy: 0.3939
# Epoch 15/50
# 8/8 - 14s - loss: 0.5118 - accuracy: 0.8845 - val_loss: 25.3258 - val_accuracy: 0.3939
# Epoch 16/50
# 8/8 - 14s - loss: 0.5613 - accuracy: 0.8526 - val_loss: 28.7929 - val_accuracy: 0.3939
# Epoch 17/50
# 8/8 - 14s - loss: 0.4498 - accuracy: 0.8765 - val_loss: 30.5089 - val_accuracy: 0.3939
# Epoch 18/50
# 8/8 - 14s - loss: 0.4992 - accuracy: 0.8566 - val_loss: 29.8625 - val_accuracy: 0.3939
# Epoch 19/50
# 8/8 - 14s - loss: 0.4313 - accuracy: 0.8964 - val_loss: 28.9538 - val_accuracy: 0.3939
# Epoch 20/50
# 8/8 - 14s - loss: 0.5690 - accuracy: 0.8685 - val_loss: 30.9163 - val_accuracy: 0.3939
# Epoch 21/50
# 8/8 - 14s - loss: 0.3211 - accuracy: 0.9044 - val_loss: 31.8218 - val_accuracy: 0.3939
# Epoch 22/50
# 8/8 - 14s - loss: 0.4532 - accuracy: 0.8685 - val_loss: 31.3001 - val_accuracy: 0.3939
# Epoch 23/50
# 8/8 - 14s - loss: 0.2961 - accuracy: 0.9044 - val_loss: 32.4674 - val_accuracy: 0.3939
# Epoch 24/50
# 8/8 - 14s - loss: 0.3565 - accuracy: 0.8725 - val_loss: 31.4027 - val_accuracy: 0.3939
# Epoch 25/50
# 8/8 - 13s - loss: 0.3487 - accuracy: 0.8805 - val_loss: 31.2945 - val_accuracy: 0.3939
# Epoch 26/50
# 8/8 - 14s - loss: 0.3972 - accuracy: 0.8725 - val_loss: 30.0846 - val_accuracy: 0.3939
# Epoch 27/50
# 8/8 - 14s - loss: 0.3928 - accuracy: 0.8725 - val_loss: 29.5760 - val_accuracy: 0.3939
# Epoch 28/50
# 8/8 - 15s - loss: 0.4697 - accuracy: 0.8964 - val_loss: 30.6368 - val_accuracy: 0.3939
# Epoch 29/50
# 8/8 - 14s - loss: 0.6336 - accuracy: 0.8845 - val_loss: 29.1004 - val_accuracy: 0.3939
# Epoch 30/50
# 8/8 - 14s - loss: 0.5471 - accuracy: 0.8406 - val_loss: 29.2344 - val_accuracy: 0.3939
# Epoch 31/50
# 8/8 - 14s - loss: 0.3749 - accuracy: 0.9163 - val_loss: 28.1392 - val_accuracy: 0.3939
# Epoch 32/50
# 8/8 - 14s - loss: 0.3804 - accuracy: 0.8606 - val_loss: 25.2802 - val_accuracy: 0.3939
# Epoch 33/50
# 8/8 - 14s - loss: 0.3589 - accuracy: 0.9203 - val_loss: 25.9947 - val_accuracy: 0.3939
# Epoch 34/50
# 8/8 - 14s - loss: 0.5604 - accuracy: 0.8685 - val_loss: 26.2442 - val_accuracy: 0.3939
# Epoch 35/50
# 8/8 - 14s - loss: 0.3590 - accuracy: 0.8884 - val_loss: 25.7621 - val_accuracy: 0.3939
# Epoch 36/50
# 8/8 - 13s - loss: 0.3462 - accuracy: 0.9004 - val_loss: 22.9756 - val_accuracy: 0.3939
# Epoch 37/50
# 8/8 - 14s - loss: 0.4098 - accuracy: 0.8685 - val_loss: 21.8247 - val_accuracy: 0.3939
# Epoch 38/50
# 8/8 - 14s - loss: 0.3649 - accuracy: 0.8805 - val_loss: 22.0018 - val_accuracy: 0.3939
# Epoch 39/50
# 8/8 - 14s - loss: 0.3072 - accuracy: 0.8884 - val_loss: 20.1273 - val_accuracy: 0.3939
# Epoch 40/50
# 8/8 - 14s - loss: 0.5052 - accuracy: 0.8725 - val_loss: 19.6173 - val_accuracy: 0.3939
# Epoch 41/50
# 8/8 - 14s - loss: 0.2818 - accuracy: 0.9203 - val_loss: 17.7375 - val_accuracy: 0.3939
# Epoch 42/50
# 8/8 - 14s - loss: 0.3253 - accuracy: 0.9084 - val_loss: 17.0642 - val_accuracy: 0.3939
# Epoch 43/50
# 8/8 - 14s - loss: 0.3419 - accuracy: 0.9004 - val_loss: 14.4941 - val_accuracy: 0.3939
# Epoch 44/50
# 8/8 - 14s - loss: 0.4613 - accuracy: 0.8725 - val_loss: 14.6100 - val_accuracy: 0.3939
# Epoch 45/50
# 8/8 - 14s - loss: 0.2815 - accuracy: 0.9044 - val_loss: 14.1738 - val_accuracy: 0.3939
# Epoch 46/50
# 8/8 - 13s - loss: 0.3748 - accuracy: 0.8805 - val_loss: 12.5509 - val_accuracy: 0.3939
# Epoch 47/50
# 8/8 - 14s - loss: 0.3410 - accuracy: 0.9124 - val_loss: 10.2972 - val_accuracy: 0.4242
# Epoch 48/50
# 8/8 - 14s - loss: 0.3654 - accuracy: 0.8924 - val_loss: 11.2030 - val_accuracy: 0.4091
# Epoch 49/50
# 8/8 - 14s - loss: 0.2774 - accuracy: 0.8725 - val_loss: 9.9940 - val_accuracy: 0.3939
# Epoch 50/50
# 8/8 - 14s - loss: 0.3800 - accuracy: 0.8884 - val_loss: 9.0739 - val_accuracy: 0.4091
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Covid
# 1 : Normal
# 2 : Viral Pneumonia
# Batch Sizes: 32
# Epochs: 100
# Epoch 1/100
# 8/8 - 16s - loss: 4.0048 - accuracy: 0.6335 - val_loss: 8.9948 - val_accuracy: 0.3182
# Epoch 2/100
# 8/8 - 14s - loss: 3.1869 - accuracy: 0.7570 - val_loss: 5.4865 - val_accuracy: 0.3485
# Epoch 3/100
# 8/8 - 13s - loss: 3.0236 - accuracy: 0.7769 - val_loss: 5.2232 - val_accuracy: 0.3485
# Epoch 4/100
# 8/8 - 14s - loss: 2.2346 - accuracy: 0.7610 - val_loss: 2.9031 - val_accuracy: 0.4242
# Epoch 5/100
# 8/8 - 14s - loss: 2.2169 - accuracy: 0.7689 - val_loss: 5.0042 - val_accuracy: 0.3636
# Epoch 6/100
# 8/8 - 14s - loss: 1.6392 - accuracy: 0.8207 - val_loss: 1.7878 - val_accuracy: 0.5606
# Epoch 7/100
# 8/8 - 14s - loss: 1.1211 - accuracy: 0.8048 - val_loss: 5.3205 - val_accuracy: 0.5152
# Epoch 8/100
# 8/8 - 14s - loss: 1.5306 - accuracy: 0.8088 - val_loss: 5.1050 - val_accuracy: 0.4697
# Epoch 9/100
# 8/8 - 14s - loss: 1.1650 - accuracy: 0.8127 - val_loss: 5.0782 - val_accuracy: 0.4545
# Epoch 10/100
# 8/8 - 14s - loss: 0.7793 - accuracy: 0.8606 - val_loss: 10.9015 - val_accuracy: 0.4242
# Epoch 11/100
# 8/8 - 14s - loss: 1.0946 - accuracy: 0.8127 - val_loss: 14.7199 - val_accuracy: 0.3939
# Epoch 12/100
# 8/8 - 14s - loss: 0.9346 - accuracy: 0.8446 - val_loss: 20.8767 - val_accuracy: 0.3939
# Epoch 13/100
# 8/8 - 14s - loss: 0.5558 - accuracy: 0.8765 - val_loss: 28.8574 - val_accuracy: 0.3939
# Epoch 14/100
# 8/8 - 14s - loss: 0.4692 - accuracy: 0.8725 - val_loss: 30.3852 - val_accuracy: 0.3939
# Epoch 15/100
# 8/8 - 14s - loss: 0.3149 - accuracy: 0.9004 - val_loss: 30.6312 - val_accuracy: 0.3939
# Epoch 16/100
# 8/8 - 14s - loss: 0.4493 - accuracy: 0.8685 - val_loss: 30.7493 - val_accuracy: 0.3939
# Epoch 17/100
# 8/8 - 14s - loss: 0.4099 - accuracy: 0.9044 - val_loss: 32.8636 - val_accuracy: 0.3939
# Epoch 18/100
# 8/8 - 14s - loss: 0.4573 - accuracy: 0.8805 - val_loss: 35.0676 - val_accuracy: 0.3939
# Epoch 19/100
# 8/8 - 14s - loss: 0.3828 - accuracy: 0.8884 - val_loss: 37.6592 - val_accuracy: 0.3939
# Epoch 20/100
# 8/8 - 14s - loss: 0.3439 - accuracy: 0.9084 - val_loss: 36.6905 - val_accuracy: 0.3939
# Epoch 21/100
# 8/8 - 13s - loss: 0.3647 - accuracy: 0.8924 - val_loss: 36.5015 - val_accuracy: 0.3939
# Epoch 22/100
# 8/8 - 14s - loss: 0.4232 - accuracy: 0.8685 - val_loss: 35.5952 - val_accuracy: 0.3939
# Epoch 23/100
# 8/8 - 14s - loss: 0.3813 - accuracy: 0.8685 - val_loss: 36.5680 - val_accuracy: 0.3939
# Epoch 24/100
# 8/8 - 14s - loss: 0.4333 - accuracy: 0.8845 - val_loss: 33.2218 - val_accuracy: 0.3939
# Epoch 25/100
# 8/8 - 14s - loss: 0.4976 - accuracy: 0.9044 - val_loss: 34.8639 - val_accuracy: 0.3939
# Epoch 26/100
# 8/8 - 14s - loss: 0.3002 - accuracy: 0.8964 - val_loss: 33.1682 - val_accuracy: 0.3939
# Epoch 27/100
# 8/8 - 14s - loss: 0.2300 - accuracy: 0.9363 - val_loss: 33.5059 - val_accuracy: 0.3939
# Epoch 28/100
# 8/8 - 14s - loss: 0.3232 - accuracy: 0.9044 - val_loss: 33.9265 - val_accuracy: 0.3939
# Epoch 29/100
# 8/8 - 14s - loss: 0.2698 - accuracy: 0.9004 - val_loss: 30.0601 - val_accuracy: 0.3939
# Epoch 30/100
# 8/8 - 14s - loss: 0.3722 - accuracy: 0.8964 - val_loss: 31.6133 - val_accuracy: 0.3939
# Epoch 31/100
# 8/8 - 14s - loss: 0.2722 - accuracy: 0.9124 - val_loss: 27.7386 - val_accuracy: 0.3939
# Epoch 32/100
# 8/8 - 14s - loss: 0.3068 - accuracy: 0.8845 - val_loss: 28.7250 - val_accuracy: 0.3939
# Epoch 33/100
# 8/8 - 14s - loss: 0.3322 - accuracy: 0.8964 - val_loss: 27.2259 - val_accuracy: 0.3939
# Epoch 34/100
# 8/8 - 14s - loss: 0.3431 - accuracy: 0.9044 - val_loss: 27.2058 - val_accuracy: 0.3939
# Epoch 35/100
# 8/8 - 14s - loss: 0.3562 - accuracy: 0.9124 - val_loss: 25.4894 - val_accuracy: 0.3939
# Epoch 36/100
# 8/8 - 14s - loss: 0.2572 - accuracy: 0.8964 - val_loss: 23.6302 - val_accuracy: 0.3939
# Epoch 37/100
# 8/8 - 14s - loss: 0.4825 - accuracy: 0.8685 - val_loss: 24.6688 - val_accuracy: 0.3939
# Epoch 38/100
# 8/8 - 13s - loss: 0.3511 - accuracy: 0.8765 - val_loss: 21.4321 - val_accuracy: 0.3939
# Epoch 39/100
# 8/8 - 14s - loss: 0.2815 - accuracy: 0.9084 - val_loss: 20.3144 - val_accuracy: 0.3939
# Epoch 40/100
# 8/8 - 14s - loss: 0.2722 - accuracy: 0.9203 - val_loss: 19.1303 - val_accuracy: 0.3939
# Epoch 41/100
# 8/8 - 14s - loss: 0.3608 - accuracy: 0.8645 - val_loss: 16.1511 - val_accuracy: 0.3939
# Epoch 42/100
# 8/8 - 14s - loss: 0.3903 - accuracy: 0.8805 - val_loss: 14.8273 - val_accuracy: 0.3939
# Epoch 43/100
# 8/8 - 14s - loss: 0.2894 - accuracy: 0.8924 - val_loss: 14.5081 - val_accuracy: 0.3939
# Epoch 44/100
# 8/8 - 14s - loss: 0.2307 - accuracy: 0.9243 - val_loss: 13.1157 - val_accuracy: 0.3939
# Epoch 45/100
# 8/8 - 14s - loss: 0.3522 - accuracy: 0.8924 - val_loss: 12.3385 - val_accuracy: 0.3939
# Epoch 46/100
# 8/8 - 14s - loss: 0.2919 - accuracy: 0.9283 - val_loss: 13.6263 - val_accuracy: 0.4242
# Epoch 47/100
# 8/8 - 14s - loss: 0.3723 - accuracy: 0.8765 - val_loss: 11.1063 - val_accuracy: 0.4242
# Epoch 48/100
# 8/8 - 13s - loss: 0.3788 - accuracy: 0.8685 - val_loss: 8.7767 - val_accuracy: 0.4242
# Epoch 49/100
# 8/8 - 14s - loss: 0.3657 - accuracy: 0.8924 - val_loss: 9.3557 - val_accuracy: 0.4394
# Epoch 50/100
# 8/8 - 13s - loss: 0.4129 - accuracy: 0.8805 - val_loss: 7.5903 - val_accuracy: 0.4545
# Epoch 51/100
# 8/8 - 14s - loss: 0.1871 - accuracy: 0.9323 - val_loss: 5.5290 - val_accuracy: 0.4394
# Epoch 52/100
# 8/8 - 13s - loss: 0.4418 - accuracy: 0.8845 - val_loss: 6.3364 - val_accuracy: 0.4394
# Epoch 53/100
# 8/8 - 13s - loss: 0.2775 - accuracy: 0.8884 - val_loss: 5.0916 - val_accuracy: 0.5152
# Epoch 54/100
# 8/8 - 14s - loss: 0.3943 - accuracy: 0.8765 - val_loss: 5.2110 - val_accuracy: 0.5152
# Epoch 55/100
# 8/8 - 14s - loss: 0.3094 - accuracy: 0.9243 - val_loss: 3.7616 - val_accuracy: 0.6212
# Epoch 56/100
# 8/8 - 14s - loss: 0.3275 - accuracy: 0.8645 - val_loss: 3.2019 - val_accuracy: 0.5455
# Epoch 57/100
# 8/8 - 13s - loss: 0.2100 - accuracy: 0.9163 - val_loss: 4.3320 - val_accuracy: 0.5303
# Epoch 58/100
# 8/8 - 14s - loss: 0.4079 - accuracy: 0.8964 - val_loss: 1.9916 - val_accuracy: 0.6364
# Epoch 59/100
# 8/8 - 14s - loss: 0.2895 - accuracy: 0.9323 - val_loss: 3.3224 - val_accuracy: 0.6364
# Epoch 60/100
# 8/8 - 13s - loss: 0.3006 - accuracy: 0.9163 - val_loss: 2.4565 - val_accuracy: 0.6818
# Epoch 61/100
# 8/8 - 14s - loss: 0.2871 - accuracy: 0.9084 - val_loss: 2.5963 - val_accuracy: 0.6364
# Epoch 62/100
# 8/8 - 13s - loss: 0.2990 - accuracy: 0.9084 - val_loss: 2.1873 - val_accuracy: 0.6364
# Epoch 63/100
# 8/8 - 14s - loss: 0.2291 - accuracy: 0.9402 - val_loss: 1.7073 - val_accuracy: 0.6364
# Epoch 64/100
# 8/8 - 14s - loss: 0.3454 - accuracy: 0.8685 - val_loss: 1.8009 - val_accuracy: 0.7727
# Epoch 65/100
# 8/8 - 13s - loss: 0.3193 - accuracy: 0.8805 - val_loss: 2.0689 - val_accuracy: 0.7424
# Epoch 66/100
# 8/8 - 14s - loss: 0.3006 - accuracy: 0.8964 - val_loss: 1.4287 - val_accuracy: 0.7576
# Epoch 67/100
# 8/8 - 14s - loss: 0.3413 - accuracy: 0.9243 - val_loss: 0.9036 - val_accuracy: 0.7576
# Epoch 68/100
# 8/8 - 13s - loss: 0.4122 - accuracy: 0.8884 - val_loss: 0.9901 - val_accuracy: 0.7424
# Epoch 69/100
# 8/8 - 14s - loss: 0.3228 - accuracy: 0.9124 - val_loss: 0.8715 - val_accuracy: 0.8182
# Epoch 70/100
# 8/8 - 14s - loss: 0.4600 - accuracy: 0.8685 - val_loss: 0.5244 - val_accuracy: 0.7424
# Epoch 71/100
# 8/8 - 14s - loss: 0.2646 - accuracy: 0.9004 - val_loss: 0.9462 - val_accuracy: 0.7424
# Epoch 72/100
# 8/8 - 13s - loss: 0.3345 - accuracy: 0.9163 - val_loss: 0.7095 - val_accuracy: 0.7727
# Epoch 73/100
# 8/8 - 14s - loss: 0.3443 - accuracy: 0.9163 - val_loss: 0.8565 - val_accuracy: 0.6970
# Epoch 74/100
# 8/8 - 13s - loss: 0.4283 - accuracy: 0.9084 - val_loss: 0.8028 - val_accuracy: 0.7576
# Epoch 75/100
# 8/8 - 14s - loss: 0.2686 - accuracy: 0.8964 - val_loss: 0.7325 - val_accuracy: 0.8182
# Epoch 76/100
# 8/8 - 14s - loss: 0.2861 - accuracy: 0.8924 - val_loss: 0.6469 - val_accuracy: 0.7879
# Epoch 77/100
# 8/8 - 13s - loss: 0.3381 - accuracy: 0.8924 - val_loss: 0.4815 - val_accuracy: 0.8182
# Epoch 78/100
# 8/8 - 14s - loss: 0.3148 - accuracy: 0.8924 - val_loss: 0.3961 - val_accuracy: 0.8333
# Epoch 79/100
# 8/8 - 13s - loss: 0.4262 - accuracy: 0.8606 - val_loss: 0.4203 - val_accuracy: 0.8636
# Epoch 80/100
# 8/8 - 14s - loss: 0.2316 - accuracy: 0.9004 - val_loss: 0.6698 - val_accuracy: 0.8030
# Epoch 81/100
# 8/8 - 13s - loss: 0.3936 - accuracy: 0.8884 - val_loss: 0.5502 - val_accuracy: 0.7727
# Epoch 82/100
# 8/8 - 14s - loss: 0.3682 - accuracy: 0.8805 - val_loss: 0.4525 - val_accuracy: 0.8788
# Epoch 83/100
# 8/8 - 14s - loss: 0.4016 - accuracy: 0.8685 - val_loss: 0.5084 - val_accuracy: 0.8485
# Epoch 84/100
# 8/8 - 14s - loss: 0.3428 - accuracy: 0.8964 - val_loss: 0.5322 - val_accuracy: 0.8030
# Epoch 85/100
# 8/8 - 14s - loss: 0.3598 - accuracy: 0.8924 - val_loss: 0.5060 - val_accuracy: 0.7727
# Epoch 86/100
# 8/8 - 14s - loss: 0.3905 - accuracy: 0.8725 - val_loss: 0.4292 - val_accuracy: 0.7879
# Epoch 87/100
# 8/8 - 14s - loss: 0.5070 - accuracy: 0.8845 - val_loss: 0.4538 - val_accuracy: 0.7879
# Epoch 88/100
# 8/8 - 14s - loss: 0.3858 - accuracy: 0.8526 - val_loss: 0.5580 - val_accuracy: 0.8182
# Epoch 89/100
# 8/8 - 14s - loss: 0.2530 - accuracy: 0.8964 - val_loss: 0.4879 - val_accuracy: 0.7727
# Epoch 90/100
# 8/8 - 14s - loss: 0.2479 - accuracy: 0.8884 - val_loss: 0.4729 - val_accuracy: 0.8182
# Epoch 91/100
# 8/8 - 13s - loss: 0.4134 - accuracy: 0.8924 - val_loss: 0.4886 - val_accuracy: 0.8182
# Epoch 92/100
# 8/8 - 14s - loss: 0.3463 - accuracy: 0.8845 - val_loss: 0.3604 - val_accuracy: 0.8333
# Epoch 93/100
# 8/8 - 13s - loss: 0.3476 - accuracy: 0.8845 - val_loss: 0.4544 - val_accuracy: 0.8182
# Epoch 94/100
# 8/8 - 14s - loss: 0.3304 - accuracy: 0.8884 - val_loss: 0.4129 - val_accuracy: 0.8485
# Epoch 95/100
# 8/8 - 13s - loss: 0.2767 - accuracy: 0.9203 - val_loss: 0.5681 - val_accuracy: 0.8030
# Epoch 96/100
# 8/8 - 14s - loss: 0.3452 - accuracy: 0.9243 - val_loss: 0.3593 - val_accuracy: 0.7879
# Epoch 97/100
# 8/8 - 14s - loss: 0.3893 - accuracy: 0.8805 - val_loss: 0.5035 - val_accuracy: 0.8030
# Epoch 98/100
# 8/8 - 14s - loss: 0.4051 - accuracy: 0.8845 - val_loss: 0.3645 - val_accuracy: 0.8485
# Epoch 99/100
# 8/8 - 14s - loss: 0.3254 - accuracy: 0.8884 - val_loss: 0.4267 - val_accuracy: 0.7727
# Epoch 100/100
# 8/8 - 14s - loss: 0.3845 - accuracy: 0.8884 - val_loss: 0.4117 - val_accuracy: 0.8333
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Covid
# 1 : Normal
# 2 : Viral Pneumonia
# Batch Sizes: 64
# Epochs: 20
# Epoch 1/20
# 4/4 - 18s - loss: 3.6046 - accuracy: 0.5697 - val_loss: 1.3735 - val_accuracy: 0.3182
# Epoch 2/20
# 4/4 - 14s - loss: 2.1595 - accuracy: 0.7530 - val_loss: 2.4965 - val_accuracy: 0.3182
# Epoch 3/20
# 4/4 - 14s - loss: 2.3608 - accuracy: 0.7928 - val_loss: 2.1516 - val_accuracy: 0.3636
# Epoch 4/20
# 4/4 - 14s - loss: 1.5061 - accuracy: 0.8446 - val_loss: 2.1494 - val_accuracy: 0.3485
# Epoch 5/20
# 4/4 - 15s - loss: 1.5068 - accuracy: 0.7968 - val_loss: 3.0448 - val_accuracy: 0.3485
# Epoch 6/20
# 4/4 - 14s - loss: 0.8459 - accuracy: 0.8048 - val_loss: 3.6295 - val_accuracy: 0.2879
# Epoch 7/20
# 4/4 - 14s - loss: 1.0346 - accuracy: 0.7649 - val_loss: 2.1322 - val_accuracy: 0.4545
# Epoch 8/20
# 4/4 - 14s - loss: 0.8343 - accuracy: 0.8327 - val_loss: 1.4948 - val_accuracy: 0.5152
# Epoch 9/20
# 4/4 - 14s - loss: 0.6049 - accuracy: 0.8247 - val_loss: 1.2798 - val_accuracy: 0.6061
# Epoch 10/20
# 4/4 - 14s - loss: 0.4669 - accuracy: 0.8606 - val_loss: 1.8272 - val_accuracy: 0.5909
# Epoch 11/20
# 4/4 - 14s - loss: 0.6843 - accuracy: 0.8606 - val_loss: 2.1791 - val_accuracy: 0.5606
# Epoch 12/20
# 4/4 - 14s - loss: 0.5573 - accuracy: 0.8406 - val_loss: 2.4786 - val_accuracy: 0.5303
# Epoch 13/20
# 4/4 - 14s - loss: 0.4106 - accuracy: 0.8765 - val_loss: 3.2315 - val_accuracy: 0.5303
# Epoch 14/20
# 4/4 - 15s - loss: 0.7226 - accuracy: 0.8606 - val_loss: 4.5229 - val_accuracy: 0.4545
# Epoch 15/20
# 4/4 - 14s - loss: 0.5210 - accuracy: 0.8685 - val_loss: 6.3904 - val_accuracy: 0.4091
# Epoch 16/20
# 4/4 - 14s - loss: 0.4194 - accuracy: 0.8725 - val_loss: 7.6032 - val_accuracy: 0.3939
# Epoch 17/20
# 4/4 - 14s - loss: 0.3078 - accuracy: 0.8884 - val_loss: 8.9456 - val_accuracy: 0.3939
# Epoch 18/20
# 4/4 - 14s - loss: 0.4332 - accuracy: 0.8884 - val_loss: 11.3554 - val_accuracy: 0.3939
# Epoch 19/20
# 4/4 - 14s - loss: 0.2899 - accuracy: 0.8805 - val_loss: 11.6717 - val_accuracy: 0.3939
# Epoch 20/20
# 4/4 - 14s - loss: 0.3237 - accuracy: 0.9163 - val_loss: 12.5291 - val_accuracy: 0.3939
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Covid
# 1 : Normal
# 2 : Viral Pneumonia
# Batch Sizes: 64
# Epochs: 50
# Epoch 1/50
# 4/4 - 17s - loss: 3.1309 - accuracy: 0.5578 - val_loss: 9.1742 - val_accuracy: 0.3030
# Epoch 2/50
# 4/4 - 14s - loss: 2.7534 - accuracy: 0.7052 - val_loss: 5.5354 - val_accuracy: 0.3030
# Epoch 3/50
# 4/4 - 14s - loss: 1.6611 - accuracy: 0.7689 - val_loss: 3.9987 - val_accuracy: 0.3030
# Epoch 4/50
# 4/4 - 14s - loss: 0.8380 - accuracy: 0.8207 - val_loss: 4.3005 - val_accuracy: 0.3030
# Epoch 5/50
# 4/4 - 14s - loss: 0.9881 - accuracy: 0.8287 - val_loss: 5.7194 - val_accuracy: 0.3030
# Epoch 6/50
# 4/4 - 14s - loss: 0.9452 - accuracy: 0.8247 - val_loss: 8.3831 - val_accuracy: 0.3182
# Epoch 7/50
# 4/4 - 14s - loss: 0.9780 - accuracy: 0.8048 - val_loss: 7.8963 - val_accuracy: 0.3939
# Epoch 8/50
# 4/4 - 14s - loss: 0.8185 - accuracy: 0.8327 - val_loss: 8.2203 - val_accuracy: 0.3636
# Epoch 9/50
# 4/4 - 14s - loss: 1.2523 - accuracy: 0.7649 - val_loss: 4.8087 - val_accuracy: 0.4394
# Epoch 10/50
# 4/4 - 14s - loss: 0.7805 - accuracy: 0.8247 - val_loss: 2.0262 - val_accuracy: 0.5152
# Epoch 11/50
# 4/4 - 14s - loss: 0.7564 - accuracy: 0.8526 - val_loss: 0.8432 - val_accuracy: 0.6818
# Epoch 12/50
# 4/4 - 14s - loss: 0.6748 - accuracy: 0.8446 - val_loss: 0.9306 - val_accuracy: 0.6970
# Epoch 13/50
# 4/4 - 14s - loss: 0.7041 - accuracy: 0.8486 - val_loss: 0.7219 - val_accuracy: 0.6970
# Epoch 14/50
# 4/4 - 14s - loss: 0.5505 - accuracy: 0.8566 - val_loss: 1.5574 - val_accuracy: 0.6212
# Epoch 15/50
# 4/4 - 14s - loss: 0.3487 - accuracy: 0.8884 - val_loss: 3.1782 - val_accuracy: 0.4697
# Epoch 16/50
# 4/4 - 14s - loss: 0.4288 - accuracy: 0.8845 - val_loss: 5.5298 - val_accuracy: 0.5152
# Epoch 17/50
# 4/4 - 14s - loss: 0.4367 - accuracy: 0.8924 - val_loss: 9.0571 - val_accuracy: 0.4697
# Epoch 18/50
# 4/4 - 14s - loss: 0.5958 - accuracy: 0.8606 - val_loss: 12.8069 - val_accuracy: 0.4242
# Epoch 19/50
# 4/4 - 14s - loss: 0.3796 - accuracy: 0.8924 - val_loss: 15.9783 - val_accuracy: 0.3939
# Epoch 20/50
# 4/4 - 14s - loss: 0.2424 - accuracy: 0.9243 - val_loss: 17.8389 - val_accuracy: 0.3939
# Epoch 21/50
# 4/4 - 14s - loss: 0.3766 - accuracy: 0.8685 - val_loss: 20.3097 - val_accuracy: 0.3939
# Epoch 22/50
# 4/4 - 15s - loss: 0.3305 - accuracy: 0.8725 - val_loss: 25.8117 - val_accuracy: 0.3939
# Epoch 23/50
# 4/4 - 14s - loss: 0.2809 - accuracy: 0.9044 - val_loss: 27.9322 - val_accuracy: 0.3939
# Epoch 24/50
# 4/4 - 14s - loss: 0.3387 - accuracy: 0.8765 - val_loss: 29.4962 - val_accuracy: 0.3939
# Epoch 25/50
# 4/4 - 14s - loss: 0.3993 - accuracy: 0.8685 - val_loss: 32.5536 - val_accuracy: 0.3939
# Epoch 26/50
# 4/4 - 14s - loss: 0.2679 - accuracy: 0.9044 - val_loss: 33.3250 - val_accuracy: 0.3939
# Epoch 27/50
# 4/4 - 14s - loss: 0.2888 - accuracy: 0.9044 - val_loss: 36.5955 - val_accuracy: 0.3939
# Epoch 28/50
# 4/4 - 14s - loss: 0.4095 - accuracy: 0.8884 - val_loss: 36.8314 - val_accuracy: 0.3939
# Epoch 29/50
# 4/4 - 15s - loss: 0.3238 - accuracy: 0.9084 - val_loss: 34.1657 - val_accuracy: 0.3939
# Epoch 30/50
# 4/4 - 14s - loss: 0.2514 - accuracy: 0.9124 - val_loss: 38.7099 - val_accuracy: 0.3939
# Epoch 31/50
# 4/4 - 14s - loss: 0.2908 - accuracy: 0.9283 - val_loss: 37.0914 - val_accuracy: 0.3939
# Epoch 32/50
# 4/4 - 14s - loss: 0.3232 - accuracy: 0.9163 - val_loss: 39.0068 - val_accuracy: 0.3939
# Epoch 33/50
# 4/4 - 14s - loss: 0.2578 - accuracy: 0.9044 - val_loss: 40.3370 - val_accuracy: 0.3939
# Epoch 34/50
# 4/4 - 14s - loss: 0.6071 - accuracy: 0.9004 - val_loss: 40.3569 - val_accuracy: 0.3939
# Epoch 35/50
# 4/4 - 14s - loss: 0.3145 - accuracy: 0.8964 - val_loss: 40.3822 - val_accuracy: 0.3939
# Epoch 36/50
# 4/4 - 14s - loss: 0.3950 - accuracy: 0.8765 - val_loss: 40.4972 - val_accuracy: 0.3939
# Epoch 37/50
# 4/4 - 14s - loss: 0.3854 - accuracy: 0.8765 - val_loss: 37.9489 - val_accuracy: 0.3939
# Epoch 38/50
# 4/4 - 14s - loss: 0.4360 - accuracy: 0.8924 - val_loss: 42.3387 - val_accuracy: 0.3939
# Epoch 39/50
# 4/4 - 14s - loss: 0.2781 - accuracy: 0.8805 - val_loss: 41.9158 - val_accuracy: 0.3939
# Epoch 40/50
# 4/4 - 14s - loss: 0.3174 - accuracy: 0.9004 - val_loss: 43.2338 - val_accuracy: 0.3939
# Epoch 41/50
# 4/4 - 14s - loss: 0.2913 - accuracy: 0.9163 - val_loss: 43.0213 - val_accuracy: 0.3939
# Epoch 42/50
# 4/4 - 14s - loss: 0.3101 - accuracy: 0.8845 - val_loss: 45.4524 - val_accuracy: 0.3939
# Epoch 43/50
# 4/4 - 14s - loss: 0.2285 - accuracy: 0.9044 - val_loss: 43.1219 - val_accuracy: 0.3939
# Epoch 44/50
# 4/4 - 14s - loss: 0.2509 - accuracy: 0.9084 - val_loss: 46.0512 - val_accuracy: 0.3939
# Epoch 45/50
# 4/4 - 14s - loss: 0.2431 - accuracy: 0.9163 - val_loss: 39.8489 - val_accuracy: 0.3939
# Epoch 46/50
# 4/4 - 14s - loss: 0.2815 - accuracy: 0.8845 - val_loss: 41.9244 - val_accuracy: 0.3939
# Epoch 47/50
# 4/4 - 15s - loss: 0.3379 - accuracy: 0.8924 - val_loss: 41.5315 - val_accuracy: 0.3939
# Epoch 48/50
# 4/4 - 14s - loss: 0.2746 - accuracy: 0.8924 - val_loss: 44.8486 - val_accuracy: 0.3939
# Epoch 49/50
# 4/4 - 14s - loss: 0.2723 - accuracy: 0.9203 - val_loss: 44.5673 - val_accuracy: 0.3939
# Epoch 50/50
# 4/4 - 14s - loss: 0.2875 - accuracy: 0.9163 - val_loss: 41.2363 - val_accuracy: 0.3939
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Covid
# 1 : Normal
# 2 : Viral Pneumonia
# Batch Sizes: 64
# Epochs: 100
# Epoch 1/100
# 4/4 - 17s - loss: 2.9230 - accuracy: 0.6016 - val_loss: 3.0422 - val_accuracy: 0.3030
# Epoch 2/100
# 4/4 - 14s - loss: 1.3693 - accuracy: 0.7610 - val_loss: 1.6372 - val_accuracy: 0.4242
# Epoch 3/100
# 4/4 - 14s - loss: 1.5461 - accuracy: 0.7649 - val_loss: 0.8674 - val_accuracy: 0.6364
# Epoch 4/100
# 4/4 - 15s - loss: 1.3086 - accuracy: 0.7888 - val_loss: 1.4545 - val_accuracy: 0.4697
# Epoch 5/100
# 4/4 - 14s - loss: 1.5242 - accuracy: 0.7450 - val_loss: 3.6254 - val_accuracy: 0.4091
# Epoch 6/100
# 4/4 - 15s - loss: 1.1071 - accuracy: 0.7809 - val_loss: 2.7008 - val_accuracy: 0.3939
# Epoch 7/100
# 4/4 - 14s - loss: 0.9364 - accuracy: 0.8247 - val_loss: 1.7801 - val_accuracy: 0.5303
# Epoch 8/100
# 4/4 - 14s - loss: 0.7252 - accuracy: 0.8008 - val_loss: 3.1623 - val_accuracy: 0.4394
# Epoch 9/100
# 4/4 - 14s - loss: 0.6466 - accuracy: 0.8406 - val_loss: 2.9482 - val_accuracy: 0.4545
# Epoch 10/100
# 4/4 - 15s - loss: 0.6712 - accuracy: 0.8167 - val_loss: 3.9596 - val_accuracy: 0.4242
# Epoch 11/100
# 4/4 - 14s - loss: 0.5169 - accuracy: 0.8845 - val_loss: 3.7054 - val_accuracy: 0.4545
# Epoch 12/100
# 4/4 - 14s - loss: 0.6382 - accuracy: 0.8327 - val_loss: 4.2743 - val_accuracy: 0.5000
# Epoch 13/100
# 4/4 - 14s - loss: 0.3100 - accuracy: 0.8805 - val_loss: 5.1637 - val_accuracy: 0.4091
# Epoch 14/100
# 4/4 - 14s - loss: 0.3581 - accuracy: 0.8765 - val_loss: 6.7867 - val_accuracy: 0.4394
# Epoch 15/100
# 4/4 - 15s - loss: 0.4650 - accuracy: 0.8566 - val_loss: 8.7296 - val_accuracy: 0.3939
# Epoch 16/100
# 4/4 - 14s - loss: 0.4259 - accuracy: 0.8645 - val_loss: 8.8946 - val_accuracy: 0.3939
# Epoch 17/100
# 4/4 - 14s - loss: 0.3449 - accuracy: 0.8884 - val_loss: 12.3880 - val_accuracy: 0.3939
# Epoch 18/100
# 4/4 - 14s - loss: 0.4333 - accuracy: 0.8765 - val_loss: 14.2250 - val_accuracy: 0.3939
# Epoch 19/100
# 4/4 - 14s - loss: 0.4127 - accuracy: 0.8406 - val_loss: 14.7203 - val_accuracy: 0.3939
# Epoch 20/100
# 4/4 - 14s - loss: 0.2716 - accuracy: 0.9124 - val_loss: 15.5795 - val_accuracy: 0.3939
# Epoch 21/100
# 4/4 - 14s - loss: 0.3621 - accuracy: 0.8805 - val_loss: 17.3914 - val_accuracy: 0.3939
# Epoch 22/100
# 4/4 - 14s - loss: 0.2869 - accuracy: 0.9243 - val_loss: 19.3241 - val_accuracy: 0.3939
# Epoch 23/100
# 4/4 - 14s - loss: 0.3659 - accuracy: 0.8685 - val_loss: 19.1227 - val_accuracy: 0.3939
# Epoch 24/100
# 4/4 - 14s - loss: 0.2567 - accuracy: 0.9004 - val_loss: 21.5667 - val_accuracy: 0.3939
# Epoch 25/100
# 4/4 - 14s - loss: 0.4015 - accuracy: 0.8924 - val_loss: 21.4566 - val_accuracy: 0.3939
# Epoch 26/100
# 4/4 - 14s - loss: 0.4017 - accuracy: 0.8884 - val_loss: 21.2766 - val_accuracy: 0.3939
# Epoch 27/100
# 4/4 - 14s - loss: 0.4402 - accuracy: 0.8685 - val_loss: 24.4081 - val_accuracy: 0.3939
# Epoch 28/100
# 4/4 - 14s - loss: 0.3214 - accuracy: 0.8725 - val_loss: 23.7623 - val_accuracy: 0.3939
# Epoch 29/100
# 4/4 - 14s - loss: 0.3211 - accuracy: 0.8924 - val_loss: 25.0639 - val_accuracy: 0.3939
# Epoch 30/100
# 4/4 - 14s - loss: 0.2726 - accuracy: 0.8964 - val_loss: 25.6319 - val_accuracy: 0.3939
# Epoch 31/100
# 4/4 - 14s - loss: 0.3197 - accuracy: 0.8964 - val_loss: 24.0691 - val_accuracy: 0.3939
# Epoch 32/100
# 4/4 - 14s - loss: 0.2979 - accuracy: 0.9124 - val_loss: 25.3424 - val_accuracy: 0.3939
# Epoch 33/100
# 4/4 - 14s - loss: 0.3180 - accuracy: 0.8805 - val_loss: 27.1411 - val_accuracy: 0.3939
# Epoch 34/100
# 4/4 - 15s - loss: 0.3178 - accuracy: 0.9044 - val_loss: 25.3708 - val_accuracy: 0.3939
# Epoch 35/100
# 4/4 - 14s - loss: 0.5334 - accuracy: 0.8805 - val_loss: 27.2869 - val_accuracy: 0.3939
# Epoch 36/100
# 4/4 - 14s - loss: 0.4321 - accuracy: 0.9004 - val_loss: 27.9880 - val_accuracy: 0.3939
# Epoch 37/100
# 4/4 - 14s - loss: 0.3287 - accuracy: 0.8845 - val_loss: 27.7432 - val_accuracy: 0.3939
# Epoch 38/100
# 4/4 - 14s - loss: 0.3230 - accuracy: 0.8884 - val_loss: 27.8634 - val_accuracy: 0.3939
# Epoch 39/100
# 4/4 - 14s - loss: 0.3445 - accuracy: 0.8645 - val_loss: 26.7172 - val_accuracy: 0.3939
# Epoch 40/100
# 4/4 - 14s - loss: 0.3885 - accuracy: 0.8845 - val_loss: 28.1764 - val_accuracy: 0.3939
# Epoch 41/100
# 4/4 - 14s - loss: 0.3083 - accuracy: 0.8924 - val_loss: 27.9624 - val_accuracy: 0.3939
# Epoch 42/100
# 4/4 - 14s - loss: 0.3539 - accuracy: 0.8924 - val_loss: 27.9892 - val_accuracy: 0.3939
# Epoch 43/100
# 4/4 - 14s - loss: 0.5040 - accuracy: 0.8606 - val_loss: 28.1751 - val_accuracy: 0.3939
# Epoch 44/100
# 4/4 - 14s - loss: 0.3477 - accuracy: 0.8884 - val_loss: 28.1241 - val_accuracy: 0.3939
# Epoch 45/100
# 4/4 - 14s - loss: 0.3251 - accuracy: 0.8805 - val_loss: 27.9605 - val_accuracy: 0.3939
# Epoch 46/100
# 4/4 - 14s - loss: 0.3486 - accuracy: 0.8685 - val_loss: 28.2411 - val_accuracy: 0.3939
# Epoch 47/100
# 4/4 - 14s - loss: 0.4920 - accuracy: 0.8486 - val_loss: 27.1145 - val_accuracy: 0.3939
# Epoch 48/100
# 4/4 - 14s - loss: 0.3054 - accuracy: 0.8964 - val_loss: 29.7246 - val_accuracy: 0.3939
# Epoch 49/100
# 4/4 - 14s - loss: 0.3262 - accuracy: 0.8884 - val_loss: 27.8150 - val_accuracy: 0.3939
# Epoch 50/100
# 4/4 - 14s - loss: 0.2810 - accuracy: 0.8964 - val_loss: 26.7528 - val_accuracy: 0.3939
# Epoch 51/100
# 4/4 - 14s - loss: 0.4672 - accuracy: 0.8884 - val_loss: 27.9016 - val_accuracy: 0.3939
# Epoch 52/100
# 4/4 - 14s - loss: 0.3052 - accuracy: 0.8805 - val_loss: 26.7255 - val_accuracy: 0.3939
# Epoch 53/100
# 4/4 - 14s - loss: 0.3414 - accuracy: 0.8805 - val_loss: 26.5406 - val_accuracy: 0.3939
# Epoch 54/100
# 4/4 - 14s - loss: 0.3328 - accuracy: 0.9084 - val_loss: 27.5500 - val_accuracy: 0.3939
# Epoch 55/100
# 4/4 - 14s - loss: 0.3332 - accuracy: 0.8765 - val_loss: 26.3289 - val_accuracy: 0.3939
# Epoch 56/100
# 4/4 - 14s - loss: 0.3591 - accuracy: 0.8964 - val_loss: 27.3964 - val_accuracy: 0.3939
# Epoch 57/100
# 4/4 - 14s - loss: 0.4250 - accuracy: 0.8486 - val_loss: 24.2050 - val_accuracy: 0.3939
# Epoch 58/100
# 4/4 - 14s - loss: 0.4080 - accuracy: 0.8566 - val_loss: 27.2666 - val_accuracy: 0.3939
# Epoch 59/100
# 4/4 - 14s - loss: 0.3255 - accuracy: 0.8924 - val_loss: 25.9577 - val_accuracy: 0.3939
# Epoch 60/100
# 4/4 - 15s - loss: 0.2902 - accuracy: 0.8964 - val_loss: 26.4977 - val_accuracy: 0.3939
# Epoch 61/100
# 4/4 - 14s - loss: 0.3223 - accuracy: 0.9124 - val_loss: 23.3714 - val_accuracy: 0.3939
# Epoch 62/100
# 4/4 - 14s - loss: 0.3536 - accuracy: 0.8805 - val_loss: 24.9566 - val_accuracy: 0.3939
# Epoch 63/100
# 4/4 - 14s - loss: 0.4058 - accuracy: 0.8884 - val_loss: 24.6437 - val_accuracy: 0.3939
# Epoch 64/100
# 4/4 - 14s - loss: 0.5708 - accuracy: 0.8566 - val_loss: 24.8936 - val_accuracy: 0.3939
# Epoch 65/100
# 4/4 - 14s - loss: 0.3524 - accuracy: 0.8884 - val_loss: 23.6359 - val_accuracy: 0.3939
# Epoch 66/100
# 4/4 - 14s - loss: 0.3506 - accuracy: 0.8845 - val_loss: 23.2259 - val_accuracy: 0.3939
# Epoch 67/100
# 4/4 - 14s - loss: 0.3332 - accuracy: 0.8805 - val_loss: 21.4944 - val_accuracy: 0.3939
# Epoch 68/100
# 4/4 - 13s - loss: 0.2716 - accuracy: 0.9124 - val_loss: 20.4742 - val_accuracy: 0.3939
# Epoch 69/100
# 4/4 - 14s - loss: 0.2853 - accuracy: 0.9004 - val_loss: 19.8412 - val_accuracy: 0.3939
# Epoch 70/100
# 4/4 - 14s - loss: 0.4204 - accuracy: 0.8924 - val_loss: 22.7835 - val_accuracy: 0.3939
# Epoch 71/100
# 4/4 - 14s - loss: 0.3806 - accuracy: 0.8645 - val_loss: 18.9566 - val_accuracy: 0.3939
# Epoch 72/100
# 4/4 - 14s - loss: 0.2765 - accuracy: 0.8924 - val_loss: 18.4528 - val_accuracy: 0.3939
# Epoch 73/100
# 4/4 - 14s - loss: 0.3470 - accuracy: 0.8884 - val_loss: 18.0731 - val_accuracy: 0.3939
# Epoch 74/100
# 4/4 - 14s - loss: 0.3252 - accuracy: 0.8964 - val_loss: 19.4650 - val_accuracy: 0.3939
# Epoch 75/100
# 4/4 - 14s - loss: 0.3380 - accuracy: 0.8645 - val_loss: 17.9146 - val_accuracy: 0.3939
# Epoch 76/100
# 4/4 - 15s - loss: 0.3653 - accuracy: 0.8765 - val_loss: 17.0685 - val_accuracy: 0.4091
# Epoch 77/100
# 4/4 - 14s - loss: 0.3036 - accuracy: 0.8924 - val_loss: 14.0687 - val_accuracy: 0.4091
# Epoch 78/100
# 4/4 - 14s - loss: 0.3549 - accuracy: 0.8765 - val_loss: 16.4434 - val_accuracy: 0.3939
# Epoch 79/100
# 4/4 - 14s - loss: 0.3170 - accuracy: 0.8924 - val_loss: 17.0744 - val_accuracy: 0.3939
# Epoch 80/100
# 4/4 - 15s - loss: 0.3795 - accuracy: 0.8924 - val_loss: 13.1231 - val_accuracy: 0.3939
# Epoch 81/100
# 4/4 - 14s - loss: 0.3214 - accuracy: 0.8884 - val_loss: 12.7601 - val_accuracy: 0.4091
# Epoch 82/100
# 4/4 - 14s - loss: 0.4253 - accuracy: 0.8725 - val_loss: 14.2484 - val_accuracy: 0.3939
# Epoch 83/100
# 4/4 - 14s - loss: 0.3775 - accuracy: 0.9004 - val_loss: 14.4784 - val_accuracy: 0.3939
# Epoch 84/100
# 4/4 - 14s - loss: 0.3596 - accuracy: 0.8685 - val_loss: 13.4065 - val_accuracy: 0.4242
# Epoch 85/100
# 4/4 - 15s - loss: 0.4183 - accuracy: 0.8685 - val_loss: 12.9201 - val_accuracy: 0.4091
# Epoch 86/100
# 4/4 - 14s - loss: 0.3613 - accuracy: 0.8924 - val_loss: 11.9975 - val_accuracy: 0.4091
# Epoch 87/100
# 4/4 - 15s - loss: 0.3058 - accuracy: 0.9124 - val_loss: 11.3036 - val_accuracy: 0.4091
# Epoch 88/100
# 4/4 - 14s - loss: 0.3953 - accuracy: 0.8805 - val_loss: 11.4691 - val_accuracy: 0.4091
# Epoch 89/100
# 4/4 - 14s - loss: 0.4714 - accuracy: 0.8526 - val_loss: 10.1867 - val_accuracy: 0.3939
# Epoch 90/100
# 4/4 - 15s - loss: 0.2947 - accuracy: 0.9084 - val_loss: 10.1653 - val_accuracy: 0.4242
# Epoch 91/100
# 4/4 - 14s - loss: 0.4021 - accuracy: 0.8805 - val_loss: 9.2698 - val_accuracy: 0.4242
# Epoch 92/100
# 4/4 - 15s - loss: 0.3142 - accuracy: 0.8805 - val_loss: 9.2512 - val_accuracy: 0.4394
# Epoch 93/100
# 4/4 - 14s - loss: 0.4262 - accuracy: 0.8725 - val_loss: 7.4822 - val_accuracy: 0.4091
# Epoch 94/100
# 4/4 - 14s - loss: 0.3925 - accuracy: 0.8685 - val_loss: 9.4664 - val_accuracy: 0.4697
# Epoch 95/100
# 4/4 - 14s - loss: 0.2964 - accuracy: 0.9084 - val_loss: 7.6928 - val_accuracy: 0.4545
# Epoch 96/100
# 4/4 - 14s - loss: 0.3660 - accuracy: 0.8566 - val_loss: 7.1649 - val_accuracy: 0.4545
# Epoch 97/100
# 4/4 - 14s - loss: 0.2397 - accuracy: 0.9283 - val_loss: 7.7640 - val_accuracy: 0.4394
# Epoch 98/100
# 4/4 - 14s - loss: 0.2749 - accuracy: 0.9044 - val_loss: 7.9717 - val_accuracy: 0.5152
# Epoch 99/100
# 4/4 - 15s - loss: 0.3812 - accuracy: 0.8884 - val_loss: 5.4282 - val_accuracy: 0.4848
# Epoch 100/100
# 4/4 - 14s - loss: 0.4929 - accuracy: 0.8566 - val_loss: 5.1602 - val_accuracy: 0.5000
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Covid
# 1 : Normal
# 2 : Viral Pneumonia
# Batch Sizes: 120
# Epochs: 20
# Epoch 1/20
# 3/3 - 19s - loss: 3.2828 - accuracy: 0.5100 - val_loss: 2.5066 - val_accuracy: 0.3030
# Epoch 2/20
# 3/3 - 14s - loss: 3.0419 - accuracy: 0.7012 - val_loss: 5.4632 - val_accuracy: 0.3030
# Epoch 3/20
# 3/3 - 15s - loss: 2.5701 - accuracy: 0.6972 - val_loss: 8.8345 - val_accuracy: 0.3030
# Epoch 4/20
# 3/3 - 14s - loss: 2.5977 - accuracy: 0.6932 - val_loss: 4.1210 - val_accuracy: 0.3333
# Epoch 5/20
# 3/3 - 15s - loss: 1.3780 - accuracy: 0.7610 - val_loss: 2.6955 - val_accuracy: 0.4242
# Epoch 6/20
# 3/3 - 14s - loss: 1.2157 - accuracy: 0.7928 - val_loss: 5.8023 - val_accuracy: 0.3636
# Epoch 7/20
# 3/3 - 15s - loss: 1.9676 - accuracy: 0.7092 - val_loss: 4.6411 - val_accuracy: 0.3788
# Epoch 8/20
# 3/3 - 14s - loss: 1.3707 - accuracy: 0.7928 - val_loss: 3.2841 - val_accuracy: 0.4091
# Epoch 9/20
# 3/3 - 14s - loss: 0.9849 - accuracy: 0.7849 - val_loss: 2.1731 - val_accuracy: 0.4545
# Epoch 10/20
# 3/3 - 14s - loss: 0.8221 - accuracy: 0.8167 - val_loss: 1.4955 - val_accuracy: 0.5152
# Epoch 11/20
# 3/3 - 14s - loss: 0.7698 - accuracy: 0.8406 - val_loss: 1.0785 - val_accuracy: 0.5455
# Epoch 12/20
# 3/3 - 15s - loss: 0.8644 - accuracy: 0.8127 - val_loss: 1.3975 - val_accuracy: 0.4848
# Epoch 13/20
# 3/3 - 14s - loss: 0.9020 - accuracy: 0.7888 - val_loss: 1.4115 - val_accuracy: 0.4848
# Epoch 14/20
# 3/3 - 15s - loss: 0.7992 - accuracy: 0.8287 - val_loss: 1.3138 - val_accuracy: 0.5152
# Epoch 15/20
# 3/3 - 14s - loss: 1.1873 - accuracy: 0.8167 - val_loss: 1.2074 - val_accuracy: 0.5000
# Epoch 16/20
# 3/3 - 14s - loss: 0.6133 - accuracy: 0.8645 - val_loss: 1.2390 - val_accuracy: 0.5000
# Epoch 17/20
# 3/3 - 14s - loss: 0.5166 - accuracy: 0.8645 - val_loss: 1.8483 - val_accuracy: 0.5000
# Epoch 18/20
# 3/3 - 14s - loss: 0.4762 - accuracy: 0.8725 - val_loss: 1.9731 - val_accuracy: 0.5000
# Epoch 19/20
# 3/3 - 15s - loss: 0.4587 - accuracy: 0.8606 - val_loss: 2.6307 - val_accuracy: 0.4848
# Epoch 20/20
# 3/3 - 14s - loss: 0.5614 - accuracy: 0.8964 - val_loss: 3.1177 - val_accuracy: 0.4697
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Covid
# 1 : Normal
# 2 : Viral Pneumonia
# Batch Sizes: 120
# Epochs: 50
# Epoch 1/50
# 3/3 - 17s - loss: 3.5079 - accuracy: 0.6135 - val_loss: 1.9768 - val_accuracy: 0.3030
# Epoch 2/50
# 3/3 - 14s - loss: 1.6216 - accuracy: 0.7131 - val_loss: 2.9844 - val_accuracy: 0.3030
# Epoch 3/50
# 3/3 - 15s - loss: 1.2684 - accuracy: 0.7689 - val_loss: 3.5022 - val_accuracy: 0.3030
# Epoch 4/50
# 3/3 - 14s - loss: 2.0274 - accuracy: 0.7251 - val_loss: 3.5482 - val_accuracy: 0.2879
# Epoch 5/50
# 3/3 - 15s - loss: 2.1954 - accuracy: 0.7570 - val_loss: 5.6004 - val_accuracy: 0.2424
# Epoch 6/50
# 3/3 - 14s - loss: 1.6272 - accuracy: 0.7809 - val_loss: 7.7503 - val_accuracy: 0.3333
# Epoch 7/50
# 3/3 - 15s - loss: 1.7233 - accuracy: 0.7729 - val_loss: 7.3133 - val_accuracy: 0.3182
# Epoch 8/50
# 3/3 - 14s - loss: 1.2829 - accuracy: 0.8048 - val_loss: 5.8425 - val_accuracy: 0.3485
# Epoch 9/50
# 3/3 - 14s - loss: 1.2948 - accuracy: 0.7729 - val_loss: 3.4733 - val_accuracy: 0.3939
# Epoch 10/50
# 3/3 - 15s - loss: 1.3493 - accuracy: 0.7689 - val_loss: 1.9362 - val_accuracy: 0.5152
# Epoch 11/50
# 3/3 - 14s - loss: 1.1227 - accuracy: 0.8247 - val_loss: 1.9252 - val_accuracy: 0.5303
# Epoch 12/50
# 3/3 - 14s - loss: 0.9722 - accuracy: 0.8406 - val_loss: 2.2281 - val_accuracy: 0.5152
# Epoch 13/50
# 3/3 - 14s - loss: 1.0522 - accuracy: 0.8287 - val_loss: 1.8945 - val_accuracy: 0.5152
# Epoch 14/50
# 3/3 - 15s - loss: 0.9029 - accuracy: 0.8247 - val_loss: 2.0643 - val_accuracy: 0.5606
# Epoch 15/50
# 3/3 - 14s - loss: 0.9005 - accuracy: 0.8247 - val_loss: 2.9166 - val_accuracy: 0.5152
# Epoch 16/50
# 3/3 - 14s - loss: 0.8448 - accuracy: 0.8406 - val_loss: 4.0414 - val_accuracy: 0.4697
# Epoch 17/50
# 3/3 - 14s - loss: 0.6848 - accuracy: 0.8685 - val_loss: 4.7260 - val_accuracy: 0.4394
# Epoch 18/50
# 3/3 - 14s - loss: 0.6198 - accuracy: 0.8725 - val_loss: 6.2478 - val_accuracy: 0.3939
# Epoch 19/50
# 3/3 - 15s - loss: 0.5781 - accuracy: 0.8486 - val_loss: 7.1197 - val_accuracy: 0.3939
# Epoch 20/50
# 3/3 - 14s - loss: 0.6077 - accuracy: 0.8805 - val_loss: 7.8466 - val_accuracy: 0.3939
# Epoch 21/50
# 3/3 - 15s - loss: 0.5955 - accuracy: 0.8566 - val_loss: 8.1719 - val_accuracy: 0.3939
# Epoch 22/50
# 3/3 - 14s - loss: 0.3489 - accuracy: 0.8725 - val_loss: 8.2850 - val_accuracy: 0.3939
# Epoch 23/50
# 3/3 - 14s - loss: 0.4917 - accuracy: 0.8845 - val_loss: 9.3114 - val_accuracy: 0.3939
# Epoch 24/50
# 3/3 - 14s - loss: 0.3740 - accuracy: 0.8765 - val_loss: 10.6872 - val_accuracy: 0.3939
# Epoch 25/50
# 3/3 - 14s - loss: 0.4925 - accuracy: 0.8845 - val_loss: 10.9748 - val_accuracy: 0.3939
# Epoch 26/50
# 3/3 - 14s - loss: 0.4254 - accuracy: 0.8725 - val_loss: 11.2782 - val_accuracy: 0.3939
# Epoch 27/50
# 3/3 - 14s - loss: 0.3747 - accuracy: 0.8805 - val_loss: 12.2596 - val_accuracy: 0.3939
# Epoch 28/50
# 3/3 - 14s - loss: 0.5024 - accuracy: 0.8566 - val_loss: 12.5213 - val_accuracy: 0.3939
# Epoch 29/50
# 3/3 - 14s - loss: 0.4895 - accuracy: 0.8884 - val_loss: 12.3786 - val_accuracy: 0.3939
# Epoch 30/50
# 3/3 - 15s - loss: 0.5218 - accuracy: 0.8685 - val_loss: 14.2731 - val_accuracy: 0.3939
# Epoch 31/50
# 3/3 - 14s - loss: 0.4252 - accuracy: 0.8805 - val_loss: 13.7973 - val_accuracy: 0.3939
# Epoch 32/50
# 3/3 - 15s - loss: 0.3822 - accuracy: 0.8765 - val_loss: 14.4066 - val_accuracy: 0.3939
# Epoch 33/50
# 3/3 - 14s - loss: 0.3572 - accuracy: 0.8884 - val_loss: 13.5549 - val_accuracy: 0.3939
# Epoch 34/50
# 3/3 - 14s - loss: 0.5128 - accuracy: 0.8606 - val_loss: 14.7827 - val_accuracy: 0.3939
# Epoch 35/50
# 3/3 - 15s - loss: 0.3107 - accuracy: 0.8924 - val_loss: 15.4899 - val_accuracy: 0.3939
# Epoch 36/50
# 3/3 - 14s - loss: 0.2829 - accuracy: 0.9084 - val_loss: 15.5213 - val_accuracy: 0.3939
# Epoch 37/50
# 3/3 - 14s - loss: 0.5208 - accuracy: 0.8805 - val_loss: 15.2852 - val_accuracy: 0.3939
# Epoch 38/50
# 3/3 - 14s - loss: 0.3748 - accuracy: 0.8884 - val_loss: 16.5000 - val_accuracy: 0.3939
# Epoch 39/50
# 3/3 - 15s - loss: 0.4551 - accuracy: 0.8805 - val_loss: 16.5496 - val_accuracy: 0.3939
# Epoch 40/50
# 3/3 - 14s - loss: 0.3135 - accuracy: 0.8845 - val_loss: 17.7620 - val_accuracy: 0.3939
# Epoch 41/50
# 3/3 - 14s - loss: 0.5918 - accuracy: 0.8725 - val_loss: 17.5540 - val_accuracy: 0.3939
# Epoch 42/50
# 3/3 - 15s - loss: 0.4316 - accuracy: 0.8845 - val_loss: 17.3155 - val_accuracy: 0.3939
# Epoch 43/50
# 3/3 - 14s - loss: 0.6467 - accuracy: 0.8725 - val_loss: 17.6881 - val_accuracy: 0.3939
# Epoch 44/50
# 3/3 - 14s - loss: 0.4412 - accuracy: 0.9044 - val_loss: 17.6100 - val_accuracy: 0.3939
# Epoch 45/50
# 3/3 - 14s - loss: 0.5283 - accuracy: 0.8845 - val_loss: 18.4303 - val_accuracy: 0.3939
# Epoch 46/50
# 3/3 - 15s - loss: 0.4649 - accuracy: 0.8765 - val_loss: 18.7788 - val_accuracy: 0.3939
# Epoch 47/50
# 3/3 - 14s - loss: 0.5945 - accuracy: 0.8685 - val_loss: 18.1849 - val_accuracy: 0.3939
# Epoch 48/50
# 3/3 - 14s - loss: 0.3726 - accuracy: 0.8845 - val_loss: 19.8356 - val_accuracy: 0.3939
# Epoch 49/50
# 3/3 - 15s - loss: 0.2933 - accuracy: 0.8964 - val_loss: 19.2689 - val_accuracy: 0.3939
# Epoch 50/50
# 3/3 - 14s - loss: 0.4646 - accuracy: 0.8765 - val_loss: 19.8293 - val_accuracy: 0.3939
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Covid
# 1 : Normal
# 2 : Viral Pneumonia
# Batch Sizes: 120
# Epochs: 100
# Epoch 1/100
# 3/3 - 17s - loss: 4.0310 - accuracy: 0.6056 - val_loss: 2.4222 - val_accuracy: 0.3030
# Epoch 2/100
# 3/3 - 14s - loss: 2.8229 - accuracy: 0.6892 - val_loss: 5.7028 - val_accuracy: 0.3030
# Epoch 3/100
# 3/3 - 15s - loss: 1.6973 - accuracy: 0.7490 - val_loss: 5.4772 - val_accuracy: 0.3030
# Epoch 4/100
# 3/3 - 14s - loss: 1.7301 - accuracy: 0.8048 - val_loss: 4.7418 - val_accuracy: 0.3030
# Epoch 5/100
# 3/3 - 14s - loss: 2.0295 - accuracy: 0.7371 - val_loss: 3.7631 - val_accuracy: 0.3485
# Epoch 6/100
# 3/3 - 14s - loss: 1.3087 - accuracy: 0.7809 - val_loss: 3.2396 - val_accuracy: 0.3485
# Epoch 7/100
# 3/3 - 15s - loss: 0.7314 - accuracy: 0.8645 - val_loss: 1.8638 - val_accuracy: 0.4242
# Epoch 8/100
# 3/3 - 14s - loss: 1.1487 - accuracy: 0.8127 - val_loss: 1.5777 - val_accuracy: 0.4091
# Epoch 9/100
# 3/3 - 14s - loss: 1.0521 - accuracy: 0.7968 - val_loss: 2.9226 - val_accuracy: 0.3939
# Epoch 10/100
# 3/3 - 14s - loss: 1.2152 - accuracy: 0.7968 - val_loss: 4.3267 - val_accuracy: 0.3939
# Epoch 11/100
# 3/3 - 15s - loss: 0.8896 - accuracy: 0.8287 - val_loss: 5.8845 - val_accuracy: 0.3939
# Epoch 12/100
# 3/3 - 14s - loss: 1.1910 - accuracy: 0.8088 - val_loss: 7.7054 - val_accuracy: 0.3939
# Epoch 13/100
# 3/3 - 14s - loss: 1.0232 - accuracy: 0.8048 - val_loss: 9.3889 - val_accuracy: 0.3939
# Epoch 14/100
# 3/3 - 14s - loss: 1.0448 - accuracy: 0.7928 - val_loss: 9.9033 - val_accuracy: 0.3939
# Epoch 15/100
# 3/3 - 14s - loss: 0.8830 - accuracy: 0.8048 - val_loss: 10.8460 - val_accuracy: 0.3939
# Epoch 16/100
# 3/3 - 14s - loss: 0.7867 - accuracy: 0.8446 - val_loss: 11.7006 - val_accuracy: 0.3939
# Epoch 17/100
# 3/3 - 14s - loss: 0.6897 - accuracy: 0.8526 - val_loss: 13.0702 - val_accuracy: 0.3939
# Epoch 18/100
# 3/3 - 15s - loss: 0.6811 - accuracy: 0.8327 - val_loss: 13.2916 - val_accuracy: 0.3939
# Epoch 19/100
# 3/3 - 14s - loss: 0.6401 - accuracy: 0.8446 - val_loss: 14.9869 - val_accuracy: 0.3939
# Epoch 20/100
# 3/3 - 15s - loss: 0.7289 - accuracy: 0.8327 - val_loss: 15.5621 - val_accuracy: 0.3939
# Epoch 21/100
# 3/3 - 14s - loss: 0.6058 - accuracy: 0.8526 - val_loss: 16.6197 - val_accuracy: 0.3939
# Epoch 22/100
# 3/3 - 14s - loss: 0.6683 - accuracy: 0.8367 - val_loss: 17.5443 - val_accuracy: 0.3939
# Epoch 23/100
# 3/3 - 14s - loss: 0.6974 - accuracy: 0.8446 - val_loss: 18.5244 - val_accuracy: 0.3939
# Epoch 24/100
# 3/3 - 14s - loss: 0.6630 - accuracy: 0.8327 - val_loss: 19.5252 - val_accuracy: 0.3939
# Epoch 25/100
# 3/3 - 15s - loss: 0.5544 - accuracy: 0.8526 - val_loss: 20.5427 - val_accuracy: 0.3939
# Epoch 26/100
# 3/3 - 14s - loss: 0.6279 - accuracy: 0.8645 - val_loss: 20.7720 - val_accuracy: 0.3939
# Epoch 27/100
# 3/3 - 15s - loss: 0.5144 - accuracy: 0.8765 - val_loss: 21.6987 - val_accuracy: 0.3939
# Epoch 28/100
# 3/3 - 14s - loss: 0.4832 - accuracy: 0.8606 - val_loss: 21.7041 - val_accuracy: 0.3939
# Epoch 29/100
# 3/3 - 15s - loss: 0.6200 - accuracy: 0.8287 - val_loss: 21.9232 - val_accuracy: 0.3939
# Epoch 30/100
# 3/3 - 14s - loss: 0.5891 - accuracy: 0.8645 - val_loss: 23.7545 - val_accuracy: 0.3939
# Epoch 31/100
# 3/3 - 14s - loss: 0.6437 - accuracy: 0.8367 - val_loss: 23.8894 - val_accuracy: 0.3939
# Epoch 32/100
# 3/3 - 14s - loss: 0.5122 - accuracy: 0.8845 - val_loss: 24.8822 - val_accuracy: 0.3939
# Epoch 33/100
# 3/3 - 14s - loss: 0.5496 - accuracy: 0.8526 - val_loss: 24.7082 - val_accuracy: 0.3939
# Epoch 34/100
# 3/3 - 14s - loss: 0.5123 - accuracy: 0.8327 - val_loss: 25.6433 - val_accuracy: 0.3939
# Epoch 35/100
# 3/3 - 14s - loss: 0.4656 - accuracy: 0.8645 - val_loss: 25.6548 - val_accuracy: 0.3939
# Epoch 36/100
# 3/3 - 14s - loss: 0.5639 - accuracy: 0.8446 - val_loss: 26.3458 - val_accuracy: 0.3939
# Epoch 37/100
# 3/3 - 14s - loss: 0.6528 - accuracy: 0.8367 - val_loss: 26.2436 - val_accuracy: 0.3939
# Epoch 38/100
# 3/3 - 15s - loss: 0.7436 - accuracy: 0.8406 - val_loss: 27.5385 - val_accuracy: 0.3939
# Epoch 39/100
# 3/3 - 14s - loss: 0.4227 - accuracy: 0.8884 - val_loss: 26.7284 - val_accuracy: 0.3939
# Epoch 40/100
# 3/3 - 14s - loss: 0.5227 - accuracy: 0.8645 - val_loss: 27.6200 - val_accuracy: 0.3939
# Epoch 41/100
# 3/3 - 14s - loss: 0.4001 - accuracy: 0.8924 - val_loss: 28.4576 - val_accuracy: 0.3939
# Epoch 42/100
# 3/3 - 14s - loss: 0.5665 - accuracy: 0.8884 - val_loss: 27.7588 - val_accuracy: 0.3939
# Epoch 43/100
# 3/3 - 15s - loss: 0.4766 - accuracy: 0.8446 - val_loss: 28.8242 - val_accuracy: 0.3939
# Epoch 44/100
# 3/3 - 14s - loss: 0.6345 - accuracy: 0.8406 - val_loss: 29.6620 - val_accuracy: 0.3939
# Epoch 45/100
# 3/3 - 15s - loss: 0.6173 - accuracy: 0.8526 - val_loss: 29.0446 - val_accuracy: 0.3939
# Epoch 46/100
# 3/3 - 14s - loss: 0.4792 - accuracy: 0.8765 - val_loss: 29.5804 - val_accuracy: 0.3939
# Epoch 47/100
# 3/3 - 14s - loss: 0.3604 - accuracy: 0.8765 - val_loss: 29.0120 - val_accuracy: 0.3939
# Epoch 48/100
# 3/3 - 14s - loss: 0.5975 - accuracy: 0.8247 - val_loss: 28.7815 - val_accuracy: 0.3939
# Epoch 49/100
# 3/3 - 14s - loss: 0.7390 - accuracy: 0.8367 - val_loss: 30.6040 - val_accuracy: 0.3939
# Epoch 50/100
# 3/3 - 15s - loss: 0.5129 - accuracy: 0.8765 - val_loss: 29.9924 - val_accuracy: 0.3939
# Epoch 51/100
# 3/3 - 14s - loss: 0.6323 - accuracy: 0.8446 - val_loss: 29.3271 - val_accuracy: 0.3939
# Epoch 52/100
# 3/3 - 15s - loss: 0.5296 - accuracy: 0.8406 - val_loss: 28.9455 - val_accuracy: 0.3939
# Epoch 53/100
# 3/3 - 14s - loss: 0.6208 - accuracy: 0.8526 - val_loss: 30.1154 - val_accuracy: 0.3939
# Epoch 54/100
# 3/3 - 14s - loss: 0.5263 - accuracy: 0.8765 - val_loss: 29.4906 - val_accuracy: 0.3939
# Epoch 55/100
# 3/3 - 14s - loss: 0.5341 - accuracy: 0.8446 - val_loss: 30.6677 - val_accuracy: 0.3939
# Epoch 56/100
# 3/3 - 14s - loss: 0.5431 - accuracy: 0.8606 - val_loss: 31.2958 - val_accuracy: 0.3939
# Epoch 57/100
# 3/3 - 14s - loss: 0.6073 - accuracy: 0.8606 - val_loss: 31.5317 - val_accuracy: 0.3939
# Epoch 58/100
# 3/3 - 14s - loss: 0.4542 - accuracy: 0.8406 - val_loss: 30.6606 - val_accuracy: 0.3939
# Epoch 59/100
# 3/3 - 14s - loss: 0.5490 - accuracy: 0.8685 - val_loss: 31.4497 - val_accuracy: 0.3939
# Epoch 60/100
# 3/3 - 14s - loss: 0.4528 - accuracy: 0.8884 - val_loss: 29.9170 - val_accuracy: 0.3939
# Epoch 61/100
# 3/3 - 15s - loss: 0.4890 - accuracy: 0.8367 - val_loss: 30.4248 - val_accuracy: 0.3939
# Epoch 62/100
# 3/3 - 14s - loss: 0.6609 - accuracy: 0.8406 - val_loss: 31.2663 - val_accuracy: 0.3939
# Epoch 63/100
# 3/3 - 15s - loss: 0.5893 - accuracy: 0.8566 - val_loss: 30.9103 - val_accuracy: 0.3939
# Epoch 64/100
# 3/3 - 14s - loss: 0.7098 - accuracy: 0.8566 - val_loss: 32.0626 - val_accuracy: 0.3939
# Epoch 65/100
# 3/3 - 15s - loss: 0.3722 - accuracy: 0.8765 - val_loss: 30.5444 - val_accuracy: 0.3939
# Epoch 66/100
# 3/3 - 14s - loss: 0.6013 - accuracy: 0.8725 - val_loss: 30.9298 - val_accuracy: 0.3939
# Epoch 67/100
# 3/3 - 14s - loss: 0.5100 - accuracy: 0.8167 - val_loss: 30.8994 - val_accuracy: 0.3939
# Epoch 68/100
# 3/3 - 15s - loss: 0.5372 - accuracy: 0.8606 - val_loss: 30.0845 - val_accuracy: 0.3939
# Epoch 69/100
# 3/3 - 14s - loss: 0.6147 - accuracy: 0.8327 - val_loss: 30.2452 - val_accuracy: 0.3939
# Epoch 70/100
# 3/3 - 14s - loss: 0.5063 - accuracy: 0.8645 - val_loss: 29.2495 - val_accuracy: 0.3939
# Epoch 71/100
# 3/3 - 14s - loss: 0.5327 - accuracy: 0.8566 - val_loss: 30.4960 - val_accuracy: 0.3939
# Epoch 72/100
# 3/3 - 14s - loss: 0.4901 - accuracy: 0.9044 - val_loss: 30.8851 - val_accuracy: 0.3939
# Epoch 73/100
# 3/3 - 14s - loss: 0.6040 - accuracy: 0.8406 - val_loss: 29.7055 - val_accuracy: 0.3939
# Epoch 74/100
# 3/3 - 15s - loss: 0.5782 - accuracy: 0.8446 - val_loss: 30.9158 - val_accuracy: 0.3939
# Epoch 75/100
# 3/3 - 14s - loss: 0.6372 - accuracy: 0.8446 - val_loss: 30.5381 - val_accuracy: 0.3939
# Epoch 76/100
# 3/3 - 14s - loss: 0.5274 - accuracy: 0.8765 - val_loss: 29.4075 - val_accuracy: 0.3939
# Epoch 77/100
# 3/3 - 15s - loss: 0.6497 - accuracy: 0.8645 - val_loss: 28.1788 - val_accuracy: 0.3939
# Epoch 78/100
# 3/3 - 14s - loss: 0.5737 - accuracy: 0.8446 - val_loss: 28.9353 - val_accuracy: 0.3939
# Epoch 79/100
# 3/3 - 15s - loss: 0.6597 - accuracy: 0.8685 - val_loss: 29.7911 - val_accuracy: 0.3939
# Epoch 80/100
# 3/3 - 14s - loss: 0.4243 - accuracy: 0.8805 - val_loss: 28.4784 - val_accuracy: 0.3939
# Epoch 81/100
# 3/3 - 15s - loss: 0.4263 - accuracy: 0.8845 - val_loss: 28.4451 - val_accuracy: 0.3939
# Epoch 82/100
# 3/3 - 14s - loss: 0.8221 - accuracy: 0.8207 - val_loss: 26.2915 - val_accuracy: 0.3939
# Epoch 83/100
# 3/3 - 15s - loss: 0.6984 - accuracy: 0.8367 - val_loss: 28.6980 - val_accuracy: 0.3939
# Epoch 84/100
# 3/3 - 14s - loss: 0.5975 - accuracy: 0.8566 - val_loss: 28.2110 - val_accuracy: 0.3939
# Epoch 85/100
# 3/3 - 14s - loss: 0.5303 - accuracy: 0.8606 - val_loss: 26.6111 - val_accuracy: 0.3939
# Epoch 86/100
# 3/3 - 15s - loss: 0.5578 - accuracy: 0.8406 - val_loss: 25.5012 - val_accuracy: 0.3939
# Epoch 87/100
# 3/3 - 14s - loss: 0.5559 - accuracy: 0.8845 - val_loss: 27.9711 - val_accuracy: 0.3939
# Epoch 88/100
# 3/3 - 15s - loss: 0.4030 - accuracy: 0.8884 - val_loss: 28.2211 - val_accuracy: 0.3939
# Epoch 89/100
# 3/3 - 14s - loss: 0.7789 - accuracy: 0.8367 - val_loss: 25.1959 - val_accuracy: 0.3939
# Epoch 90/100
# 3/3 - 14s - loss: 0.5485 - accuracy: 0.8845 - val_loss: 26.5168 - val_accuracy: 0.3939
# Epoch 91/100
# 3/3 - 14s - loss: 0.5361 - accuracy: 0.8725 - val_loss: 24.8176 - val_accuracy: 0.3939
# Epoch 92/100
# 3/3 - 14s - loss: 0.6384 - accuracy: 0.8167 - val_loss: 25.4944 - val_accuracy: 0.3939
# Epoch 93/100
# 3/3 - 15s - loss: 0.4837 - accuracy: 0.8685 - val_loss: 24.6620 - val_accuracy: 0.3939
# Epoch 94/100
# 3/3 - 14s - loss: 0.6635 - accuracy: 0.8566 - val_loss: 24.9714 - val_accuracy: 0.3939
# Epoch 95/100
# 3/3 - 14s - loss: 0.3829 - accuracy: 0.8725 - val_loss: 24.8783 - val_accuracy: 0.3939
# Epoch 96/100
# 3/3 - 14s - loss: 0.5273 - accuracy: 0.9084 - val_loss: 24.9294 - val_accuracy: 0.3939
# Epoch 97/100
# 3/3 - 15s - loss: 0.4905 - accuracy: 0.8645 - val_loss: 23.6392 - val_accuracy: 0.3939
# Epoch 98/100
# 3/3 - 14s - loss: 0.6263 - accuracy: 0.8287 - val_loss: 24.0181 - val_accuracy: 0.3939
# Epoch 99/100
# 3/3 - 14s - loss: 0.6037 - accuracy: 0.8446 - val_loss: 23.8941 - val_accuracy: 0.3939
# Epoch 100/100
# 3/3 - 14s - loss: 0.7648 - accuracy: 0.8287 - val_loss: 21.9018 - val_accuracy: 0.3939

# %% [markdown]
# ### Resnet

# %%
batch_size = 32  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 3

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

n = 3

version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
print(model_type)
# Out:
# ResNet20v1

# %%
input_shape = x_train.shape[1:]
print(input_shape)
# Out:
# (244, 244, 3)

# %%
# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (251, 244, 244, 3)
# 251 train samples
# 66 test samples
# y_train shape: (251,)

# %%
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=3):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=3):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=adam_v2.Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'IntelImageClass_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]
# Out:
# Learning rate:  0.001
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 244, 244, 3) 0
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 244, 244, 16) 448         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 244, 244, 16) 64          conv2d_168[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 244, 244, 16) 0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 244, 244, 16) 2320        activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 244, 244, 16) 64          conv2d_169[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 244, 244, 16) 0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 244, 244, 16) 2320        activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 244, 244, 16) 64          conv2d_170[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 244, 244, 16) 0           activation_38[0][0]
#                                                                  batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 244, 244, 16) 0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 244, 244, 16) 2320        activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 244, 244, 16) 64          conv2d_171[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 244, 244, 16) 0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 244, 244, 16) 2320        activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 244, 244, 16) 64          conv2d_172[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 244, 244, 16) 0           activation_40[0][0]
#                                                                  batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 244, 244, 16) 0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 244, 244, 16) 2320        activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 244, 244, 16) 64          conv2d_173[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 244, 244, 16) 0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 244, 244, 16) 2320        activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 244, 244, 16) 64          conv2d_174[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 244, 244, 16) 0           activation_42[0][0]
#                                                                  batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 244, 244, 16) 0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 122, 122, 32) 4640        activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 122, 122, 32) 128         conv2d_175[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 122, 122, 32) 0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 122, 122, 32) 9248        activation_45[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 122, 122, 32) 544         activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 122, 122, 32) 128         conv2d_176[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 122, 122, 32) 0           conv2d_177[0][0]
#                                                                  batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 122, 122, 32) 0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 122, 122, 32) 9248        activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 122, 122, 32) 128         conv2d_178[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 122, 122, 32) 0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 122, 122, 32) 9248        activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 122, 122, 32) 128         conv2d_179[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 122, 122, 32) 0           activation_46[0][0]
#                                                                  batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 122, 122, 32) 0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 122, 122, 32) 9248        activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 122, 122, 32) 128         conv2d_180[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 122, 122, 32) 0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 122, 122, 32) 9248        activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 122, 122, 32) 128         conv2d_181[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 122, 122, 32) 0           activation_48[0][0]
#                                                                  batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 122, 122, 32) 0           add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 61, 61, 64)   18496       activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 61, 61, 64)   256         conv2d_182[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 61, 61, 64)   0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 61, 61, 64)   36928       activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 61, 61, 64)   2112        activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 61, 61, 64)   256         conv2d_183[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 61, 61, 64)   0           conv2d_184[0][0]
#                                                                  batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 61, 61, 64)   0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 61, 61, 64)   36928       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 61, 61, 64)   256         conv2d_185[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 61, 61, 64)   0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 61, 61, 64)   36928       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 61, 61, 64)   256         conv2d_186[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 61, 61, 64)   0           activation_52[0][0]
#                                                                  batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 61, 61, 64)   0           add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 61, 61, 64)   36928       activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 61, 61, 64)   256         conv2d_187[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 61, 61, 64)   0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 61, 61, 64)   36928       activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 61, 61, 64)   256         conv2d_188[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 61, 61, 64)   0           activation_54[0][0]
#                                                                  batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 61, 61, 64)   0           add_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 7, 7, 64)     0           activation_56[0][0]
# __________________________________________________________________________________________________
# flatten_38 (Flatten)            (None, 3136)         0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_74 (Dense)                (None, 3)            9411        flatten_38[0][0]
# ==================================================================================================
# Total params: 283,203
# Trainable params: 281,827
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v
50
# Learning rate:  0.001
# 8/8 [==============================] - 5s 308ms/step - loss: 0.2238 - accuracy: 0.9801 - val_loss: 1.6571 - val_accuracy: 0.6667
# Epoch 31/50
# Learning rate:  0.001
# 8/8 [==============================] - 4s 284ms/step - loss: 0.2139 - accuracy: 0.9721 - val_loss: 2.7210 - val_accuracy: 0.5455
# Epoch 32/50
# Learning rate:  0.001
# 8/8 [==============================] - 4s 315ms/step - loss: 0.2416 - accuracy: 0.9602 - val_loss: 5.8495 - val_accuracy: 0.4394
# Epoch 33/50
# Learning rate:  0.001
# 8/8 [==============================] - 4s 299ms/step - loss: 0.2423 - accuracy: 0.9721 - val_loss: 4.2218 - val_accuracy: 0.4545
# Epoch 34/50
# Learning rate:  0.001
# 8/8 [==============================] - 4s 295ms/step - loss: 0.2202 - accuracy: 0.9681 - val_loss: 3.0848 - val_accuracy: 0.4697
# Epoch 35/50
# Learning rate:  0.001
# 8/8 [==============================] - 4s 300ms/step - loss: 0.2127 - accuracy: 0.9681 - val_loss: 3.7576 - val_accuracy: 0.4545
# Epoch 36/50
# Learning rate:  0.001
# 8/8 [==============================] - 4s 293ms/step - loss: 0.1853 - accuracy: 0.9880 - val_loss: 2.3654 - val_accuracy: 0.5303
# Epoch 37/50
# Learning rate:  0.001
# 8/8 [==============================] - 4s 361ms/step - loss: 0.2010 - accuracy: 0.9721 - val_loss: 1.7211 - val_accuracy: 0.6212
# Epoch 38/50
# Learning rate:  0.001
# 8/8 [==============================] - 4s 294ms/step - loss: 0.1972 - accuracy: 0.9801 - val_loss: 1.8594 - val_accuracy: 0.6212
# Epoch 39/50
# Learning rate:  0.001
# 8/8 [==============================] - 4s 312ms/step - loss: 0.2501 - accuracy: 0.9641 - val_loss: 0.6828 - val_accuracy: 0.8485
# Epoch 40/50
# Learning rate:  0.001
# 8/8 [==============================] - 4s 305ms/step - loss: 0.1908 - accuracy: 0.9801 - val_loss: 0.5558 - val_accuracy: 0.8636
# Epoch 41/50
# Learning rate:  0.001
# 8/8 [==============================] - 4s 304ms/step - loss: 0.1866 - accuracy: 0.9920 - val_loss: 0.4426 - val_accuracy: 0.8636
# Epoch 42/50
# Learning rate:  0.001
# 8/8 [==============================] - 4s 355ms/step - loss: 0.1902 - accuracy: 0.9880 - val_loss: 0.6317 - val_accuracy: 0.8636
# Epoch 43/50
# Learning rate:  0.001
# 8/8 [==============================] - 4s 296ms/step - loss: 0.2554 - accuracy: 0.9562 - val_loss: 0.8837 - val_accuracy: 0.7879
# Epoch 44/50
# Learning rate:  0.001
# 8/8 [==============================] - 4s 380ms/step - loss: 0.2465 - accuracy: 0.9482 - val_loss: 0.4000 - val_accuracy: 0.9091
# Epoch 45/50
# Learning rate:  0.001
# 8/8 [==============================] - 3s 319ms/step - loss: 0.2928 - accuracy: 0.9363 - val_loss: 0.5017 - val_accuracy: 0.9091
# Epoch 46/50
# Learning rate:  0.001
# 8/8 [==============================] - 3s 290ms/step - loss: 0.1809 - accuracy: 0.9841 - val_loss: 0.4920 - val_accuracy: 0.9242
# Epoch 47/50
# Learning rate:  0.001
# 8/8 [==============================] - 3s 290ms/step - loss: 0.2172 - accuracy: 0.9721 - val_loss: 0.8722 - val_accuracy: 0.7879
# Epoch 48/50
# Learning rate:  0.001
# 8/8 [==============================] - 3s 298ms/step - loss: 0.2433 - accuracy: 0.9761 - val_loss: 0.6493 - val_accuracy: 0.8939
# Epoch 49/50
# Learning rate:  0.001
# 8/8 [==============================] - 3s 275ms/step - loss: 0.1842 - accuracy: 0.9880 - val_loss: 0.3857 - val_accuracy: 0.9242
# Epoch 50/50
# Learning rate:  0.001
# 8/8 [==============================] - 4s 289ms/step - loss: 0.2047 - accuracy: 0.9721 - val_loss: 1.0684 - val_accuracy: 0.8030

# %%
scores = model.evaluate(x_test, y_test, verbose=1)

print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
plot_accuracy_loss(history)
# Out:
# 3/3 [==============================] - 0s 34ms/step - loss: 1.0684 - accuracy: 0.8030
# Test loss: 1.0683754682540894
# Test accuracy: 0.8030303120613098

# %%
def display_random_image(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Predicte Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
predictions = model.predict(x_test)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

display_random_image(class_names, x_test, pred_labels)

# %%
version=2
data_augmentation=True

# %%
# Fit the model on the batches generated by datagen.flow().
model.summary()
checkpoint_path = "training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
history=model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None,