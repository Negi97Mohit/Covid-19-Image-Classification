# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import os
from glob import glob
import pandas as pd
import tensorflow as tf
import cv2 as cv
from sklearn.utils import shuffle 
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils.np_utils import to_categorical
from keras.regularizers import l2
from tensorflow.python.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.python.keras.layers import  Dropout, Conv2D, MaxPooling2D,MaxPool2D,GlobalAveragePooling2D,BatchNormalization
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.callbacks import ModelCheckpoint, LearningRateScheduler,ReduceLROnPlateau,EarlyStopping
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model,Sequential
from keras.optimizers import adam_v2
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import CategoricalCrossentropy

import warnings
warnings.filterwarnings("ignore")

# %%
train_path="../input/coviddata/train"
test_path="../input/coviddata/test"
print("Test images dataset"+str(os.listdir(train_path)))
print("Test images dataset"+str(os.listdir(test_path)))
# Out:
# Test images dataset['Normal', 'Viral Pneumonia', 'Covid']
# Test images dataset['Normal', 'Viral Pneumonia', 'Covid']

# %%
IMAGE_SIZE=[244,244]
label=['Covid','Normal','Viral Pneumonia']

# %%
folder=glob(train_path+'/*')
folder
# Out:
# ['../input/coviddata/train/Normal',
#  '../input/coviddata/train/Viral Pneumonia',
#  '../input/coviddata/train/Covid']

# %%
from tqdm import tqdm
class_names = label
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (244,244)

# %%
def load_data():
    """
        Load the data:
            - 14,034 images to train the network.
            - 3,000 images to evaluate how accurately the network learned to classify images.
    """
    
    datasets = [train_path, test_path]
    output = []
    
    # Iterate through training and test sets
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
                image = cv.imread(img_path)
                image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
                image = cv.resize(image, IMAGE_SIZE) 
                
                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(x_train, y_train), (x_test, y_test) = load_data()
x_train, y_train = shuffle(x_train,y_train, random_state=25)
n_train = y_train.shape[0]
n_test = y_test.shape[0]
# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:03<00:00, 17.86it/s]
# 100%|██████████| 70/70 [00:01<00:00, 40.34it/s]
# 100%|██████████| 111/111 [00:04<00:00, 24.31it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 26.11it/s]
# 100%|██████████| 20/20 [00:00<00:00, 59.24it/s]
# 100%|██████████| 26/26 [00:00<00:00, 73.25it/s]
# Number of training examples: 251
# Number of testing examples: 66
# Each image is of size: (244, 244)

# %%
_, train_counts = np.unique(y_train, return_counts=True)
_, test_counts = np.unique(y_test, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=label
            ).plot.bar()

plt.show()

plt.pie(train_counts,
        explode=(0, 0, 0) , 
        labels=label,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %%
def display_random_images(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

display_random_images(label,x_train,y_train)

# %%
def display_examples(class_names, images, labels):
    """
        Display 25 images from the images array with its corresponding labels
    """
    
    fig = plt.figure(figsize=(10,10))
    fig.suptitle("Some examples of images of the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()
    
display_examples(label,x_train,y_train)

# %%
data_augmentation=False
batch_sizes=[32,64,120]
epoch_num=[20,50,100]
data_aug=[True,False]

# %% [markdown]
# ### Plotting accuracy and loss

# %%
def plot_accuracy_loss(history):
    """
        Plot the accuracy and the loss during the training of the nn.
    """
    fig = plt.figure(figsize=(20,20))

    # Plot accuracy
    plt.subplot(221)
    plt.plot(history.history['accuracy'],'bo--', label = "acc")
    plt.plot(history.history['val_accuracy'], 'ro--', label = "val_acc")
    plt.title("train_acc vs val_acc")
    plt.ylabel("accuracy")
    plt.xlabel("epochs")
    plt.legend()

    # Plot loss function
    plt.subplot(222)
    plt.plot(history.history['loss'],'bo--', label = "loss")
    plt.plot(history.history['val_loss'], 'ro--', label = "val_loss")
    plt.title("train_loss vs val_loss")
    plt.ylabel("loss")
    plt.xlabel("epochs")

    plt.legend()
    plt.show()

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (251, 244, 244, 3)
# (66, 244, 244, 3)
# (251,)
# (66,)

# %% [markdown]
# #### Data Augmentation

# %%
def data_augmen(batch_size,epochs,data_augmentation):
    if data_augmentation==False:
        print('No data augmentation.')
#         model.fit(x_train, y_train,
#                   batch_size=batch_size,
#                   epochs=epochs,
#                   validation_data=(x_test, y_test),
#                   shuffle=True,
#                   callbacks=callbacks)
    else:
        print('Using real-time data augmentation.')
        # This will do preprocessing and realtime data augmentation:
        datagen = ImageDataGenerator(
            # set input mean to 0 over the dataset
            featurewise_center=False,
            # set each sample mean to 0
            samplewise_center=False,
            # divide inputs by std of dataset
            featurewise_std_normalization=False,
            # divide each input by its std
            samplewise_std_normalization=False,
            # apply ZCA whitening
            zca_whitening=False,
            # epsilon for ZCA whitening
            zca_epsilon=1e-06,
            # randomly rotate images in the range (deg 0 to 180)
            rotation_range=0,
            # randomly shift images horizontally
            width_shift_range=0.1,
            # randomly shift images vertically
            height_shift_range=0.1,
            # set range for random shear
            shear_range=0.,
            # set range for random zoom
            zoom_range=0.,
            # set range for random channel shifts
            channel_shift_range=0.,
            # set mode for filling points outside the input boundaries
            fill_mode='nearest',
            # value used for fill_mode = "constant"
            cval=0.,
            # randomly flip images
            horizontal_flip=True,
            # randomly flip images
            vertical_flip=False,
            # set rescaling factor (applied before any other transformation)
            rescale=None,
            # set function that will be applied on each input
            preprocessing_function=None,
            # image data format, either "channels_first" or "channels_last"
            data_format=None,
            # fraction of images reserved for validation (strictly between 0 and 1)
            validation_split=0.0)

# %% [markdown]
# ### CNN- Model

# %%
#Model 1
def build_model_1():
    model=Sequential()
    model.add(Conv2D(16,(3,3),activation='relu',input_shape=(244,244,3)))
    model.add(MaxPool2D(2,2))
    model.add(Dropout(0.2))

    model.add(Conv2D(32,(3,3),activation='relu'))
    model.add(MaxPool2D(2,2))
    model.add(Dropout(0.3))

    model.add(Conv2D(64,(3,3),activation='relu'))
    model.add(MaxPool2D(2,2))
    model.add(Dropout(0.3))

    model.add(Conv2D(64,(3,3),activation='relu'))
    model.add(MaxPool2D(2,2))
    model.add(Dropout(0.3))

    model.add(Conv2D(64,(3,3),activation='relu'))
    model.add(MaxPool2D(2,2))
    model.add(Dropout(0.3))

    model.add(Flatten())
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(1,activation='sigmoid'))



    model.compile(optimizer = "rmsprop", loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
for batch_size in batch_sizes:
    for epochs in epoch_num:
        for data_au in data_aug:
            (x_train, y_train), (x_test, y_test) = load_data()
            x_train, y_train = shuffle(x_train,y_train, random_state=25)
            n_train = y_train.shape[0]
            n_test = y_test.shape[0]
            # Normalize data.
            x_train = x_train.astype('float32') / 255
            x_test = x_test.astype('float32') / 255

            model=build_model_1()
            data_augmen(batch_size,epochs,data_au)
            print("Batch_size:",batch_size)
            print("Epochs:",epochs)
            print("Data Augmentation:",data_au)
            
            model.compile(optimizer = "rmsprop", loss='binary_crossentropy', metrics=['accuracy'])

            early_stop = EarlyStopping(monitor='val_loss',patience=2)
            history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, 
                                validation_data=(x_test,y_test), verbose=2)
            plot_accuracy_loss(history)
# Out:
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:03<00:00, 19.37it/s]
# 100%|██████████| 70/70 [00:01<00:00, 44.77it/s]
# 100%|██████████| 111/111 [00:04<00:00, 27.11it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 28.67it/s]
# 100%|██████████| 20/20 [00:00<00:00, 73.22it/s]
# 100%|██████████| 26/26 [00:00<00:00, 96.02it/s]
# 2022-03-24 16:00:27.431911: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-24 16:00:27.506277: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-24 16:00:27.507020: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-24 16:00:27.508311: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-24 16:00:27.509378: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-24 16:00:27.510028: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-24 16:00:27.510657: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-24 16:00:29.093296: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-24 16:00:29.094162: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-24 16:00:29.094840: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-24 16:00:29.095425: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Using real-time data augmentation.
# Batch_size: 32
# Epochs: 20
# Data Augmentation: True
# 2022-03-24 16:00:30.097532: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/20
# 2022-03-24 16:00:32.169244: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 8/8 - 8s - loss: 0.7149 - accuracy: 0.2829 - val_loss: 0.5057 - val_accuracy: 0.3030
# Epoch 2/20
# 8/8 - 0s - loss: 0.3242 - accuracy: 0.2869 - val_loss: 0.5581 - val_accuracy: 0.3030
# Epoch 3/20
# 8/8 - 0s - loss: 0.3456 - accuracy: 0.3068 - val_loss: -7.1523e-01 - val_accuracy: 0.3333
# Epoch 4/20
# 8/8 - 0s - loss: -3.6723e+00 - accuracy: 0.3665 - val_loss: -1.1162e+01 - val_accuracy: 0.3030
# Epoch 5/20
# 8/8 - 0s - loss: -3.9201e+01 - accuracy: 0.3984 - val_loss: -2.1800e+02 - val_accuracy: 0.3333
# Epoch 6/20
# 8/8 - 0s - loss: -2.4317e+02 - accuracy: 0.3785 - val_loss: -5.9982e+02 - val_accuracy: 0.6515
# Epoch 7/20
# 8/8 - 0s - loss: -2.1321e+03 - accuracy: 0.4542 - val_loss: -5.9771e+03 - val_accuracy: 0.4091
# Epoch 8/20
# 8/8 - 0s - loss: -1.1481e+04 - accuracy: 0.3745 - val_loss: -2.7349e+04 - val_accuracy: 0.5303
# Epoch 9/20
# 8/8 - 0s - loss: -5.3546e+04 - accuracy: 0.4143 - val_loss: -1.0952e+05 - val_accuracy: 0.3788
# Epoch 10/20
# 8/8 - 0s - loss: -1.3562e+05 - accuracy: 0.4024 - val_loss: -2.8590e+05 - val_accuracy: 0.3788
# Epoch 11/20
# 8/8 - 0s - loss: -4.8502e+05 - accuracy: 0.3785 - val_loss: -7.5633e+05 - val_accuracy: 0.4848
# Epoch 12/20
# 8/8 - 0s - loss: -1.1628e+06 - accuracy: 0.4582 - val_loss: -1.6452e+06 - val_accuracy: 0.3182
# Epoch 13/20
# 8/8 - 0s - loss: -1.9076e+06 - accuracy: 0.3586 - val_loss: -3.0597e+06 - val_accuracy: 0.4091
# Epoch 14/20
# 8/8 - 0s - loss: -3.5417e+06 - accuracy: 0.4382 - val_loss: -5.3233e+06 - val_accuracy: 0.3333
# Epoch 15/20
# 8/8 - 0s - loss: -5.9226e+06 - accuracy: 0.3825 - val_loss: -8.7047e+06 - val_accuracy: 0.4091
# Epoch 16/20
# 8/8 - 0s - loss: -8.6336e+06 - accuracy: 0.4343 - val_loss: -1.3298e+07 - val_accuracy: 0.3485
# Epoch 17/20
# 8/8 - 0s - loss: -1.3758e+07 - accuracy: 0.4343 - val_loss: -1.9603e+07 - val_accuracy: 0.3333
# Epoch 18/20
# 8/8 - 0s - loss: -2.3615e+07 - accuracy: 0.4143 - val_loss: -3.0535e+07 - val_accuracy: 0.3788
# Epoch 19/20
# 8/8 - 0s - loss: -3.5331e+07 - accuracy: 0.4104 - val_loss: -4.6249e+07 - val_accuracy: 0.3788
# Epoch 20/20
# 8/8 - 0s - loss: -4.4941e+07 - accuracy: 0.4183 - val_loss: -6.3939e+07 - val_accuracy: 0.3788
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:03<00:00, 18.47it/s]
# 100%|██████████| 70/70 [00:01<00:00, 54.98it/s]
# 100%|██████████| 111/111 [00:04<00:00, 27.20it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 28.43it/s]
# 100%|██████████| 20/20 [00:00<00:00, 72.93it/s]
# 100%|██████████| 26/26 [00:00<00:00, 97.39it/s]
# No data augmentation.
# Batch_size: 32
# Epochs: 20
# Data Augmentation: False
# Epoch 1/20
# 8/8 - 2s - loss: 0.5949 - accuracy: 0.2829 - val_loss: 0.2620 - val_accuracy: 0.3030
# Epoch 2/20
# 8/8 - 0s - loss: 0.5227 - accuracy: 0.3307 - val_loss: 0.4761 - val_accuracy: 0.3030
# Epoch 3/20
# 8/8 - 0s - loss: 0.1315 - accuracy: 0.3068 - val_loss: 0.0615 - val_accuracy: 0.3030
# Epoch 4/20
# 8/8 - 0s - loss: -2.2268e+00 - accuracy: 0.3187 - val_loss: -1.0280e+01 - val_accuracy: 0.3182
# Epoch 5/20
# 8/8 - 0s - loss: -1.1976e+02 - accuracy: 0.3984 - val_loss: -5.2350e+02 - val_accuracy: 0.3182
# Epoch 6/20
# 8/8 - 0s - loss: -2.1173e+03 - accuracy: 0.3665 - val_loss: -4.9692e+03 - val_accuracy: 0.6364
# Epoch 7/20
# 8/8 - 0s - loss: -1.6186e+04 - accuracy: 0.4143 - val_loss: -3.1678e+04 - val_accuracy: 0.3182
# Epoch 8/20
# 8/8 - 0s - loss: -5.1225e+04 - accuracy: 0.3785 - val_loss: -1.0906e+05 - val_accuracy: 0.3182
# Epoch 9/20
# 8/8 - 0s - loss: -1.0946e+05 - accuracy: 0.3825 - val_loss: -2.3618e+05 - val_accuracy: 0.3333
# Epoch 10/20
# 8/8 - 0s - loss: -3.1983e+05 - accuracy: 0.4024 - val_loss: -5.8844e+05 - val_accuracy: 0.3788
# Epoch 11/20
# 8/8 - 0s - loss: -7.4559e+05 - accuracy: 0.4462 - val_loss: -1.2490e+06 - val_accuracy: 0.3182
# Epoch 12/20
# 8/8 - 0s - loss: -1.9290e+06 - accuracy: 0.3865 - val_loss: -2.8074e+06 - val_accuracy: 0.4091
# Epoch 13/20
# 8/8 - 0s - loss: -3.3398e+06 - accuracy: 0.3984 - val_loss: -5.0232e+06 - val_accuracy: 0.4545
# Epoch 14/20
# 8/8 - 0s - loss: -5.8000e+06 - accuracy: 0.4303 - val_loss: -8.5639e+06 - val_accuracy: 0.3788
# Epoch 15/20
# 8/8 - 0s - loss: -1.1269e+07 - accuracy: 0.4343 - val_loss: -1.4167e+07 - val_accuracy: 0.3333
# Epoch 16/20
# 8/8 - 0s - loss: -1.4258e+07 - accuracy: 0.4064 - val_loss: -2.1598e+07 - val_accuracy: 0.3788
# Epoch 17/20
# 8/8 - 0s - loss: -2.2635e+07 - accuracy: 0.4263 - val_loss: -3.3100e+07 - val_accuracy: 0.3485
# Epoch 18/20
# 8/8 - 0s - loss: -3.8446e+07 - accuracy: 0.3984 - val_loss: -5.0161e+07 - val_accuracy: 0.4091
# Epoch 19/20
# 8/8 - 0s - loss: -5.0500e+07 - accuracy: 0.4223 - val_loss: -7.2682e+07 - val_accuracy: 0.4091
# Epoch 20/20
# 8/8 - 0s - loss: -7.5073e+07 - accuracy: 0.4462 - val_loss: -1.0208e+08 - val_accuracy: 0.3788
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:03<00:00, 19.84it/s]
# 100%|██████████| 70/70 [00:01<00:00, 54.74it/s]
# 100%|██████████| 111/111 [00:04<00:00, 25.65it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 29.28it/s]
# 100%|██████████| 20/20 [00:00<00:00, 74.40it/s]
# 100%|██████████| 26/26 [00:00<00:00, 95.83it/s]
# Using real-time data augmentation.
# Batch_size: 32
# Epochs: 50
# Data Augmentation: True
# Epoch 1/50
# 8/8 - 1s - loss: 0.7155 - accuracy: 0.2948 - val_loss: 0.5507 - val_accuracy: 0.3030
# Epoch 2/50
# 8/8 - 0s - loss: -9.6015e-03 - accuracy: 0.2829 - val_loss: -3.8297e-01 - val_accuracy: 0.3030
# Epoch 3/50
# 8/8 - 0s - loss: -4.4472e-01 - accuracy: 0.3466 - val_loss: -3.2190e+00 - val_accuracy: 0.3182
# Epoch 4/50
# 8/8 - 0s - loss: -7.1539e+00 - accuracy: 0.3825 - val_loss: -3.6090e+01 - val_accuracy: 0.3182
# Epoch 5/50
# 8/8 - 0s - loss: -1.6890e+02 - accuracy: 0.3745 - val_loss: -5.3289e+02 - val_accuracy: 0.3182
# Epoch 6/50
# 8/8 - 0s - loss: -1.3000e+03 - accuracy: 0.3825 - val_loss: -3.4874e+03 - val_accuracy: 0.3182
# Epoch 7/50
# 8/8 - 0s - loss: -1.3557e+04 - accuracy: 0.3785 - val_loss: -3.0206e+04 - val_accuracy: 0.3182
# Epoch 8/50
# 8/8 - 0s - loss: -6.2060e+04 - accuracy: 0.3705 - val_loss: -1.2373e+05 - val_accuracy: 0.3788
# Epoch 9/50
# 8/8 - 0s - loss: -1.4575e+05 - accuracy: 0.4024 - val_loss: -2.9988e+05 - val_accuracy: 0.4091
# Epoch 10/50
# 8/8 - 0s - loss: -4.3150e+05 - accuracy: 0.3944 - val_loss: -7.0714e+05 - val_accuracy: 0.4545
# Epoch 11/50
# 8/8 - 0s - loss: -9.2205e+05 - accuracy: 0.4223 - val_loss: -1.5813e+06 - val_accuracy: 0.3485
# Epoch 12/50
# 8/8 - 0s - loss: -2.1126e+06 - accuracy: 0.3825 - val_loss: -3.2619e+06 - val_accuracy: 0.4091
# Epoch 13/50
# 8/8 - 0s - loss: -3.6377e+06 - accuracy: 0.3904 - val_loss: -5.9524e+06 - val_accuracy: 0.4091
# Epoch 14/50
# 8/8 - 0s - loss: -7.6114e+06 - accuracy: 0.3904 - val_loss: -1.0654e+07 - val_accuracy: 0.3788
# Epoch 15/50
# 8/8 - 0s - loss: -1.4020e+07 - accuracy: 0.4542 - val_loss: -1.7066e+07 - val_accuracy: 0.3182
# Epoch 16/50
# 8/8 - 0s - loss: -1.9051e+07 - accuracy: 0.3705 - val_loss: -2.7797e+07 - val_accuracy: 0.3485
# Epoch 17/50
# 8/8 - 0s - loss: -3.0228e+07 - accuracy: 0.4024 - val_loss: -4.2134e+07 - val_accuracy: 0.3788
# Epoch 18/50
# 8/8 - 0s - loss: -4.7384e+07 - accuracy: 0.3785 - val_loss: -6.1898e+07 - val_accuracy: 0.4091
# Epoch 19/50
# 8/8 - 0s - loss: -6.9258e+07 - accuracy: 0.4303 - val_loss: -9.1610e+07 - val_accuracy: 0.3788
# Epoch 20/50
# 8/8 - 0s - loss: -1.0214e+08 - accuracy: 0.4263 - val_loss: -1.2791e+08 - val_accuracy: 0.3333
# Epoch 21/50
# 8/8 - 0s - loss: -1.4709e+08 - accuracy: 0.3944 - val_loss: -1.7899e+08 - val_accuracy: 0.3788
# Epoch 22/50
# 8/8 - 0s - loss: -1.7337e+08 - accuracy: 0.3705 - val_loss: -2.2106e+08 - val_accuracy: 0.4545
# Epoch 23/50
# 8/8 - 0s - loss: -2.4394e+08 - accuracy: 0.4303 - val_loss: -3.0100e+08 - val_accuracy: 0.3788
# Epoch 24/50
# 8/8 - 0s - loss: -2.8534e+08 - accuracy: 0.4223 - val_loss: -3.9058e+08 - val_accuracy: 0.3788
# Epoch 25/50
# 8/8 - 0s - loss: -4.3427e+08 - accuracy: 0.3984 - val_loss: -5.1344e+08 - val_accuracy: 0.4091
# Epoch 26/50
# 8/8 - 0s - loss: -5.4857e+08 - accuracy: 0.4223 - val_loss: -6.6986e+08 - val_accuracy: 0.3788
# Epoch 27/50
# 8/8 - 0s - loss: -6.9924e+08 - accuracy: 0.4024 - val_loss: -8.5187e+08 - val_accuracy: 0.3788
# Epoch 28/50
# 8/8 - 0s - loss: -8.2290e+08 - accuracy: 0.4303 - val_loss: -1.0627e+09 - val_accuracy: 0.3788
# Epoch 29/50
# 8/8 - 0s - loss: -1.0732e+09 - accuracy: 0.4223 - val_loss: -1.3324e+09 - val_accuracy: 0.3788
# Epoch 30/50
# 8/8 - 0s - loss: -1.2938e+09 - accuracy: 0.4223 - val_loss: -1.6363e+09 - val_accuracy: 0.3788
# Epoch 31/50
# 8/8 - 0s - loss: -1.6059e+09 - accuracy: 0.4462 - val_loss: -2.0130e+09 - val_accuracy: 0.3788
# Epoch 32/50
# 8/8 - 0s - loss: -2.1640e+09 - accuracy: 0.4104 - val_loss: -2.4820e+09 - val_accuracy: 0.3788
# Epoch 33/50
# 8/8 - 0s - loss: -2.6499e+09 - accuracy: 0.4263 - val_loss: -3.0510e+09 - val_accuracy: 0.3788
# Epoch 34/50
# 8/8 - 0s - loss: -2.8371e+09 - accuracy: 0.4064 - val_loss: -3.5704e+09 - val_accuracy: 0.3788
# Epoch 35/50
# 8/8 - 0s - loss: -3.7010e+09 - accuracy: 0.3984 - val_loss: -4.1866e+09 - val_accuracy: 0.3788
# Epoch 36/50
# 8/8 - 0s - loss: -4.1163e+09 - accuracy: 0.4143 - val_loss: -4.9361e+09 - val_accuracy: 0.3788
# Epoch 37/50
# 8/8 - 0s - loss: -4.9800e+09 - accuracy: 0.3865 - val_loss: -5.8527e+09 - val_accuracy: 0.4091
# Epoch 38/50
# 8/8 - 0s - loss: -5.7540e+09 - accuracy: 0.4382 - val_loss: -6.8855e+09 - val_accuracy: 0.3788
# Epoch 39/50
# 8/8 - 0s - loss: -6.6633e+09 - accuracy: 0.3745 - val_loss: -7.9889e+09 - val_accuracy: 0.4091
# Epoch 40/50
# 8/8 - 0s - loss: -7.3166e+09 - accuracy: 0.4303 - val_loss: -9.2457e+09 - val_accuracy: 0.4091
# Epoch 41/50
# 8/8 - 0s - loss: -8.5930e+09 - accuracy: 0.4422 - val_loss: -1.0860e+10 - val_accuracy: 0.3788
# Epoch 42/50
# 8/8 - 0s - loss: -1.1174e+10 - accuracy: 0.4263 - val_loss: -1.2759e+10 - val_accuracy: 0.3788
# Epoch 43/50
# 8/8 - 0s - loss: -1.2109e+10 - accuracy: 0.4382 - val_loss: -1.4850e+10 - val_accuracy: 0.3788
# Epoch 44/50
# 8/8 - 0s - loss: -1.3347e+10 - accuracy: 0.3944 - val_loss: -1.7052e+10 - val_accuracy: 0.3788
# Epoch 45/50
# 8/8 - 0s - loss: -1.7072e+10 - accuracy: 0.4104 - val_loss: -1.9710e+10 - val_accuracy: 0.4091
# Epoch 46/50
# 8/8 - 0s - loss: -1.8683e+10 - accuracy: 0.4263 - val_loss: -2.2570e+10 - val_accuracy: 0.4091
# Epoch 47/50
# 8/8 - 0s - loss: -2.1228e+10 - accuracy: 0.4343 - val_loss: -2.5824e+10 - val_accuracy: 0.4091
# Epoch 48/50
# 8/8 - 0s - loss: -2.3317e+10 - accuracy: 0.4382 - val_loss: -2.9389e+10 - val_accuracy: 0.4091
# Epoch 49/50
# 8/8 - 0s - loss: -2.8416e+10 - accuracy: 0.4462 - val_loss: -3.3155e+10 - val_accuracy: 0.3788
# Epoch 50/50
# 8/8 - 0s - loss: -3.1279e+10 - accuracy: 0.3904 - val_loss: -3.7376e+10 - val_accuracy: 0.4091
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:04<00:00, 16.75it/s]
# 100%|██████████| 70/70 [00:01<00:00, 45.50it/s]
# 100%|██████████| 111/111 [00:04<00:00, 27.16it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 27.93it/s]
# 100%|██████████| 20/20 [00:00<00:00, 74.45it/s]
# 100%|██████████| 26/26 [00:00<00:00, 97.43it/s]
# No data augmentation.
# Batch_size: 32
# Epochs: 50
# Data Augmentation: False
# Epoch 1/50
# 8/8 - 2s - loss: 0.4308 - accuracy: 0.2709 - val_loss: 0.4474 - val_accuracy: 0.3030
# Epoch 2/50
# 8/8 - 0s - loss: 0.4951 - accuracy: 0.2988 - val_loss: 0.3748 - val_accuracy: 0.3030
# Epoch 3/50
# 8/8 - 0s - loss: 0.1098 - accuracy: 0.3147 - val_loss: 0.1135 - val_accuracy: 0.3182
# Epoch 4/50
# 8/8 - 0s - loss: -8.5935e-01 - accuracy: 0.3825 - val_loss: -3.1396e+00 - val_accuracy: 0.4242
# Epoch 5/50
# 8/8 - 0s - loss: -3.5786e+01 - accuracy: 0.3745 - val_loss: -1.3555e+02 - val_accuracy: 0.3182
# Epoch 6/50
# 8/8 - 0s - loss: -3.6382e+02 - accuracy: 0.3745 - val_loss: -7.2402e+02 - val_accuracy: 0.6667
# Epoch 7/50
# 8/8 - 0s - loss: -3.0520e+03 - accuracy: 0.4382 - val_loss: -8.8739e+03 - val_accuracy: 0.3182
# Epoch 8/50
# 8/8 - 0s - loss: -1.7605e+04 - accuracy: 0.3785 - val_loss: -4.3505e+04 - val_accuracy: 0.4091
# Epoch 9/50
# 8/8 - 0s - loss: -8.3296e+04 - accuracy: 0.4343 - val_loss: -1.3165e+05 - val_accuracy: 0.3182
# Epoch 10/50
# 8/8 - 0s - loss: -2.2035e+05 - accuracy: 0.3745 - val_loss: -3.9451e+05 - val_accuracy: 0.3333
# Epoch 11/50
# 8/8 - 0s - loss: -5.0684e+05 - accuracy: 0.3825 - val_loss: -8.4999e+05 - val_accuracy: 0.3788
# Epoch 12/50
# 8/8 - 0s - loss: -9.4679e+05 - accuracy: 0.3944 - val_loss: -1.6192e+06 - val_accuracy: 0.4242
# Epoch 13/50
# 8/8 - 0s - loss: -2.0980e+06 - accuracy: 0.4143 - val_loss: -3.1863e+06 - val_accuracy: 0.4091
# Epoch 14/50
# 8/8 - 0s - loss: -3.3628e+06 - accuracy: 0.4343 - val_loss: -5.3987e+06 - val_accuracy: 0.3333
# Epoch 15/50
# 8/8 - 0s - loss: -6.2655e+06 - accuracy: 0.4183 - val_loss: -9.5796e+06 - val_accuracy: 0.3485
# Epoch 16/50
# 8/8 - 0s - loss: -1.0253e+07 - accuracy: 0.3904 - val_loss: -1.5222e+07 - val_accuracy: 0.4091
# Epoch 17/50
# 8/8 - 0s - loss: -1.5072e+07 - accuracy: 0.3984 - val_loss: -2.2924e+07 - val_accuracy: 0.4242
# Epoch 18/50
# 8/8 - 0s - loss: -2.8512e+07 - accuracy: 0.4382 - val_loss: -3.6200e+07 - val_accuracy: 0.3788
# Epoch 19/50
# 8/8 - 0s - loss: -4.3652e+07 - accuracy: 0.4104 - val_loss: -5.4273e+07 - val_accuracy: 0.3485
# Epoch 20/50
# 8/8 - 0s - loss: -5.9306e+07 - accuracy: 0.4382 - val_loss: -7.5424e+07 - val_accuracy: 0.3333
# Epoch 21/50
# 8/8 - 0s - loss: -8.7011e+07 - accuracy: 0.3745 - val_loss: -1.0796e+08 - val_accuracy: 0.4091
# Epoch 22/50
# 8/8 - 0s - loss: -1.0744e+08 - accuracy: 0.4223 - val_loss: -1.4097e+08 - val_accuracy: 0.3788
# Epoch 23/50
# 8/8 - 0s - loss: -1.3712e+08 - accuracy: 0.4064 - val_loss: -1.8692e+08 - val_accuracy: 0.3788
# Epoch 24/50
# 8/8 - 0s - loss: -1.9308e+08 - accuracy: 0.4502 - val_loss: -2.5080e+08 - val_accuracy: 0.3485
# Epoch 25/50
# 8/8 - 0s - loss: -2.6050e+08 - accuracy: 0.4064 - val_loss: -3.3789e+08 - val_accuracy: 0.3788
# Epoch 26/50
# 8/8 - 0s - loss: -3.9222e+08 - accuracy: 0.4263 - val_loss: -4.5406e+08 - val_accuracy: 0.3788
# Epoch 27/50
# 8/8 - 0s - loss: -5.0358e+08 - accuracy: 0.4183 - val_loss: -5.8806e+08 - val_accuracy: 0.3788
# Epoch 28/50
# 8/8 - 0s - loss: -6.5838e+08 - accuracy: 0.4263 - val_loss: -7.6376e+08 - val_accuracy: 0.3788
# Epoch 29/50
# 8/8 - 0s - loss: -8.0136e+08 - accuracy: 0.3984 - val_loss: -9.5603e+08 - val_accuracy: 0.3788
# Epoch 30/50
# 8/8 - 0s - loss: -9.7482e+08 - accuracy: 0.4343 - val_loss: -1.1898e+09 - val_accuracy: 0.3788
# Epoch 31/50
# 8/8 - 0s - loss: -1.3105e+09 - accuracy: 0.4223 - val_loss: -1.4955e+09 - val_accuracy: 0.3788
# Epoch 32/50
# 8/8 - 0s - loss: -1.5045e+09 - accuracy: 0.4143 - val_loss: -1.8213e+09 - val_accuracy: 0.3788
# Epoch 33/50
# 8/8 - 0s - loss: -1.8113e+09 - accuracy: 0.4024 - val_loss: -2.2187e+09 - val_accuracy: 0.3788
# Epoch 34/50
# 8/8 - 0s - loss: -2.2434e+09 - accuracy: 0.4143 - val_loss: -2.6956e+09 - val_accuracy: 0.3788
# Epoch 35/50
# 8/8 - 0s - loss: -2.5600e+09 - accuracy: 0.4183 - val_loss: -3.1926e+09 - val_accuracy: 0.3788
# Epoch 36/50
# 8/8 - 0s - loss: -3.2593e+09 - accuracy: 0.4223 - val_loss: -3.8182e+09 - val_accuracy: 0.4091
# Epoch 37/50
# 8/8 - 0s - loss: -3.8388e+09 - accuracy: 0.4143 - val_loss: -4.5756e+09 - val_accuracy: 0.3788
# Epoch 38/50
# 8/8 - 0s - loss: -4.4078e+09 - accuracy: 0.4104 - val_loss: -5.4115e+09 - val_accuracy: 0.3788
# Epoch 39/50
# 8/8 - 0s - loss: -4.9925e+09 - accuracy: 0.4343 - val_loss: -6.3567e+09 - val_accuracy: 0.3788
# Epoch 40/50
# 8/8 - 0s - loss: -6.7242e+09 - accuracy: 0.4183 - val_loss: -7.6242e+09 - val_accuracy: 0.3788
# Epoch 41/50
# 8/8 - 0s - loss: -8.2374e+09 - accuracy: 0.4024 - val_loss: -9.0264e+09 - val_accuracy: 0.3788
# Epoch 42/50
# 8/8 - 0s - loss: -9.9480e+09 - accuracy: 0.4382 - val_loss: -1.0594e+10 - val_accuracy: 0.3485
# Epoch 43/50
# 8/8 - 0s - loss: -1.0816e+10 - accuracy: 0.3984 - val_loss: -1.2407e+10 - val_accuracy: 0.3788
# Epoch 44/50
# 8/8 - 0s - loss: -1.2141e+10 - accuracy: 0.4024 - val_loss: -1.4289e+10 - val_accuracy: 0.4091
# Epoch 45/50
# 8/8 - 0s - loss: -1.3975e+10 - accuracy: 0.4143 - val_loss: -1.6512e+10 - val_accuracy: 0.4091
# Epoch 46/50
# 8/8 - 0s - loss: -1.3809e+10 - accuracy: 0.4343 - val_loss: -1.8673e+10 - val_accuracy: 0.4091
# Epoch 47/50
# 8/8 - 0s - loss: -1.6775e+10 - accuracy: 0.4143 - val_loss: -2.1107e+10 - val_accuracy: 0.3788
# Epoch 48/50
# 8/8 - 0s - loss: -2.1477e+10 - accuracy: 0.4064 - val_loss: -2.4192e+10 - val_accuracy: 0.4091
# Epoch 49/50
# 8/8 - 0s - loss: -2.3379e+10 - accuracy: 0.4502 - val_loss: -2.7726e+10 - val_accuracy: 0.4091
# Epoch 50/50
# 8/8 - 0s - loss: -3.0306e+10 - accuracy: 0.4343 - val_loss: -3.1925e+10 - val_accuracy: 0.3788
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:03<00:00, 18.34it/s]
# 100%|██████████| 70/70 [00:01<00:00, 53.93it/s]
# 100%|██████████| 111/111 [00:04<00:00, 27.47it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 27.98it/s]
# 100%|██████████| 20/20 [00:00<00:00, 74.23it/s]
# 100%|██████████| 26/26 [00:00<00:00, 97.32it/s]
# Using real-time data augmentation.
# Batch_size: 32
# Epochs: 100
# Data Augmentation: True
# Epoch 1/100
# 8/8 - 2s - loss: 0.3152 - accuracy: 0.3347 - val_loss: -1.4708e-02 - val_accuracy: 0.3030
# Epoch 2/100
# 8/8 - 0s - loss: 1.1547 - accuracy: 0.3227 - val_loss: 0.1306 - val_accuracy: 0.3485
# Epoch 3/100
# 8/8 - 0s - loss: -5.6808e-01 - accuracy: 0.3705 - val_loss: -5.1371e-01 - val_accuracy: 0.6667
# Epoch 4/100
# 8/8 - 0s - loss: -1.6961e+01 - accuracy: 0.4462 - val_loss: -7.0015e+01 - val_accuracy: 0.3182
# Epoch 5/100
# 8/8 - 0s - loss: -2.7593e+02 - accuracy: 0.3347 - val_loss: -6.6993e+02 - val_accuracy: 0.6515
# Epoch 6/100
# 8/8 - 0s - loss: -2.5697e+03 - accuracy: 0.3984 - val_loss: -5.7658e+03 - val_accuracy: 0.6364
# Epoch 7/100
# 8/8 - 0s - loss: -1.4615e+04 - accuracy: 0.3904 - val_loss: -3.3683e+04 - val_accuracy: 0.3333
# Epoch 8/100
# 8/8 - 0s - loss: -5.5852e+04 - accuracy: 0.4024 - val_loss: -1.1615e+05 - val_accuracy: 0.4545
# Epoch 9/100
# 8/8 - 0s - loss: -2.3956e+05 - accuracy: 0.4502 - val_loss: -3.6921e+05 - val_accuracy: 0.3182
# Epoch 10/100
# 8/8 - 0s - loss: -5.4590e+05 - accuracy: 0.4223 - val_loss: -7.8324e+05 - val_accuracy: 0.3182
# Epoch 11/100
# 8/8 - 0s - loss: -1.0242e+06 - accuracy: 0.3745 - val_loss: -1.6300e+06 - val_accuracy: 0.4091
# Epoch 12/100
# 8/8 - 0s - loss: -1.9001e+06 - accuracy: 0.4303 - val_loss: -2.8290e+06 - val_accuracy: 0.3333
# Epoch 13/100
# 8/8 - 0s - loss: -3.4763e+06 - accuracy: 0.3865 - val_loss: -5.1076e+06 - val_accuracy: 0.4091
# Epoch 14/100
# 8/8 - 0s - loss: -6.1287e+06 - accuracy: 0.4343 - val_loss: -8.4188e+06 - val_accuracy: 0.3182
# Epoch 15/100
# 8/8 - 0s - loss: -1.0558e+07 - accuracy: 0.3984 - val_loss: -1.3967e+07 - val_accuracy: 0.4091
# Epoch 16/100
# 8/8 - 0s - loss: -1.2394e+07 - accuracy: 0.4143 - val_loss: -1.9949e+07 - val_accuracy: 0.4091
# Epoch 17/100
# 8/8 - 0s - loss: -2.1584e+07 - accuracy: 0.3944 - val_loss: -2.9095e+07 - val_accuracy: 0.4394
# Epoch 18/100
# 8/8 - 0s - loss: -2.8879e+07 - accuracy: 0.4542 - val_loss: -4.1444e+07 - val_accuracy: 0.3788
# Epoch 19/100
# 8/8 - 0s - loss: -3.9704e+07 - accuracy: 0.4183 - val_loss: -5.6190e+07 - val_accuracy: 0.4545
# Epoch 20/100
# 8/8 - 0s - loss: -6.4393e+07 - accuracy: 0.4462 - val_loss: -7.9013e+07 - val_accuracy: 0.3485
# Epoch 21/100
# 8/8 - 0s - loss: -8.0145e+07 - accuracy: 0.4024 - val_loss: -1.0815e+08 - val_accuracy: 0.3788
# Epoch 22/100
# 8/8 - 0s - loss: -1.2716e+08 - accuracy: 0.4064 - val_loss: -1.4980e+08 - val_accuracy: 0.3485
# Epoch 23/100
# 8/8 - 0s - loss: -1.5754e+08 - accuracy: 0.4223 - val_loss: -2.0139e+08 - val_accuracy: 0.3485
# Epoch 24/100
# 8/8 - 0s - loss: -2.1894e+08 - accuracy: 0.4143 - val_loss: -2.6794e+08 - val_accuracy: 0.3636
# Epoch 25/100
# 8/8 - 0s - loss: -2.5657e+08 - accuracy: 0.4024 - val_loss: -3.4285e+08 - val_accuracy: 0.4091
# Epoch 26/100
# 8/8 - 0s - loss: -3.1618e+08 - accuracy: 0.4542 - val_loss: -4.2677e+08 - val_accuracy: 0.3333
# Epoch 27/100
# 8/8 - 0s - loss: -4.3496e+08 - accuracy: 0.4223 - val_loss: -5.5452e+08 - val_accuracy: 0.3485
# Epoch 28/100
# 8/8 - 0s - loss: -5.8206e+08 - accuracy: 0.4223 - val_loss: -7.1309e+08 - val_accuracy: 0.3636
# Epoch 29/100
# 8/8 - 0s - loss: -6.3789e+08 - accuracy: 0.4024 - val_loss: -8.7838e+08 - val_accuracy: 0.3788
# Epoch 30/100
# 8/8 - 0s - loss: -8.5816e+08 - accuracy: 0.4263 - val_loss: -1.0958e+09 - val_accuracy: 0.3788
# Epoch 31/100
# 8/8 - 0s - loss: -1.2216e+09 - accuracy: 0.4382 - val_loss: -1.3759e+09 - val_accuracy: 0.3788
# Epoch 32/100
# 8/8 - 0s - loss: -1.4171e+09 - accuracy: 0.4263 - val_loss: -1.6605e+09 - val_accuracy: 0.4091
# Epoch 33/100
# 8/8 - 0s - loss: -1.6798e+09 - accuracy: 0.4303 - val_loss: -2.0004e+09 - val_accuracy: 0.4091
# Epoch 34/100
# 8/8 - 0s - loss: -1.8050e+09 - accuracy: 0.4303 - val_loss: -2.3811e+09 - val_accuracy: 0.4091
# Epoch 35/100
# 8/8 - 0s - loss: -2.1667e+09 - accuracy: 0.4343 - val_loss: -2.8675e+09 - val_accuracy: 0.4091
# Epoch 36/100
# 8/8 - 0s - loss: -2.6934e+09 - accuracy: 0.4143 - val_loss: -3.4367e+09 - val_accuracy: 0.4091
# Epoch 37/100
# 8/8 - 0s - loss: -2.9481e+09 - accuracy: 0.4223 - val_loss: -4.0399e+09 - val_accuracy: 0.4091
# Epoch 38/100
# 8/8 - 0s - loss: -4.0384e+09 - accuracy: 0.4143 - val_loss: -4.8346e+09 - val_accuracy: 0.4242
# Epoch 39/100
# 8/8 - 0s - loss: -4.5638e+09 - accuracy: 0.4502 - val_loss: -5.7362e+09 - val_accuracy: 0.4091
# Epoch 40/100
# 8/8 - 0s - loss: -6.0399e+09 - accuracy: 0.4422 - val_loss: -6.8384e+09 - val_accuracy: 0.3788
# Epoch 41/100
# 8/8 - 0s - loss: -6.9649e+09 - accuracy: 0.4024 - val_loss: -8.0054e+09 - val_accuracy: 0.4091
# Epoch 42/100
# 8/8 - 0s - loss: -7.6337e+09 - accuracy: 0.4104 - val_loss: -9.2785e+09 - val_accuracy: 0.4091
# Epoch 43/100
# 8/8 - 0s - loss: -9.2721e+09 - accuracy: 0.4502 - val_loss: -1.0844e+10 - val_accuracy: 0.4091
# Epoch 44/100
# 8/8 - 0s - loss: -9.0317e+09 - accuracy: 0.4382 - val_loss: -1.2255e+10 - val_accuracy: 0.3788
# Epoch 45/100
# 8/8 - 0s - loss: -1.1690e+10 - accuracy: 0.4064 - val_loss: -1.4023e+10 - val_accuracy: 0.4091
# Epoch 46/100
# 8/8 - 0s - loss: -1.2954e+10 - accuracy: 0.4343 - val_loss: -1.6052e+10 - val_accuracy: 0.4091
# Epoch 47/100
# 8/8 - 0s - loss: -1.5418e+10 - accuracy: 0.4422 - val_loss: -1.8192e+10 - val_accuracy: 0.4091
# Epoch 48/100
# 8/8 - 0s - loss: -1.6534e+10 - accuracy: 0.4462 - val_loss: -2.0517e+10 - val_accuracy: 0.3788
# Epoch 49/100
# 8/8 - 0s - loss: -1.8433e+10 - accuracy: 0.4303 - val_loss: -2.3305e+10 - val_accuracy: 0.3788
# Epoch 50/100
# 8/8 - 0s - loss: -2.3575e+10 - accuracy: 0.4263 - val_loss: -2.6921e+10 - val_accuracy: 0.4091
# Epoch 51/100
# 8/8 - 0s - loss: -2.4906e+10 - accuracy: 0.4263 - val_loss: -3.0448e+10 - val_accuracy: 0.3788
# Epoch 52/100
# 8/8 - 0s - loss: -2.8581e+10 - accuracy: 0.3944 - val_loss: -3.4191e+10 - val_accuracy: 0.4242
# Epoch 53/100
# 8/8 - 0s - loss: -2.8944e+10 - accuracy: 0.4223 - val_loss: -3.8154e+10 - val_accuracy: 0.4091
# Epoch 54/100
# 8/8 - 0s - loss: -3.4817e+10 - accuracy: 0.4502 - val_loss: -4.2904e+10 - val_accuracy: 0.3788
# Epoch 55/100
# 8/8 - 0s - loss: -4.2979e+10 - accuracy: 0.4143 - val_loss: -4.8439e+10 - val_accuracy: 0.4091
# Epoch 56/100
# 8/8 - 0s - loss: -5.1022e+10 - accuracy: 0.4622 - val_loss: -5.4209e+10 - val_accuracy: 0.3636
# Epoch 57/100
# 8/8 - 0s - loss: -5.3334e+10 - accuracy: 0.4064 - val_loss: -6.1242e+10 - val_accuracy: 0.3788
# Epoch 58/100
# 8/8 - 0s - loss: -6.0484e+10 - accuracy: 0.3984 - val_loss: -6.8227e+10 - val_accuracy: 0.3788
# Epoch 59/100
# 8/8 - 0s - loss: -6.7166e+10 - accuracy: 0.4263 - val_loss: -7.6138e+10 - val_accuracy: 0.3788
# Epoch 60/100
# 8/8 - 0s - loss: -7.5921e+10 - accuracy: 0.4143 - val_loss: -8.4862e+10 - val_accuracy: 0.4091
# Epoch 61/100
# 8/8 - 0s - loss: -7.6034e+10 - accuracy: 0.4303 - val_loss: -9.3100e+10 - val_accuracy: 0.3788
# Epoch 62/100
# 8/8 - 0s - loss: -9.0730e+10 - accuracy: 0.4263 - val_loss: -1.0305e+11 - val_accuracy: 0.4091
# Epoch 63/100
# 8/8 - 0s - loss: -1.0367e+11 - accuracy: 0.4183 - val_loss: -1.1399e+11 - val_accuracy: 0.4091
# Epoch 64/100
# 8/8 - 0s - loss: -1.0409e+11 - accuracy: 0.4462 - val_loss: -1.2574e+11 - val_accuracy: 0.3788
# Epoch 65/100
# 8/8 - 0s - loss: -1.1311e+11 - accuracy: 0.3984 - val_loss: -1.3722e+11 - val_accuracy: 0.4242
# Epoch 66/100
# 8/8 - 0s - loss: -1.1569e+11 - accuracy: 0.4422 - val_loss: -1.5075e+11 - val_accuracy: 0.4091
# Epoch 67/100
# 8/8 - 0s - loss: -1.3710e+11 - accuracy: 0.4303 - val_loss: -1.6666e+11 - val_accuracy: 0.4242
# Epoch 68/100
# 8/8 - 0s - loss: -1.7419e+11 - accuracy: 0.4701 - val_loss: -1.8613e+11 - val_accuracy: 0.3788
# Epoch 69/100
# 8/8 - 0s - loss: -1.6608e+11 - accuracy: 0.4183 - val_loss: -2.0367e+11 - val_accuracy: 0.4091
# Epoch 70/100
# 8/8 - 0s - loss: -2.0298e+11 - accuracy: 0.4183 - val_loss: -2.2295e+11 - val_accuracy: 0.4091
# Epoch 71/100
# 8/8 - 0s - loss: -2.2673e+11 - accuracy: 0.4422 - val_loss: -2.4584e+11 - val_accuracy: 0.3788
# Epoch 72/100
# 8/8 - 0s - loss: -2.4220e+11 - accuracy: 0.4223 - val_loss: -2.7014e+11 - val_accuracy: 0.3788
# Epoch 73/100
# 8/8 - 0s - loss: -2.6040e+11 - accuracy: 0.4143 - val_loss: -2.9540e+11 - val_accuracy: 0.3788
# Epoch 74/100
# 8/8 - 0s - loss: -2.6611e+11 - accuracy: 0.4223 - val_loss: -3.1939e+11 - val_accuracy: 0.3788
# Epoch 75/100
# 8/8 - 0s - loss: -2.7927e+11 - accuracy: 0.4343 - val_loss: -3.4553e+11 - val_accuracy: 0.4091
# Epoch 76/100
# 8/8 - 0s - loss: -3.3762e+11 - accuracy: 0.4462 - val_loss: -3.7692e+11 - val_accuracy: 0.3788
# Epoch 77/100
# 8/8 - 0s - loss: -3.4666e+11 - accuracy: 0.4024 - val_loss: -4.0907e+11 - val_accuracy: 0.3788
# Epoch 78/100
# 8/8 - 0s - loss: -3.6931e+11 - accuracy: 0.4263 - val_loss: -4.4336e+11 - val_accuracy: 0.4091
# Epoch 79/100
# 8/8 - 0s - loss: -4.1485e+11 - accuracy: 0.4343 - val_loss: -4.8048e+11 - val_accuracy: 0.3788
# Epoch 80/100
# 8/8 - 0s - loss: -4.4777e+11 - accuracy: 0.4343 - val_loss: -5.2075e+11 - val_accuracy: 0.4091
# Epoch 81/100
# 8/8 - 0s - loss: -4.7001e+11 - accuracy: 0.4303 - val_loss: -5.6114e+11 - val_accuracy: 0.3788
# Epoch 82/100
# 8/8 - 0s - loss: -5.3621e+11 - accuracy: 0.4382 - val_loss: -6.0646e+11 - val_accuracy: 0.3788
# Epoch 83/100
# 8/8 - 0s - loss: -6.0084e+11 - accuracy: 0.4382 - val_loss: -6.5485e+11 - val_accuracy: 0.3788
# Epoch 84/100
# 8/8 - 0s - loss: -6.3913e+11 - accuracy: 0.4024 - val_loss: -7.0967e+11 - val_accuracy: 0.3788
# Epoch 85/100
# 8/8 - 0s - loss: -6.6598e+11 - accuracy: 0.4183 - val_loss: -7.6437e+11 - val_accuracy: 0.4091
# Epoch 86/100
# 8/8 - 0s - loss: -7.3761e+11 - accuracy: 0.4382 - val_loss: -8.2444e+11 - val_accuracy: 0.3788
# Epoch 87/100
# 8/8 - 0s - loss: -8.3593e+11 - accuracy: 0.4462 - val_loss: -8.9104e+11 - val_accuracy: 0.3636
# Epoch 88/100
# 8/8 - 0s - loss: -8.2565e+11 - accuracy: 0.3984 - val_loss: -9.5648e+11 - val_accuracy: 0.3788
# Epoch 89/100
# 8/8 - 0s - loss: -9.3176e+11 - accuracy: 0.4263 - val_loss: -1.0300e+12 - val_accuracy: 0.3788
# Epoch 90/100
# 8/8 - 0s - loss: -1.0071e+12 - accuracy: 0.4183 - val_loss: -1.1129e+12 - val_accuracy: 0.3788
# Epoch 91/100
# 8/8 - 0s - loss: -1.0298e+12 - accuracy: 0.4064 - val_loss: -1.1962e+12 - val_accuracy: 0.3788
# Epoch 92/100
# 8/8 - 0s - loss: -1.2658e+12 - accuracy: 0.4303 - val_loss: -1.2889e+12 - val_accuracy: 0.3788
# Epoch 93/100
# 8/8 - 0s - loss: -1.0558e+12 - accuracy: 0.3904 - val_loss: -1.3664e+12 - val_accuracy: 0.4091
# Epoch 94/100
# 8/8 - 0s - loss: -1.3019e+12 - accuracy: 0.4064 - val_loss: -1.4647e+12 - val_accuracy: 0.4091
# Epoch 95/100
# 8/8 - 0s - loss: -1.2349e+12 - accuracy: 0.4343 - val_loss: -1.5585e+12 - val_accuracy: 0.4091
# Epoch 96/100
# 8/8 - 0s - loss: -1.3808e+12 - accuracy: 0.4462 - val_loss: -1.6664e+12 - val_accuracy: 0.4091
# Epoch 97/100
# 8/8 - 0s - loss: -1.6177e+12 - accuracy: 0.4622 - val_loss: -1.8003e+12 - val_accuracy: 0.3788
# Epoch 98/100
# 8/8 - 0s - loss: -1.6118e+12 - accuracy: 0.4143 - val_loss: -1.9241e+12 - val_accuracy: 0.4091
# Epoch 99/100
# 8/8 - 0s - loss: -1.6810e+12 - accuracy: 0.4263 - val_loss: -2.0526e+12 - val_accuracy: 0.4091
# Epoch 100/100
# 8/8 - 0s - loss: -1.9337e+12 - accuracy: 0.4143 - val_loss: -2.1972e+12 - val_accuracy: 0.3788
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:03<00:00, 19.85it/s]
# 100%|██████████| 70/70 [00:01<00:00, 52.96it/s]
# 100%|██████████| 111/111 [00:04<00:00, 24.33it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 20.88it/s]
# 100%|██████████| 20/20 [00:00<00:00, 72.88it/s]
# 100%|██████████| 26/26 [00:00<00:00, 97.28it/s]
# No data augmentation.
# Batch_size: 32
# Epochs: 100
# Data Augmentation: False
# Epoch 1/100
# 8/8 - 1s - loss: 0.4576 - accuracy: 0.2948 - val_loss: 0.6559 - val_accuracy: 0.3030
# Epoch 2/100
# 8/8 - 0s - loss: 0.1660 - accuracy: 0.2749 - val_loss: -3.0706e-01 - val_accuracy: 0.3030
# Epoch 3/100
# 8/8 - 0s - loss: -4.6155e-01 - accuracy: 0.3386 - val_loss: -5.7555e+00 - val_accuracy: 0.3788
# Epoch 4/100
# 8/8 - 0s - loss: -5.9554e+01 - accuracy: 0.3785 - val_loss: -1.5459e+02 - val_accuracy: 0.3030
# Epoch 5/100
# 8/8 - 0s - loss: -2.7292e+02 - accuracy: 0.3466 - val_loss: -9.5846e+02 - val_accuracy: 0.3182
# Epoch 6/100
# 8/8 - 0s - loss: -2.8869e+03 - accuracy: 0.3865 - val_loss: -8.5118e+03 - val_accuracy: 0.3182
# Epoch 7/100
# 8/8 - 0s - loss: -1.2920e+04 - accuracy: 0.3785 - val_loss: -3.4294e+04 - val_accuracy: 0.4091
# Epoch 8/100
# 8/8 - 0s - loss: -5.3105e+04 - accuracy: 0.3944 - val_loss: -1.2057e+05 - val_accuracy: 0.3485
# Epoch 9/100
# 8/8 - 0s - loss: -1.7444e+05 - accuracy: 0.4183 - val_loss: -3.1490e+05 - val_accuracy: 0.3182
# Epoch 10/100
# 8/8 - 0s - loss: -4.3298e+05 - accuracy: 0.3865 - val_loss: -7.1199e+05 - val_accuracy: 0.3333
# Epoch 11/100
# 8/8 - 0s - loss: -9.1000e+05 - accuracy: 0.4223 - val_loss: -1.5210e+06 - val_accuracy: 0.3788
# Epoch 12/100
# 8/8 - 0s - loss: -1.8387e+06 - accuracy: 0.4183 - val_loss: -3.0774e+06 - val_accuracy: 0.3788
# Epoch 13/100
# 8/8 - 0s - loss: -3.6859e+06 - accuracy: 0.4064 - val_loss: -5.7733e+06 - val_accuracy: 0.3788
# Epoch 14/100
# 8/8 - 0s - loss: -6.4964e+06 - accuracy: 0.3904 - val_loss: -9.3319e+06 - val_accuracy: 0.4091
# Epoch 15/100
# 8/8 - 0s - loss: -9.9179e+06 - accuracy: 0.4024 - val_loss: -1.4624e+07 - val_accuracy: 0.4242
# Epoch 16/100
# 8/8 - 0s - loss: -1.4452e+07 - accuracy: 0.4422 - val_loss: -2.2527e+07 - val_accuracy: 0.3788
# Epoch 17/100
# 8/8 - 0s - loss: -2.2376e+07 - accuracy: 0.4064 - val_loss: -3.4528e+07 - val_accuracy: 0.4091
# Epoch 18/100
# 8/8 - 0s - loss: -4.0391e+07 - accuracy: 0.3944 - val_loss: -5.2082e+07 - val_accuracy: 0.3485
# Epoch 19/100
# 8/8 - 0s - loss: -6.0375e+07 - accuracy: 0.3904 - val_loss: -7.6250e+07 - val_accuracy: 0.3788
# Epoch 20/100
# 8/8 - 0s - loss: -7.4393e+07 - accuracy: 0.4104 - val_loss: -1.0239e+08 - val_accuracy: 0.4091
# Epoch 21/100
# 8/8 - 0s - loss: -9.7600e+07 - accuracy: 0.4143 - val_loss: -1.3426e+08 - val_accuracy: 0.4091
# Epoch 22/100
# 8/8 - 0s - loss: -1.4205e+08 - accuracy: 0.4582 - val_loss: -1.7865e+08 - val_accuracy: 0.3333
# Epoch 23/100
# 8/8 - 0s - loss: -1.7928e+08 - accuracy: 0.3944 - val_loss: -2.4050e+08 - val_accuracy: 0.4091
# Epoch 24/100
# 8/8 - 0s - loss: -2.6158e+08 - accuracy: 0.4223 - val_loss: -3.2147e+08 - val_accuracy: 0.4091
# Epoch 25/100
# 8/8 - 0s - loss: -3.2131e+08 - accuracy: 0.4104 - val_loss: -4.0769e+08 - val_accuracy: 0.4091
# Epoch 26/100
# 8/8 - 0s - loss: -4.6639e+08 - accuracy: 0.4143 - val_loss: -5.3200e+08 - val_accuracy: 0.4091
# Epoch 27/100
# 8/8 - 0s - loss: -5.9199e+08 - accuracy: 0.4223 - val_loss: -6.7570e+08 - val_accuracy: 0.4091
# Epoch 28/100
# 8/8 - 0s - loss: -7.1814e+08 - accuracy: 0.4143 - val_loss: -8.4493e+08 - val_accuracy: 0.4091
# Epoch 29/100
# 8/8 - 0s - loss: -8.2849e+08 - accuracy: 0.4303 - val_loss: -1.0516e+09 - val_accuracy: 0.3788
# Epoch 30/100
# 8/8 - 0s - loss: -1.0816e+09 - accuracy: 0.4183 - val_loss: -1.3173e+09 - val_accuracy: 0.4091
# Epoch 31/100
# 8/8 - 0s - loss: -1.3426e+09 - accuracy: 0.4303 - val_loss: -1.6469e+09 - val_accuracy: 0.4091
# Epoch 32/100
# 8/8 - 0s - loss: -1.8102e+09 - accuracy: 0.4143 - val_loss: -2.0461e+09 - val_accuracy: 0.3788
# Epoch 33/100
# 8/8 - 0s - loss: -2.1709e+09 - accuracy: 0.4502 - val_loss: -2.4750e+09 - val_accuracy: 0.3485
# Epoch 34/100
# 8/8 - 0s - loss: -2.4010e+09 - accuracy: 0.3944 - val_loss: -2.9621e+09 - val_accuracy: 0.3788
# Epoch 35/100
# 8/8 - 0s - loss: -2.9769e+09 - accuracy: 0.4223 - val_loss: -3.5665e+09 - val_accuracy: 0.3788
# Epoch 36/100
# 8/8 - 0s - loss: -3.3097e+09 - accuracy: 0.4343 - val_loss: -4.2400e+09 - val_accuracy: 0.3788
# Epoch 37/100
# 8/8 - 0s - loss: -4.1117e+09 - accuracy: 0.4183 - val_loss: -5.0556e+09 - val_accuracy: 0.4091
# Epoch 38/100
# 8/8 - 0s - loss: -4.7211e+09 - accuracy: 0.4223 - val_loss: -5.9846e+09 - val_accuracy: 0.4091
# Epoch 39/100
# 8/8 - 0s - loss: -6.1663e+09 - accuracy: 0.4223 - val_loss: -7.1264e+09 - val_accuracy: 0.3788
# Epoch 40/100
# 8/8 - 0s - loss: -7.4680e+09 - accuracy: 0.4223 - val_loss: -8.4038e+09 - val_accuracy: 0.4091
# Epoch 41/100
# 8/8 - 0s - loss: -7.8947e+09 - accuracy: 0.4263 - val_loss: -9.8283e+09 - val_accuracy: 0.4091
# Epoch 42/100
# 8/8 - 0s - loss: -8.9024e+09 - accuracy: 0.4263 - val_loss: -1.1319e+10 - val_accuracy: 0.3788
# Epoch 43/100
# 8/8 - 0s - loss: -1.0587e+10 - accuracy: 0.4143 - val_loss: -1.3011e+10 - val_accuracy: 0.4091
# Epoch 44/100
# 8/8 - 0s - loss: -1.3298e+10 - accuracy: 0.4422 - val_loss: -1.5278e+10 - val_accuracy: 0.4091
# Epoch 45/100
# 8/8 - 0s - loss: -1.5360e+10 - accuracy: 0.4104 - val_loss: -1.7835e+10 - val_accuracy: 0.3788
# Epoch 46/100
# 8/8 - 0s - loss: -1.8004e+10 - accuracy: 0.4263 - val_loss: -2.0668e+10 - val_accuracy: 0.3788
# Epoch 47/100
# 8/8 - 0s - loss: -1.9883e+10 - accuracy: 0.4263 - val_loss: -2.3564e+10 - val_accuracy: 0.4091
# Epoch 48/100
# 8/8 - 0s - loss: -2.2567e+10 - accuracy: 0.4064 - val_loss: -2.6880e+10 - val_accuracy: 0.3788
# Epoch 49/100
# 8/8 - 0s - loss: -2.6526e+10 - accuracy: 0.4382 - val_loss: -3.0796e+10 - val_accuracy: 0.3788
# Epoch 50/100
# 8/8 - 0s - loss: -2.9082e+10 - accuracy: 0.4064 - val_loss: -3.4993e+10 - val_accuracy: 0.4091
# Epoch 51/100
# 8/8 - 0s - loss: -3.6149e+10 - accuracy: 0.4343 - val_loss: -4.0081e+10 - val_accuracy: 0.3788
# Epoch 52/100
# 8/8 - 0s - loss: -3.6457e+10 - accuracy: 0.4382 - val_loss: -4.4837e+10 - val_accuracy: 0.3788
# Epoch 53/100
# 8/8 - 0s - loss: -3.8458e+10 - accuracy: 0.4343 - val_loss: -4.9914e+10 - val_accuracy: 0.3788
# Epoch 54/100
# 8/8 - 0s - loss: -4.6060e+10 - accuracy: 0.4104 - val_loss: -5.5930e+10 - val_accuracy: 0.3788
# Epoch 55/100
# 8/8 - 0s - loss: -5.6171e+10 - accuracy: 0.4143 - val_loss: -6.3034e+10 - val_accuracy: 0.3788
# Epoch 56/100
# 8/8 - 0s - loss: -6.4595e+10 - accuracy: 0.4024 - val_loss: -7.1165e+10 - val_accuracy: 0.4091
# Epoch 57/100
# 8/8 - 0s - loss: -7.5698e+10 - accuracy: 0.4382 - val_loss: -8.0470e+10 - val_accuracy: 0.3788
# Epoch 58/100
# 8/8 - 0s - loss: -7.2569e+10 - accuracy: 0.3984 - val_loss: -8.9074e+10 - val_accuracy: 0.4091
# Epoch 59/100
# 8/8 - 0s - loss: -8.8479e+10 - accuracy: 0.4223 - val_loss: -9.8888e+10 - val_accuracy: 0.3788
# Epoch 60/100
# 8/8 - 0s - loss: -7.7166e+10 - accuracy: 0.4422 - val_loss: -1.0806e+11 - val_accuracy: 0.3788
# Epoch 61/100
# 8/8 - 0s - loss: -1.0843e+11 - accuracy: 0.4143 - val_loss: -1.2150e+11 - val_accuracy: 0.4091
# Epoch 62/100
# 8/8 - 0s - loss: -1.1218e+11 - accuracy: 0.4183 - val_loss: -1.3368e+11 - val_accuracy: 0.3788
# Epoch 63/100
# 8/8 - 0s - loss: -1.2852e+11 - accuracy: 0.4223 - val_loss: -1.4744e+11 - val_accuracy: 0.3788
# Epoch 64/100
# 8/8 - 0s - loss: -1.3309e+11 - accuracy: 0.3984 - val_loss: -1.6137e+11 - val_accuracy: 0.4091
# Epoch 65/100
# 8/8 - 0s - loss: -1.5018e+11 - accuracy: 0.4382 - val_loss: -1.7695e+11 - val_accuracy: 0.3788
# Epoch 66/100
# 8/8 - 0s - loss: -1.7300e+11 - accuracy: 0.4263 - val_loss: -1.9414e+11 - val_accuracy: 0.3788
# Epoch 67/100
# 8/8 - 0s - loss: -1.8768e+11 - accuracy: 0.4104 - val_loss: -2.1248e+11 - val_accuracy: 0.3788
# Epoch 68/100
# 8/8 - 0s - loss: -1.9016e+11 - accuracy: 0.4343 - val_loss: -2.3238e+11 - val_accuracy: 0.4091
# Epoch 69/100
# 8/8 - 0s - loss: -2.2701e+11 - accuracy: 0.4542 - val_loss: -2.5546e+11 - val_accuracy: 0.3788
# Epoch 70/100
# 8/8 - 0s - loss: -2.7621e+11 - accuracy: 0.4183 - val_loss: -2.8266e+11 - val_accuracy: 0.3788
# Epoch 71/100
# 8/8 - 0s - loss: -2.6147e+11 - accuracy: 0.4104 - val_loss: -3.0748e+11 - val_accuracy: 0.4091
# Epoch 72/100
# 8/8 - 0s - loss: -2.9682e+11 - accuracy: 0.4183 - val_loss: -3.3832e+11 - val_accuracy: 0.3788
# Epoch 73/100
# 8/8 - 0s - loss: -3.3584e+11 - accuracy: 0.4382 - val_loss: -3.7037e+11 - val_accuracy: 0.3788
# Epoch 74/100
# 8/8 - 0s - loss: -3.6164e+11 - accuracy: 0.4064 - val_loss: -4.0254e+11 - val_accuracy: 0.4091
# Epoch 75/100
# 8/8 - 0s - loss: -3.7766e+11 - accuracy: 0.4263 - val_loss: -4.3489e+11 - val_accuracy: 0.4091
# Epoch 76/100
# 8/8 - 0s - loss: -4.0306e+11 - accuracy: 0.4343 - val_loss: -4.6724e+11 - val_accuracy: 0.4091
# Epoch 77/100
# 8/8 - 0s - loss: -4.5198e+11 - accuracy: 0.4303 - val_loss: -5.0528e+11 - val_accuracy: 0.4091
# Epoch 78/100
# 8/8 - 0s - loss: -4.6311e+11 - accuracy: 0.4422 - val_loss: -5.4359e+11 - val_accuracy: 0.4091
# Epoch 79/100
# 8/8 - 0s - loss: -4.9592e+11 - accuracy: 0.4303 - val_loss: -5.8619e+11 - val_accuracy: 0.4091
# Epoch 80/100
# 8/8 - 0s - loss: -5.8036e+11 - accuracy: 0.4263 - val_loss: -6.3640e+11 - val_accuracy: 0.4091
# Epoch 81/100
# 8/8 - 0s - loss: -5.5704e+11 - accuracy: 0.4422 - val_loss: -6.8534e+11 - val_accuracy: 0.4091
# Epoch 82/100
# 8/8 - 0s - loss: -6.0014e+11 - accuracy: 0.3904 - val_loss: -7.3503e+11 - val_accuracy: 0.4091
# Epoch 83/100
# 8/8 - 0s - loss: -6.6474e+11 - accuracy: 0.4422 - val_loss: -7.9335e+11 - val_accuracy: 0.4091
# Epoch 84/100
# 8/8 - 0s - loss: -7.5200e+11 - accuracy: 0.4104 - val_loss: -8.6070e+11 - val_accuracy: 0.4091
# Epoch 85/100
# 8/8 - 0s - loss: -8.2813e+11 - accuracy: 0.4422 - val_loss: -9.3377e+11 - val_accuracy: 0.4091
# Epoch 86/100
# 8/8 - 0s - loss: -8.4925e+11 - accuracy: 0.4382 - val_loss: -1.0086e+12 - val_accuracy: 0.4091
# Epoch 87/100
# 8/8 - 0s - loss: -8.7797e+11 - accuracy: 0.4303 - val_loss: -1.0844e+12 - val_accuracy: 0.4091
# Epoch 88/100
# 8/8 - 0s - loss: -1.0613e+12 - accuracy: 0.4542 - val_loss: -1.1809e+12 - val_accuracy: 0.4091
# Epoch 89/100
# 8/8 - 0s - loss: -1.0659e+12 - accuracy: 0.4343 - val_loss: -1.2660e+12 - val_accuracy: 0.4091
# Epoch 90/100
# 8/8 - 0s - loss: -1.2493e+12 - accuracy: 0.4382 - val_loss: -1.3658e+12 - val_accuracy: 0.3788
# Epoch 91/100
# 8/8 - 0s - loss: -1.1637e+12 - accuracy: 0.4462 - val_loss: -1.4601e+12 - val_accuracy: 0.3788
# Epoch 92/100
# 8/8 - 0s - loss: -1.3575e+12 - accuracy: 0.4143 - val_loss: -1.5695e+12 - val_accuracy: 0.4091
# Epoch 93/100
# 8/8 - 0s - loss: -1.6859e+12 - accuracy: 0.4223 - val_loss: -1.6947e+12 - val_accuracy: 0.3788
# Epoch 94/100
# 8/8 - 0s - loss: -1.6668e+12 - accuracy: 0.4143 - val_loss: -1.8205e+12 - val_accuracy: 0.3788
# Epoch 95/100
# 8/8 - 0s - loss: -1.6385e+12 - accuracy: 0.4064 - val_loss: -1.9463e+12 - val_accuracy: 0.3788
# Epoch 96/100
# 8/8 - 0s - loss: -1.8097e+12 - accuracy: 0.4143 - val_loss: -2.0759e+12 - val_accuracy: 0.4091
# Epoch 97/100
# 8/8 - 0s - loss: -2.0299e+12 - accuracy: 0.4143 - val_loss: -2.2091e+12 - val_accuracy: 0.4091
# Epoch 98/100
# 8/8 - 0s - loss: -1.9635e+12 - accuracy: 0.4422 - val_loss: -2.3487e+12 - val_accuracy: 0.4091
# Epoch 99/100
# 8/8 - 0s - loss: -2.2731e+12 - accuracy: 0.4622 - val_loss: -2.5135e+12 - val_accuracy: 0.3788
# Epoch 100/100
# 8/8 - 0s - loss: -2.6657e+12 - accuracy: 0.4422 - val_loss: -2.6933e+12 - val_accuracy: 0.3788
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:03<00:00, 19.82it/s]
# 100%|██████████| 70/70 [00:01<00:00, 53.32it/s]
# 100%|██████████| 111/111 [00:04<00:00, 23.23it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 29.38it/s]
# 100%|██████████| 20/20 [00:00<00:00, 73.18it/s]
# 100%|██████████| 26/26 [00:00<00:00, 97.28it/s]
# Using real-time data augmentation.
# Batch_size: 64
# Epochs: 20
# Data Augmentation: True
# Epoch 1/20
# 4/4 - 2s - loss: 0.8449 - accuracy: 0.3068 - val_loss: 0.5496 - val_accuracy: 0.3030
# Epoch 2/20
# 4/4 - 0s - loss: 0.3041 - accuracy: 0.2869 - val_loss: 0.5871 - val_accuracy: 0.3182
# Epoch 3/20
# 4/4 - 0s - loss: -1.6274e-01 - accuracy: 0.3227 - val_loss: -3.0969e-01 - val_accuracy: 0.3030
# Epoch 4/20
# 4/4 - 0s - loss: 8.6077 - accuracy: 0.3307 - val_loss: -2.2117e+00 - val_accuracy: 0.6061
# Epoch 5/20
# 4/4 - 0s - loss: -5.3528e+00 - accuracy: 0.4223 - val_loss: -6.5380e+00 - val_accuracy: 0.3182
# Epoch 6/20
# 4/4 - 0s - loss: -2.3347e+01 - accuracy: 0.3705 - val_loss: -4.7403e+01 - val_accuracy: 0.4091
# Epoch 7/20
# 4/4 - 0s - loss: -2.0663e+01 - accuracy: 0.4183 - val_loss: -2.0777e+02 - val_accuracy: 0.4091
# Epoch 8/20
# 4/4 - 0s - loss: -3.2590e+02 - accuracy: 0.3865 - val_loss: -5.4528e+02 - val_accuracy: 0.6061
# Epoch 9/20
# 4/4 - 0s - loss: -1.4281e+03 - accuracy: 0.4502 - val_loss: -2.7686e+03 - val_accuracy: 0.3182
# Epoch 10/20
# 4/4 - 0s - loss: -5.6310e+03 - accuracy: 0.3745 - val_loss: -1.0803e+04 - val_accuracy: 0.3788
# Epoch 11/20
# 4/4 - 0s - loss: -1.9456e+04 - accuracy: 0.4064 - val_loss: -3.3008e+04 - val_accuracy: 0.3788
# Epoch 12/20
# 4/4 - 0s - loss: -5.0699e+04 - accuracy: 0.3825 - val_loss: -8.0453e+04 - val_accuracy: 0.3182
# Epoch 13/20
# 4/4 - 0s - loss: -9.6514e+04 - accuracy: 0.4263 - val_loss: -1.4859e+05 - val_accuracy: 0.3182
# Epoch 14/20
# 4/4 - 0s - loss: -2.0942e+05 - accuracy: 0.4024 - val_loss: -2.9646e+05 - val_accuracy: 0.3182
# Epoch 15/20
# 4/4 - 0s - loss: -3.5773e+05 - accuracy: 0.3665 - val_loss: -5.4395e+05 - val_accuracy: 0.3788
# Epoch 16/20
# 4/4 - 0s - loss: -6.8741e+05 - accuracy: 0.4143 - val_loss: -9.4134e+05 - val_accuracy: 0.3485
# Epoch 17/20
# 4/4 - 0s - loss: -1.1954e+06 - accuracy: 0.4064 - val_loss: -1.5049e+06 - val_accuracy: 0.3333
# Epoch 18/20
# 4/4 - 0s - loss: -1.6150e+06 - accuracy: 0.4382 - val_loss: -2.1216e+06 - val_accuracy: 0.3182
# Epoch 19/20
# 4/4 - 0s - loss: -2.2086e+06 - accuracy: 0.3347 - val_loss: -3.2260e+06 - val_accuracy: 0.3788
# Epoch 20/20
# 4/4 - 0s - loss: -3.5221e+06 - accuracy: 0.4382 - val_loss: -4.5143e+06 - val_accuracy: 0.3333
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:03<00:00, 20.03it/s]
# 100%|██████████| 70/70 [00:01<00:00, 54.69it/s]
# 100%|██████████| 111/111 [00:04<00:00, 25.69it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 29.23it/s]
# 100%|██████████| 20/20 [00:00<00:00, 73.47it/s]
# 100%|██████████| 26/26 [00:00<00:00, 97.47it/s]
# No data augmentation.
# Batch_size: 64
# Epochs: 20
# Data Augmentation: False
# Epoch 1/20
# 4/4 - 1s - loss: 0.4263 - accuracy: 0.3386 - val_loss: 0.5256 - val_accuracy: 0.3030
# Epoch 2/20
# 4/4 - 0s - loss: 0.1525 - accuracy: 0.2829 - val_loss: 0.5773 - val_accuracy: 0.6667
# Epoch 3/20
# 4/4 - 0s - loss: -4.4848e-01 - accuracy: 0.3546 - val_loss: -2.7848e-01 - val_accuracy: 0.6667
# Epoch 4/20
# 4/4 - 0s - loss: -1.1412e+01 - accuracy: 0.3745 - val_loss: -3.3089e+01 - val_accuracy: 0.3030
# Epoch 5/20
# 4/4 - 0s - loss: -3.9287e+01 - accuracy: 0.3904 - val_loss: -1.3607e+02 - val_accuracy: 0.3182
# Epoch 6/20
# 4/4 - 0s - loss: -3.8642e+02 - accuracy: 0.3745 - val_loss: -1.0322e+03 - val_accuracy: 0.3333
# Epoch 7/20
# 4/4 - 0s - loss: -2.6978e+03 - accuracy: 0.4024 - val_loss: -5.8747e+03 - val_accuracy: 0.4091
# Epoch 8/20
# 4/4 - 0s - loss: -1.0869e+04 - accuracy: 0.4303 - val_loss: -2.0325e+04 - val_accuracy: 0.3333
# Epoch 9/20
# 4/4 - 0s - loss: -2.0826e+04 - accuracy: 0.3825 - val_loss: -4.2095e+04 - val_accuracy: 0.3333
# Epoch 10/20
# 4/4 - 0s - loss: -6.2557e+04 - accuracy: 0.3944 - val_loss: -9.9454e+04 - val_accuracy: 0.3333
# Epoch 11/20
# 4/4 - 0s - loss: -1.2357e+05 - accuracy: 0.3904 - val_loss: -2.0093e+05 - val_accuracy: 0.3788
# Epoch 12/20
# 4/4 - 0s - loss: -2.4146e+05 - accuracy: 0.4024 - val_loss: -3.5355e+05 - val_accuracy: 0.4545
# Epoch 13/20
# 4/4 - 0s - loss: -3.7350e+05 - accuracy: 0.4422 - val_loss: -5.8566e+05 - val_accuracy: 0.3333
# Epoch 14/20
# 4/4 - 0s - loss: -6.8590e+05 - accuracy: 0.4303 - val_loss: -9.8990e+05 - val_accuracy: 0.3485
# Epoch 15/20
# 4/4 - 0s - loss: -1.0415e+06 - accuracy: 0.3984 - val_loss: -1.5477e+06 - val_accuracy: 0.3788
# Epoch 16/20
# 4/4 - 0s - loss: -1.7175e+06 - accuracy: 0.4223 - val_loss: -2.3026e+06 - val_accuracy: 0.3485
# Epoch 17/20
# 4/4 - 0s - loss: -2.5375e+06 - accuracy: 0.4024 - val_loss: -3.3744e+06 - val_accuracy: 0.4091
# Epoch 18/20
# 4/4 - 0s - loss: -3.6886e+06 - accuracy: 0.4183 - val_loss: -4.7518e+06 - val_accuracy: 0.4091
# Epoch 19/20
# 4/4 - 0s - loss: -4.9480e+06 - accuracy: 0.3904 - val_loss: -6.4312e+06 - val_accuracy: 0.4091
# Epoch 20/20
# 4/4 - 0s - loss: -6.8919e+06 - accuracy: 0.4263 - val_loss: -8.6418e+06 - val_accuracy: 0.3788
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:03<00:00, 19.28it/s]
# 100%|██████████| 70/70 [00:01<00:00, 54.21it/s]
# 100%|██████████| 111/111 [00:04<00:00, 25.67it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 29.55it/s]
# 100%|██████████| 20/20 [00:00<00:00, 73.17it/s]
# 100%|██████████| 26/26 [00:00<00:00, 95.41it/s]
# Using real-time data augmentation.
# Batch_size: 64
# Epochs: 50
# Data Augmentation: True
# Epoch 1/50
# 4/4 - 2s - loss: 0.7463 - accuracy: 0.3028 - val_loss: 0.4574 - val_accuracy: 0.3030
# Epoch 2/50
# 4/4 - 0s - loss: 0.3816 - accuracy: 0.2789 - val_loss: 0.3704 - val_accuracy: 0.3030
# Epoch 3/50
# 4/4 - 0s - loss: 0.1568 - accuracy: 0.2829 - val_loss: 0.4199 - val_accuracy: 0.3182
# Epoch 4/50
# 4/4 - 0s - loss: -1.5838e-01 - accuracy: 0.3546 - val_loss: -3.8073e-01 - val_accuracy: 0.4545
# Epoch 5/50
# 4/4 - 0s - loss: -8.9745e-01 - accuracy: 0.3546 - val_loss: -3.1612e+00 - val_accuracy: 0.3788
# Epoch 6/50
# 4/4 - 0s - loss: -3.1950e+00 - accuracy: 0.3785 - val_loss: -1.4795e+01 - val_accuracy: 0.5909
# ...
# Epoch 57/100
# 3/3 - 0s - loss: -9.9918e+07 - accuracy: 0.3506 - val_loss: -1.2498e+08 - val_accuracy: 0.3636
# Epoch 58/100
# 3/3 - 0s - loss: -1.1635e+08 - accuracy: 0.4064 - val_loss: -1.3630e+08 - val_accuracy: 0.3788
# Epoch 59/100
# 3/3 - 0s - loss: -1.3257e+08 - accuracy: 0.4064 - val_loss: -1.4998e+08 - val_accuracy: 0.4091
# Epoch 60/100
# 3/3 - 0s - loss: -1.3077e+08 - accuracy: 0.4223 - val_loss: -1.5811e+08 - val_accuracy: 0.4848
# Epoch 61/100
# 3/3 - 0s - loss: -1.5428e+08 - accuracy: 0.4781 - val_loss: -1.8465e+08 - val_accuracy: 0.3788
# Epoch 62/100
# 3/3 - 0s - loss: -1.8152e+08 - accuracy: 0.3865 - val_loss: -1.9716e+08 - val_accuracy: 0.4394
# Epoch 63/100
# 3/3 - 0s - loss: -1.8866e+08 - accuracy: 0.4781 - val_loss: -2.2617e+08 - val_accuracy: 0.3788
# Epoch 64/100
# 3/3 - 0s - loss: -2.0848e+08 - accuracy: 0.4183 - val_loss: -2.5529e+08 - val_accuracy: 0.4091
# Epoch 65/100
# 3/3 - 0s - loss: -2.3179e+08 - accuracy: 0.4104 - val_loss: -2.9045e+08 - val_accuracy: 0.4091
# Epoch 66/100
# 3/3 - 0s - loss: -2.9428e+08 - accuracy: 0.4343 - val_loss: -3.2590e+08 - val_accuracy: 0.3485
# Epoch 67/100
# 3/3 - 0s - loss: -3.1999e+08 - accuracy: 0.3944 - val_loss: -3.4914e+08 - val_accuracy: 0.4091
# Epoch 68/100
# 3/3 - 0s - loss: -3.3024e+08 - accuracy: 0.4781 - val_loss: -3.7991e+08 - val_accuracy: 0.3788
# Epoch 69/100
# 3/3 - 0s - loss: -3.4757e+08 - accuracy: 0.3825 - val_loss: -4.2052e+08 - val_accuracy: 0.3333
# Epoch 70/100
# 3/3 - 0s - loss: -3.9514e+08 - accuracy: 0.3944 - val_loss: -4.7259e+08 - val_accuracy: 0.4091
# Epoch 71/100
# 3/3 - 0s - loss: -4.4180e+08 - accuracy: 0.4343 - val_loss: -5.1976e+08 - val_accuracy: 0.3788
# Epoch 72/100
# 3/3 - 0s - loss: -5.4521e+08 - accuracy: 0.4263 - val_loss: -5.5472e+08 - val_accuracy: 0.4242
# Epoch 73/100
# 3/3 - 0s - loss: -5.2389e+08 - accuracy: 0.4741 - val_loss: -5.9450e+08 - val_accuracy: 0.4242
# Epoch 74/100
# 3/3 - 0s - loss: -5.9080e+08 - accuracy: 0.4502 - val_loss: -6.5186e+08 - val_accuracy: 0.4242
# Epoch 75/100
# 3/3 - 0s - loss: -5.9151e+08 - accuracy: 0.4303 - val_loss: -6.8824e+08 - val_accuracy: 0.4848
# Epoch 76/100
# 3/3 - 0s - loss: -7.0927e+08 - accuracy: 0.5060 - val_loss: -7.9112e+08 - val_accuracy: 0.4091
# Epoch 77/100
# 3/3 - 0s - loss: -7.2675e+08 - accuracy: 0.4462 - val_loss: -8.6088e+08 - val_accuracy: 0.4091
# Epoch 78/100
# 3/3 - 0s - loss: -8.3591e+08 - accuracy: 0.4143 - val_loss: -9.4776e+08 - val_accuracy: 0.3788
# Epoch 79/100
# 3/3 - 0s - loss: -9.0621e+08 - accuracy: 0.4104 - val_loss: -1.0126e+09 - val_accuracy: 0.4091
# Epoch 80/100
# 3/3 - 0s - loss: -9.3292e+08 - accuracy: 0.4582 - val_loss: -1.0910e+09 - val_accuracy: 0.4091
# Epoch 81/100
# 3/3 - 0s - loss: -1.0885e+09 - accuracy: 0.4462 - val_loss: -1.1935e+09 - val_accuracy: 0.3788
# Epoch 82/100
# 3/3 - 0s - loss: -1.2192e+09 - accuracy: 0.4223 - val_loss: -1.3277e+09 - val_accuracy: 0.4091
# Epoch 83/100
# 3/3 - 0s - loss: -1.2904e+09 - accuracy: 0.4462 - val_loss: -1.4450e+09 - val_accuracy: 0.3333
# Epoch 84/100
# 3/3 - 0s - loss: -1.4645e+09 - accuracy: 0.3665 - val_loss: -1.5721e+09 - val_accuracy: 0.3333
# Epoch 85/100
# 3/3 - 0s - loss: -1.3977e+09 - accuracy: 0.3586 - val_loss: -1.7382e+09 - val_accuracy: 0.3333
# Epoch 86/100
# 3/3 - 0s - loss: -1.8194e+09 - accuracy: 0.3984 - val_loss: -1.8847e+09 - val_accuracy: 0.3333
# Epoch 87/100
# 3/3 - 0s - loss: -1.9361e+09 - accuracy: 0.3825 - val_loss: -2.0435e+09 - val_accuracy: 0.3333
# Epoch 88/100
# 3/3 - 0s - loss: -1.8059e+09 - accuracy: 0.3625 - val_loss: -2.2084e+09 - val_accuracy: 0.3788
# Epoch 89/100
# 3/3 - 0s - loss: -2.0380e+09 - accuracy: 0.3825 - val_loss: -2.3567e+09 - val_accuracy: 0.3788
# Epoch 90/100
# 3/3 - 0s - loss: -2.1582e+09 - accuracy: 0.4104 - val_loss: -2.5516e+09 - val_accuracy: 0.3788
# Epoch 91/100
# 3/3 - 0s - loss: -2.1513e+09 - accuracy: 0.4183 - val_loss: -2.6567e+09 - val_accuracy: 0.4091
# Epoch 92/100
# 3/3 - 0s - loss: -2.4998e+09 - accuracy: 0.4462 - val_loss: -2.8912e+09 - val_accuracy: 0.3636
# Epoch 93/100
# 3/3 - 0s - loss: -2.7546e+09 - accuracy: 0.4104 - val_loss: -3.1093e+09 - val_accuracy: 0.3788
# Epoch 94/100
# 3/3 - 0s - loss: -2.9782e+09 - accuracy: 0.3944 - val_loss: -3.2092e+09 - val_accuracy: 0.4242
# Epoch 95/100
# 3/3 - 0s - loss: -3.0655e+09 - accuracy: 0.4701 - val_loss: -3.4691e+09 - val_accuracy: 0.4091
# Epoch 96/100
# 3/3 - 0s - loss: -3.4680e+09 - accuracy: 0.4343 - val_loss: -3.6740e+09 - val_accuracy: 0.4394
# Epoch 97/100
# 3/3 - 0s - loss: -3.2944e+09 - accuracy: 0.4343 - val_loss: -3.7914e+09 - val_accuracy: 0.4848
# Epoch 98/100
# 3/3 - 0s - loss: -3.3170e+09 - accuracy: 0.4622 - val_loss: -3.9874e+09 - val_accuracy: 0.4848
# Epoch 99/100
# 3/3 - 0s - loss: -3.8144e+09 - accuracy: 0.5060 - val_loss: -4.4296e+09 - val_accuracy: 0.4091
# Epoch 100/100
# 3/3 - 0s - loss: -4.2236e+09 - accuracy: 0.4462 - val_loss: -4.7459e+09 - val_accuracy: 0.4242
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:03<00:00, 19.64it/s]
# 100%|██████████| 70/70 [00:01<00:00, 53.91it/s]
# 100%|██████████| 111/111 [00:04<00:00, 25.66it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 27.89it/s]
# 100%|██████████| 20/20 [00:00<00:00, 73.36it/s]
# 100%|██████████| 26/26 [00:00<00:00, 93.64it/s]
# No data augmentation.
# Batch_size: 120
# Epochs: 100
# Data Augmentation: False
# Epoch 1/100
# 3/3 - 2s - loss: 0.6626 - accuracy: 0.3108 - val_loss: 0.1784 - val_accuracy: 0.3030
# Epoch 2/100
# 3/3 - 0s - loss: 0.5487 - accuracy: 0.3108 - val_loss: 0.5966 - val_accuracy: 0.3030
# Epoch 3/100
# 3/3 - 0s - loss: 0.1666 - accuracy: 0.3108 - val_loss: 0.5765 - val_accuracy: 0.4697
# Epoch 4/100
# 3/3 - 0s - loss: 0.0018 - accuracy: 0.3745 - val_loss: -2.6867e-01 - val_accuracy: 0.3030
# Epoch 5/100
# 3/3 - 0s - loss: 0.5952 - accuracy: 0.3865 - val_loss: -9.4563e-02 - val_accuracy: 0.4394
# Epoch 6/100
# 3/3 - 0s - loss: -1.2901e+00 - accuracy: 0.3785 - val_loss: -2.9450e+00 - val_accuracy: 0.3788
# Epoch 7/100
# 3/3 - 0s - loss: -1.3302e+01 - accuracy: 0.3865 - val_loss: -4.1336e+01 - val_accuracy: 0.3030
# Epoch 8/100
# 3/3 - 0s - loss: -6.3049e+01 - accuracy: 0.3944 - val_loss: -8.8163e+01 - val_accuracy: 0.3485
# Epoch 9/100
# 3/3 - 0s - loss: -1.0288e+02 - accuracy: 0.4223 - val_loss: -2.8996e+02 - val_accuracy: 0.3182
# Epoch 10/100
# 3/3 - 0s - loss: -3.6225e+02 - accuracy: 0.4024 - val_loss: -9.5112e+02 - val_accuracy: 0.4091
# Epoch 11/100
# 3/3 - 0s - loss: -1.3150e+03 - accuracy: 0.3865 - val_loss: -1.6414e+03 - val_accuracy: 0.6061
# Epoch 12/100
# 3/3 - 0s - loss: -2.3334e+03 - accuracy: 0.4183 - val_loss: -5.1610e+03 - val_accuracy: 0.3485
# Epoch 13/100
# 3/3 - 0s - loss: -4.4924e+03 - accuracy: 0.4263 - val_loss: -1.0684e+04 - val_accuracy: 0.3788
# Epoch 14/100
# 3/3 - 0s - loss: -1.3489e+04 - accuracy: 0.3785 - val_loss: -2.4691e+04 - val_accuracy: 0.3485
# Epoch 15/100
# 3/3 - 0s - loss: -2.6420e+04 - accuracy: 0.4143 - val_loss: -3.8269e+04 - val_accuracy: 0.5758
# Epoch 16/100
# 3/3 - 0s - loss: -4.8759e+04 - accuracy: 0.4303 - val_loss: -8.4102e+04 - val_accuracy: 0.3182
# Epoch 17/100
# 3/3 - 0s - loss: -9.3805e+04 - accuracy: 0.3586 - val_loss: -9.5512e+04 - val_accuracy: 0.6515
# Epoch 18/100
# 3/3 - 0s - loss: -1.1066e+05 - accuracy: 0.4861 - val_loss: -1.8908e+05 - val_accuracy: 0.3333
# Epoch 19/100
# 3/3 - 0s - loss: -1.9899e+05 - accuracy: 0.3825 - val_loss: -3.0203e+05 - val_accuracy: 0.3182
# Epoch 20/100
# 3/3 - 0s - loss: -3.1329e+05 - accuracy: 0.3586 - val_loss: -4.7818e+05 - val_accuracy: 0.4091
# Epoch 21/100
# 3/3 - 0s - loss: -4.8948e+05 - accuracy: 0.4263 - val_loss: -6.1711e+05 - val_accuracy: 0.5606
# Epoch 22/100
# 3/3 - 0s - loss: -6.9962e+05 - accuracy: 0.4900 - val_loss: -9.3004e+05 - val_accuracy: 0.3333
# Epoch 23/100
# 3/3 - 0s - loss: -8.6076e+05 - accuracy: 0.3546 - val_loss: -1.3433e+06 - val_accuracy: 0.3485
# Epoch 24/100
# 3/3 - 0s - loss: -1.4140e+06 - accuracy: 0.3984 - val_loss: -1.7025e+06 - val_accuracy: 0.5303
# Epoch 25/100
# 3/3 - 0s - loss: -1.7547e+06 - accuracy: 0.4701 - val_loss: -2.3003e+06 - val_accuracy: 0.3788
# Epoch 26/100
# 3/3 - 0s - loss: -2.3429e+06 - accuracy: 0.4024 - val_loss: -2.8346e+06 - val_accuracy: 0.5152
# Epoch 27/100
# 3/3 - 0s - loss: -2.7036e+06 - accuracy: 0.4622 - val_loss: -4.0371e+06 - val_accuracy: 0.3333
# Epoch 28/100
# 3/3 - 0s - loss: -3.7730e+06 - accuracy: 0.4104 - val_loss: -5.2098e+06 - val_accuracy: 0.3333
# Epoch 29/100
# 3/3 - 0s - loss: -5.3093e+06 - accuracy: 0.3625 - val_loss: -6.6463e+06 - val_accuracy: 0.4091
# Epoch 30/100
# 3/3 - 0s - loss: -7.3333e+06 - accuracy: 0.4582 - val_loss: -8.0085e+06 - val_accuracy: 0.3182
# Epoch 31/100
# 3/3 - 0s - loss: -8.1832e+06 - accuracy: 0.3147 - val_loss: -1.0441e+07 - val_accuracy: 0.3636
# Epoch 32/100
# 3/3 - 0s - loss: -1.0145e+07 - accuracy: 0.3944 - val_loss: -1.2072e+07 - val_accuracy: 0.3182
# Epoch 33/100
# 3/3 - 0s - loss: -1.3081e+07 - accuracy: 0.3108 - val_loss: -1.5199e+07 - val_accuracy: 0.3788
# Epoch 34/100
# 3/3 - 0s - loss: -1.4603e+07 - accuracy: 0.3984 - val_loss: -1.6148e+07 - val_accuracy: 0.5303
# Epoch 35/100
# 3/3 - 0s - loss: -1.5652e+07 - accuracy: 0.4980 - val_loss: -2.0188e+07 - val_accuracy: 0.3485
# Epoch 36/100
# 3/3 - 0s - loss: -1.9423e+07 - accuracy: 0.3665 - val_loss: -2.4252e+07 - val_accuracy: 0.3788
# Epoch 37/100
# 3/3 - 0s - loss: -2.4609e+07 - accuracy: 0.4263 - val_loss: -2.7254e+07 - val_accuracy: 0.4091
# Epoch 38/100
# 3/3 - 0s - loss: -2.7702e+07 - accuracy: 0.4422 - val_loss: -3.2698e+07 - val_accuracy: 0.3333
# Epoch 39/100
# 3/3 - 0s - loss: -3.5891e+07 - accuracy: 0.3586 - val_loss: -3.7660e+07 - val_accuracy: 0.4242
# Epoch 40/100
# 3/3 - 0s - loss: -3.9048e+07 - accuracy: 0.4582 - val_loss: -4.5474e+07 - val_accuracy: 0.3788
# Epoch 41/100
# 3/3 - 0s - loss: -4.1939e+07 - accuracy: 0.3944 - val_loss: -4.5442e+07 - val_accuracy: 0.5455
# Epoch 42/100
# 3/3 - 0s - loss: -4.2558e+07 - accuracy: 0.4861 - val_loss: -5.2992e+07 - val_accuracy: 0.4848
# Epoch 43/100
# 3/3 - 0s - loss: -5.3171e+07 - accuracy: 0.4622 - val_loss: -6.3710e+07 - val_accuracy: 0.4091
# Epoch 44/100
# 3/3 - 0s - loss: -6.0950e+07 - accuracy: 0.4024 - val_loss: -7.2952e+07 - val_accuracy: 0.3333
# Epoch 45/100
# 3/3 - 0s - loss: -6.4390e+07 - accuracy: 0.3904 - val_loss: -8.4099e+07 - val_accuracy: 0.4091
# Epoch 46/100
# 3/3 - 0s - loss: -7.6388e+07 - accuracy: 0.4422 - val_loss: -9.5421e+07 - val_accuracy: 0.3788
# Epoch 47/100
# 3/3 - 0s - loss: -8.5192e+07 - accuracy: 0.4382 - val_loss: -1.0876e+08 - val_accuracy: 0.3485
# Epoch 48/100
# 3/3 - 0s - loss: -1.1134e+08 - accuracy: 0.3865 - val_loss: -1.1838e+08 - val_accuracy: 0.4545
# Epoch 49/100
# 3/3 - 0s - loss: -1.1175e+08 - accuracy: 0.4582 - val_loss: -1.2073e+08 - val_accuracy: 0.5455
# Epoch 50/100
# 3/3 - 0s - loss: -1.0628e+08 - accuracy: 0.4861 - val_loss: -1.4382e+08 - val_accuracy: 0.4394
# Epoch 51/100
# 3/3 - 0s - loss: -1.4058e+08 - accuracy: 0.4542 - val_loss: -1.6715e+08 - val_accuracy: 0.4091
# Epoch 52/100
# 3/3 - 0s - loss: -1.5352e+08 - accuracy: 0.4462 - val_loss: -1.8501e+08 - val_accuracy: 0.4091
# Epoch 53/100
# 3/3 - 0s - loss: -1.7540e+08 - accuracy: 0.4462 - val_loss: -2.1613e+08 - val_accuracy: 0.3485
# Epoch 54/100
# 3/3 - 0s - loss: -2.1445e+08 - accuracy: 0.4064 - val_loss: -2.4558e+08 - val_accuracy: 0.3333
# Epoch 55/100
# 3/3 - 0s - loss: -2.6799e+08 - accuracy: 0.3665 - val_loss: -2.7635e+08 - val_accuracy: 0.4091
# Epoch 56/100
# 3/3 - 0s - loss: -2.2832e+08 - accuracy: 0.4143 - val_loss: -2.6996e+08 - val_accuracy: 0.5303
# Epoch 57/100
# 3/3 - 0s - loss: -2.5082e+08 - accuracy: 0.4980 - val_loss: -3.2352e+08 - val_accuracy: 0.4091
# Epoch 58/100
# 3/3 - 0s - loss: -2.8401e+08 - accuracy: 0.4104 - val_loss: -3.5980e+08 - val_accuracy: 0.4091
# Epoch 59/100
# 3/3 - 0s - loss: -3.3349e+08 - accuracy: 0.4263 - val_loss: -3.8576e+08 - val_accuracy: 0.4242
# Epoch 60/100
# 3/3 - 0s - loss: -3.7888e+08 - accuracy: 0.4502 - val_loss: -4.1806e+08 - val_accuracy: 0.4394
# Epoch 61/100
# 3/3 - 0s - loss: -4.1659e+08 - accuracy: 0.4821 - val_loss: -4.4569e+08 - val_accuracy: 0.4848
# Epoch 62/100
# 3/3 - 0s - loss: -4.0536e+08 - accuracy: 0.4781 - val_loss: -5.0382e+08 - val_accuracy: 0.4091
# Epoch 63/100
# 3/3 - 0s - loss: -4.8633e+08 - accuracy: 0.4382 - val_loss: -5.4319e+08 - val_accuracy: 0.4242
# Epoch 64/100
# 3/3 - 0s - loss: -4.8141e+08 - accuracy: 0.4502 - val_loss: -5.7931e+08 - val_accuracy: 0.4545
# Epoch 65/100
# 3/3 - 0s - loss: -5.5399e+08 - accuracy: 0.4661 - val_loss: -6.3857e+08 - val_accuracy: 0.4394
# Epoch 66/100
# 3/3 - 0s - loss: -5.9880e+08 - accuracy: 0.4781 - val_loss: -7.0682e+08 - val_accuracy: 0.4545
# Epoch 67/100
# 3/3 - 0s - loss: -6.5453e+08 - accuracy: 0.4622 - val_loss: -8.0440e+08 - val_accuracy: 0.3788
# Epoch 68/100
# 3/3 - 0s - loss: -7.6541e+08 - accuracy: 0.4343 - val_loss: -8.9887e+08 - val_accuracy: 0.3485
# Epoch 69/100
# 3/3 - 0s - loss: -8.3039e+08 - accuracy: 0.3665 - val_loss: -9.9104e+08 - val_accuracy: 0.3636
# Epoch 70/100
# 3/3 - 0s - loss: -9.9601e+08 - accuracy: 0.3865 - val_loss: -1.0751e+09 - val_accuracy: 0.3788
# Epoch 71/100
# 3/3 - 0s - loss: -9.9767e+08 - accuracy: 0.3865 - val_loss: -1.1519e+09 - val_accuracy: 0.4242
# Epoch 72/100
# 3/3 - 0s - loss: -1.0199e+09 - accuracy: 0.4582 - val_loss: -1.2869e+09 - val_accuracy: 0.3788
# Epoch 73/100
# 3/3 - 0s - loss: -1.2712e+09 - accuracy: 0.3984 - val_loss: -1.4279e+09 - val_accuracy: 0.3788
# Epoch 74/100
# 3/3 - 0s - loss: -1.2816e+09 - accuracy: 0.3944 - val_loss: -1.4820e+09 - val_accuracy: 0.4242
# Epoch 75/100
# 3/3 - 0s - loss: -1.4374e+09 - accuracy: 0.4661 - val_loss: -1.6009e+09 - val_accuracy: 0.4242
# Epoch 76/100
# 3/3 - 0s - loss: -1.5840e+09 - accuracy: 0.4781 - val_loss: -1.7224e+09 - val_accuracy: 0.4242
# Epoch 77/100
# 3/3 - 0s - loss: -1.8451e+09 - accuracy: 0.4502 - val_loss: -1.8501e+09 - val_accuracy: 0.4545
# Epoch 78/100
# 3/3 - 0s - loss: -1.6499e+09 - accuracy: 0.4582 - val_loss: -1.9743e+09 - val_accuracy: 0.4545
# Epoch 79/100
# 3/3 - 0s - loss: -1.8628e+09 - accuracy: 0.4861 - val_loss: -2.1146e+09 - val_accuracy: 0.4545
# Epoch 80/100
# 3/3 - 0s - loss: -1.8872e+09 - accuracy: 0.4861 - val_loss: -2.3573e+09 - val_accuracy: 0.4091
# Epoch 81/100
# 3/3 - 0s - loss: -2.0197e+09 - accuracy: 0.4064 - val_loss: -2.5665e+09 - val_accuracy: 0.3788
# Epoch 82/100
# 3/3 - 0s - loss: -2.2164e+09 - accuracy: 0.3984 - val_loss: -2.7453e+09 - val_accuracy: 0.4091
# Epoch 83/100
# 3/3 - 0s - loss: -2.8858e+09 - accuracy: 0.4343 - val_loss: -2.9750e+09 - val_accuracy: 0.3788
# Epoch 84/100
# 3/3 - 0s - loss: -2.5534e+09 - accuracy: 0.4343 - val_loss: -3.1974e+09 - val_accuracy: 0.3485
# Epoch 85/100
# 3/3 - 0s - loss: -2.8526e+09 - accuracy: 0.3904 - val_loss: -3.4313e+09 - val_accuracy: 0.3788
# Epoch 86/100
# 3/3 - 0s - loss: -3.4631e+09 - accuracy: 0.3865 - val_loss: -3.7025e+09 - val_accuracy: 0.3788
# Epoch 87/100
# 3/3 - 0s - loss: -3.3057e+09 - accuracy: 0.4064 - val_loss: -4.0382e+09 - val_accuracy: 0.3636
# Epoch 88/100
# 3/3 - 0s - loss: -4.0059e+09 - accuracy: 0.3625 - val_loss: -4.3392e+09 - val_accuracy: 0.4091
# Epoch 89/100
# 3/3 - 0s - loss: -4.0082e+09 - accuracy: 0.4143 - val_loss: -4.6723e+09 - val_accuracy: 0.3788
# Epoch 90/100
# 3/3 - 0s - loss: -4.5066e+09 - accuracy: 0.4064 - val_loss: -4.9516e+09 - val_accuracy: 0.4242
# Epoch 91/100
# 3/3 - 0s - loss: -4.6940e+09 - accuracy: 0.4462 - val_loss: -5.1559e+09 - val_accuracy: 0.4394
# Epoch 92/100
# 3/3 - 0s - loss: -4.5484e+09 - accuracy: 0.4622 - val_loss: -5.3698e+09 - val_accuracy: 0.4394
# Epoch 93/100
# 3/3 - 0s - loss: -4.4229e+09 - accuracy: 0.4701 - val_loss: -5.8806e+09 - val_accuracy: 0.3788
# Epoch 94/100
# 3/3 - 0s - loss: -5.7448e+09 - accuracy: 0.4263 - val_loss: -6.2441e+09 - val_accuracy: 0.4091
# Epoch 95/100
# 3/3 - 0s - loss: -5.7410e+09 - accuracy: 0.4422 - val_loss: -6.7296e+09 - val_accuracy: 0.3788
# Epoch 96/100
# 3/3 - 0s - loss: -6.1273e+09 - accuracy: 0.3865 - val_loss: -7.2212e+09 - val_accuracy: 0.3788
# Epoch 97/100
# 3/3 - 0s - loss: -7.3922e+09 - accuracy: 0.4462 - val_loss: -7.5215e+09 - val_accuracy: 0.4091
# Epoch 98/100
# 3/3 - 0s - loss: -7.7558e+09 - accuracy: 0.4502 - val_loss: -8.0962e+09 - val_accuracy: 0.3788
# Epoch 99/100
# 3/3 - 0s - loss: -7.8104e+09 - accuracy: 0.4104 - val_loss: -8.5063e+09 - val_accuracy: 0.4091
# Epoch 100/100
# 3/3 - 0s - loss: -8.2080e+09 - accuracy: 0.4382 - val_loss: -9.1731e+09 - val_accuracy: 0.3636

# %% [markdown]
# ### Model 2

# %%
# Model 2
def build_model_2():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (244,244, 3)), 
        BatchNormalization(),
        tf.keras.layers.MaxPooling2D(2,2),
        BatchNormalization(),
        tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
        BatchNormalization(),
        tf.keras.layers.MaxPooling2D(2,2),
        BatchNormalization(),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation=tf.nn.relu),
        tf.keras.layers.Dense(6, activation=tf.nn.softmax)
    ])
    return model

# %%
for batch in batch_sizes:
    for epoch in epoch_num:
        for data_au in data_aug:
            
            (x_train, y_train), (x_test, y_test) = load_data()
            x_train, y_train = shuffle(x_train,y_train, random_state=25)
            n_train = y_train.shape[0]
            n_test = y_test.shape[0]
            # Normalize data.
            x_train = x_train.astype('float32') / 255
            x_test = x_test.astype('float32') / 255

            model=build_model_2()

            data_augmen(batch,epoch,data_au)
            print("Batch_size:",batch)
            print("Epochs:",epoch)
            print("Data Augmentation:",data_au)

            model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])            
            history = model.fit(x_train,y_train, batch_size=batch, epochs=epoch, validation_split = 0.2)
            plot_accuracy_loss(history)
# Out:
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:04<00:00, 17.44it/s]
# 100%|██████████| 70/70 [00:01<00:00, 53.73it/s]
# 100%|██████████| 111/111 [00:04<00:00, 27.41it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 27.73it/s]
# 100%|██████████| 20/20 [00:00<00:00, 73.34it/s]
# 100%|██████████| 26/26 [00:00<00:00, 90.94it/s]
# Using real-time data augmentation.
# Batch_size: 32
# Epochs: 20
# Data Augmentation: True
# Epoch 1/20
# 7/7 [==============================] - 1s 104ms/step - loss: 8.0541 - accuracy: 0.6700 - val_loss: 6.1164 - val_accuracy: 0.3137
# Epoch 2/20
# 7/7 [==============================] - 0s 38ms/step - loss: 4.4922 - accuracy: 0.8900 - val_loss: 0.4330 - val_accuracy: 0.8235
# Epoch 3/20
# 7/7 [==============================] - 0s 37ms/step - loss: 1.0857 - accuracy: 0.9800 - val_loss: 3.6054 - val_accuracy: 0.5490
# Epoch 4/20
# 7/7 [==============================] - 0s 37ms/step - loss: 0.4219 - accuracy: 0.9850 - val_loss: 15.4870 - val_accuracy: 0.4902
# Epoch 5/20
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0868 - accuracy: 0.9950 - val_loss: 23.1438 - val_accuracy: 0.4902
# Epoch 6/20
# 7/7 [==============================] - 0s 37ms/step - loss: 0.2037 - accuracy: 0.9900 - val_loss: 32.4157 - val_accuracy: 0.4902
# Epoch 7/20
# 7/7 [==============================] - 0s 37ms/step - loss: 9.3802e-05 - accuracy: 1.0000 - val_loss: 43.5972 - val_accuracy: 0.4902
# Epoch 8/20
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0514 - accuracy: 0.9950 - val_loss: 45.6008 - val_accuracy: 0.4902
# Epoch 9/20
# 7/7 [==============================] - 0s 38ms/step - loss: 2.7633e-05 - accuracy: 1.0000 - val_loss: 48.6122 - val_accuracy: 0.4902
# Epoch 10/20
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0446 - accuracy: 0.9950 - val_loss: 54.7129 - val_accuracy: 0.4902
# Epoch 11/20
# 7/7 [==============================] - 0s 38ms/step - loss: 0.2320 - accuracy: 0.9900 - val_loss: 74.4725 - val_accuracy: 0.4902
# Epoch 12/20
# 7/7 [==============================] - 0s 37ms/step - loss: 0.2008 - accuracy: 0.9900 - val_loss: 77.4604 - val_accuracy: 0.4902
# Epoch 13/20
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0922 - accuracy: 0.9900 - val_loss: 83.2848 - val_accuracy: 0.4902
# Epoch 14/20
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0971 - accuracy: 0.9950 - val_loss: 94.6689 - val_accuracy: 0.4902
# Epoch 15/20
# 7/7 [==============================] - 0s 37ms/step - loss: 8.0485e-05 - accuracy: 1.0000 - val_loss: 101.2170 - val_accuracy: 0.4902
# Epoch 16/20
# 7/7 [==============================] - 0s 37ms/step - loss: 0.1800 - accuracy: 0.9850 - val_loss: 92.9615 - val_accuracy: 0.4902
# Epoch 17/20
# 7/7 [==============================] - 0s 37ms/step - loss: 0.3049 - accuracy: 0.9850 - val_loss: 95.3575 - val_accuracy: 0.4902
# Epoch 18/20
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0300 - accuracy: 0.9950 - val_loss: 95.8672 - val_accuracy: 0.4902
# Epoch 19/20
# 7/7 [==============================] - 0s 38ms/step - loss: 0.2442 - accuracy: 0.9950 - val_loss: 97.9095 - val_accuracy: 0.4902
# Epoch 20/20
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 99.8320 - val_accuracy: 0.4902
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:03<00:00, 19.89it/s]
# 100%|██████████| 70/70 [00:01<00:00, 54.64it/s]
# 100%|██████████| 111/111 [00:04<00:00, 25.87it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 29.41it/s]
# 100%|██████████| 20/20 [00:00<00:00, 73.60it/s]
# 100%|██████████| 26/26 [00:00<00:00, 95.02it/s]
# No data augmentation.
# Batch_size: 32
# Epochs: 20
# Data Augmentation: False
# Epoch 1/20
# 7/7 [==============================] - 1s 71ms/step - loss: 3.9613 - accuracy: 0.7150 - val_loss: 5.2035 - val_accuracy: 0.4706
# Epoch 2/20
# 7/7 [==============================] - 0s 38ms/step - loss: 2.0424 - accuracy: 0.9600 - val_loss: 0.6979 - val_accuracy: 0.7451
# Epoch 3/20
# 7/7 [==============================] - 0s 37ms/step - loss: 0.8777 - accuracy: 0.9550 - val_loss: 6.2668 - val_accuracy: 0.4902
# Epoch 4/20
# 7/7 [==============================] - 0s 37ms/step - loss: 0.4734 - accuracy: 0.9700 - val_loss: 16.3725 - val_accuracy: 0.4902
# Epoch 5/20
# 7/7 [==============================] - 0s 37ms/step - loss: 0.2821 - accuracy: 0.9750 - val_loss: 20.2872 - val_accuracy: 0.4902
# Epoch 6/20
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0042 - accuracy: 0.9950 - val_loss: 23.1555 - val_accuracy: 0.4902
# Epoch 7/20
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 26.8393 - val_accuracy: 0.4902
# Epoch 8/20
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 31.0524 - val_accuracy: 0.4902
# Epoch 9/20
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 35.1744 - val_accuracy: 0.4902
# Epoch 10/20
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 39.1796 - val_accuracy: 0.4902
# Epoch 11/20
# 7/7 [==============================] - 0s 36ms/step - loss: 4.1723e-09 - accuracy: 1.0000 - val_loss: 43.0065 - val_accuracy: 0.4902
# Epoch 12/20
# 7/7 [==============================] - 0s 46ms/step - loss: 1.7881e-09 - accuracy: 1.0000 - val_loss: 46.4571 - val_accuracy: 0.4902
# Epoch 13/20
# 7/7 [==============================] - 0s 46ms/step - loss: 1.5497e-07 - accuracy: 1.0000 - val_loss: 49.6103 - val_accuracy: 0.4902
# Epoch 14/20
# 7/7 [==============================] - 0s 44ms/step - loss: 4.3856e-06 - accuracy: 1.0000 - val_loss: 52.5291 - val_accuracy: 0.4902
# Epoch 15/20
# 7/7 [==============================] - 0s 43ms/step - loss: 7.6229e-07 - accuracy: 1.0000 - val_loss: 55.2542 - val_accuracy: 0.4902
# Epoch 16/20
# 7/7 [==============================] - 0s 37ms/step - loss: 1.3113e-08 - accuracy: 1.0000 - val_loss: 57.8115 - val_accuracy: 0.4902
# Epoch 17/20
# 7/7 [==============================] - 0s 42ms/step - loss: 2.3842e-09 - accuracy: 1.0000 - val_loss: 60.0718 - val_accuracy: 0.4902
# Epoch 18/20
# 7/7 [==============================] - 0s 40ms/step - loss: 1.1682e-07 - accuracy: 1.0000 - val_loss: 62.1574 - val_accuracy: 0.4902
# Epoch 19/20
# 7/7 [==============================] - 0s 38ms/step - loss: 2.9921e-07 - accuracy: 1.0000 - val_loss: 63.7577 - val_accuracy: 0.4902
# Epoch 20/20
# 7/7 [==============================] - 0s 36ms/step - loss: 4.1245e-07 - accuracy: 1.0000 - val_loss: 65.1964 - val_accuracy: 0.4902
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:03<00:00, 20.07it/s]
# 100%|██████████| 70/70 [00:01<00:00, 52.99it/s]
# 100%|██████████| 111/111 [00:04<00:00, 27.45it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 29.10it/s]
# 100%|██████████| 20/20 [00:00<00:00, 44.25it/s]
# 100%|██████████| 26/26 [00:00<00:00, 74.83it/s]
# Using real-time data augmentation.
# Batch_size: 32
# Epochs: 50
# Data Augmentation: True
# Epoch 1/50
# 7/7 [==============================] - 1s 68ms/step - loss: 4.2991 - accuracy: 0.7200 - val_loss: 3.7228 - val_accuracy: 0.3333
# Epoch 2/50
# 7/7 [==============================] - 0s 37ms/step - loss: 2.0317 - accuracy: 0.9350 - val_loss: 2.5357 - val_accuracy: 0.6667
# Epoch 3/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.6492 - accuracy: 0.9750 - val_loss: 0.5584 - val_accuracy: 0.8627
# Epoch 4/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.4264 - accuracy: 0.9800 - val_loss: 2.8938 - val_accuracy: 0.6471
# Epoch 5/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.1280 - accuracy: 0.9900 - val_loss: 3.9303 - val_accuracy: 0.6275
# Epoch 6/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 13.8796 - val_accuracy: 0.4902
# Epoch 7/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 22.8308 - val_accuracy: 0.4902
# Epoch 8/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 30.4314 - val_accuracy: 0.4902
# Epoch 9/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 36.9926 - val_accuracy: 0.4902
# Epoch 10/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 42.8059 - val_accuracy: 0.4902
# Epoch 11/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 47.9441 - val_accuracy: 0.4902
# Epoch 12/50
# 7/7 [==============================] - 0s 44ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 52.5301 - val_accuracy: 0.4902
# Epoch 13/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 56.6983 - val_accuracy: 0.4902
# Epoch 14/50
# 7/7 [==============================] - 0s 42ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 60.3074 - val_accuracy: 0.4902
# Epoch 15/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 63.4967 - val_accuracy: 0.4902
# Epoch 16/50
# 7/7 [==============================] - 0s 37ms/step - loss: 9.6559e-08 - accuracy: 1.0000 - val_loss: 66.1411 - val_accuracy: 0.4902
# Epoch 17/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 68.3789 - val_accuracy: 0.4902
# Epoch 18/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 70.3487 - val_accuracy: 0.4902
# Epoch 19/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 71.8131 - val_accuracy: 0.4902
# Epoch 20/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 73.2136 - val_accuracy: 0.4902
# Epoch 21/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 74.0260 - val_accuracy: 0.4902
# Epoch 22/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 74.6824 - val_accuracy: 0.4902
# Epoch 23/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 75.0901 - val_accuracy: 0.4902
# Epoch 24/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 75.3314 - val_accuracy: 0.4902
# Epoch 25/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 75.2628 - val_accuracy: 0.4902
# Epoch 26/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 75.0484 - val_accuracy: 0.4902
# Epoch 27/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 74.5924 - val_accuracy: 0.4902
# Epoch 28/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 74.0353 - val_accuracy: 0.4902
# Epoch 29/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 73.4072 - val_accuracy: 0.4902
# Epoch 30/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 72.6344 - val_accuracy: 0.4902
# Epoch 31/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 71.6598 - val_accuracy: 0.4902
# Epoch 32/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 70.4861 - val_accuracy: 0.4902
# Epoch 33/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 69.0955 - val_accuracy: 0.4902
# Epoch 34/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.7726 - val_accuracy: 0.4902
# Epoch 35/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 66.1832 - val_accuracy: 0.4902
# Epoch 36/50
# 7/7 [==============================] - 0s 43ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 64.3543 - val_accuracy: 0.4902
# Epoch 37/50
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 62.6469 - val_accuracy: 0.4902
# Epoch 38/50
# 7/7 [==============================] - 0s 39ms/step - loss: 5.9605e-10 - accuracy: 1.0000 - val_loss: 60.7867 - val_accuracy: 0.4902
# Epoch 39/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 58.9354 - val_accuracy: 0.4902
# Epoch 40/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 56.9650 - val_accuracy: 0.4902
# Epoch 41/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 54.9686 - val_accuracy: 0.4902
# Epoch 42/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 52.9071 - val_accuracy: 0.4902
# Epoch 43/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 50.6159 - val_accuracy: 0.4902
# Epoch 44/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 48.4375 - val_accuracy: 0.4902
# Epoch 45/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 46.0247 - val_accuracy: 0.4902
# Epoch 46/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 43.7589 - val_accuracy: 0.4902
# Epoch 47/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 41.5047 - val_accuracy: 0.5098
# Epoch 48/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 39.3175 - val_accuracy: 0.5490
# Epoch 49/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 37.2439 - val_accuracy: 0.5686
# Epoch 50/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 35.2650 - val_accuracy: 0.5686
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:03<00:00, 19.74it/s]
# 100%|██████████| 70/70 [00:01<00:00, 53.07it/s]
# 100%|██████████| 111/111 [00:04<00:00, 23.11it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 28.11it/s]
# 100%|██████████| 20/20 [00:00<00:00, 68.75it/s]
# 100%|██████████| 26/26 [00:00<00:00, 94.81it/s]
# No data augmentation.
# Batch_size: 32
# Epochs: 50
# Data Augmentation: False
# Epoch 1/50
# 7/7 [==============================] - 1s 64ms/step - loss: 3.6710 - accuracy: 0.7550 - val_loss: 12.8053 - val_accuracy: 0.1961
# Epoch 2/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.9231 - accuracy: 0.9350 - val_loss: 10.3896 - val_accuracy: 0.1961
# Epoch 3/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.1664 - accuracy: 0.9900 - val_loss: 6.4827 - val_accuracy: 0.2745
# Epoch 4/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.3709 - accuracy: 0.9750 - val_loss: 1.6731 - val_accuracy: 0.5686
# Epoch 5/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.5644 - accuracy: 0.9750 - val_loss: 12.2045 - val_accuracy: 0.4902
# Epoch 6/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0974 - accuracy: 0.9950 - val_loss: 1.5550 - val_accuracy: 0.7843
# Epoch 7/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.3347 - accuracy: 0.9700 - val_loss: 3.0524 - val_accuracy: 0.8039
# Epoch 8/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0784 - accuracy: 0.9950 - val_loss: 10.3622 - val_accuracy: 0.5098
# Epoch 9/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.2795 - accuracy: 0.9800 - val_loss: 9.9313 - val_accuracy: 0.5098
# Epoch 10/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.1509 - accuracy: 0.9900 - val_loss: 21.8571 - val_accuracy: 0.4902
# Epoch 11/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 33.5020 - val_accuracy: 0.4902
# Epoch 12/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0078 - accuracy: 0.9950 - val_loss: 44.8170 - val_accuracy: 0.4902
# Epoch 13/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0702 - accuracy: 0.9950 - val_loss: 55.8842 - val_accuracy: 0.4902
# Epoch 14/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 65.3834 - val_accuracy: 0.4902
# Epoch 15/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.2523 - accuracy: 0.9950 - val_loss: 70.2347 - val_accuracy: 0.4902
# Epoch 16/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 70.6596 - val_accuracy: 0.4902
# Epoch 17/50
# 7/7 [==============================] - 0s 37ms/step - loss: 1.7881e-09 - accuracy: 1.0000 - val_loss: 69.4097 - val_accuracy: 0.4902
# Epoch 18/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 69.3607 - val_accuracy: 0.4902
# Epoch 19/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 69.7823 - val_accuracy: 0.4902
# Epoch 20/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 70.5460 - val_accuracy: 0.4902
# Epoch 21/50
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 71.1407 - val_accuracy: 0.4902
# Epoch 22/50
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 71.6351 - val_accuracy: 0.4902
# Epoch 23/50
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 71.9145 - val_accuracy: 0.4902
# Epoch 24/50
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 72.0977 - val_accuracy: 0.4902
# Epoch 25/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 72.0183 - val_accuracy: 0.4902
# Epoch 26/50
# 7/7 [==============================] - 0s 42ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 71.8703 - val_accuracy: 0.4902
# Epoch 27/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 71.3459 - val_accuracy: 0.4902
# Epoch 28/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 70.6389 - val_accuracy: 0.4902
# Epoch 29/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 69.9398 - val_accuracy: 0.4902
# Epoch 30/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 69.2259 - val_accuracy: 0.4902
# Epoch 31/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 68.3413 - val_accuracy: 0.4902
# Epoch 32/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.3099 - val_accuracy: 0.4902
# Epoch 33/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 66.2126 - val_accuracy: 0.4902
# Epoch 34/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 64.8551 - val_accuracy: 0.4902
# Epoch 35/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 63.4265 - val_accuracy: 0.4902
# Epoch 36/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 61.8555 - val_accuracy: 0.4902
# Epoch 37/50
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 60.1829 - val_accuracy: 0.4902
# Epoch 38/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 58.4978 - val_accuracy: 0.4902
# Epoch 39/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 56.6086 - val_accuracy: 0.4902
# Epoch 40/50
# 7/7 [==============================] - 0s 39ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 54.6210 - val_accuracy: 0.4902
# Epoch 41/50
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 52.7354 - val_accuracy: 0.4902
# Epoch 42/50
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 50.6003 - val_accuracy: 0.4902
# Epoch 43/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 48.1547 - val_accuracy: 0.4902
# Epoch 44/50
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 45.6017 - val_accuracy: 0.4902
# Epoch 45/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 43.1772 - val_accuracy: 0.4902
# Epoch 46/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 40.6450 - val_accuracy: 0.4902
# Epoch 47/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 38.0397 - val_accuracy: 0.4902
# Epoch 48/50
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 35.4026 - val_accuracy: 0.4902
# Epoch 49/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 32.5588 - val_accuracy: 0.4902
# Epoch 50/50
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 30.0196 - val_accuracy: 0.5294
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:03<00:00, 19.34it/s]
# 100%|██████████| 70/70 [00:01<00:00, 51.73it/s]
# 100%|██████████| 111/111 [00:04<00:00, 22.83it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 28.47it/s]
# 100%|██████████| 20/20 [00:00<00:00, 72.84it/s]
# 100%|██████████| 26/26 [00:00<00:00, 95.86it/s]
# Using real-time data augmentation.
# Batch_size: 32
# Epochs: 100
# Data Augmentation: True
# Epoch 1/100
# 7/7 [==============================] - 1s 75ms/step - loss: 6.7575 - accuracy: 0.7100 - val_loss: 5.8466 - val_accuracy: 0.3137
# Epoch 2/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.8491 - accuracy: 0.9350 - val_loss: 7.6742 - val_accuracy: 0.4902
# Epoch 3/100
# 7/7 [==============================] - 0s 37ms/step - loss: 2.0026 - accuracy: 0.8550 - val_loss: 8.0713 - val_accuracy: 0.4902
# Epoch 4/100
# 7/7 [==============================] - 0s 37ms/step - loss: 1.0309 - accuracy: 0.9650 - val_loss: 19.1423 - val_accuracy: 0.4902
# Epoch 5/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.1250 - accuracy: 0.9800 - val_loss: 27.5661 - val_accuracy: 0.4902
# Epoch 6/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0747 - accuracy: 0.9900 - val_loss: 37.1070 - val_accuracy: 0.4902
# Epoch 7/100
# 7/7 [==============================] - 0s 37ms/step - loss: 4.0287e-05 - accuracy: 1.0000 - val_loss: 45.7566 - val_accuracy: 0.4902
# Epoch 8/100
# 7/7 [==============================] - 0s 42ms/step - loss: 3.0398e-07 - accuracy: 1.0000 - val_loss: 52.8828 - val_accuracy: 0.4902
# Epoch 9/100
# 7/7 [==============================] - 0s 38ms/step - loss: 5.8533e-05 - accuracy: 1.0000 - val_loss: 59.0957 - val_accuracy: 0.4902
# Epoch 10/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0754 - accuracy: 0.9950 - val_loss: 65.3080 - val_accuracy: 0.4902
# Epoch 11/100
# 7/7 [==============================] - 0s 38ms/step - loss: 1.3765e-05 - accuracy: 1.0000 - val_loss: 70.1956 - val_accuracy: 0.4902
# Epoch 12/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 74.4525 - val_accuracy: 0.4902
# Epoch 13/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.3036 - accuracy: 0.9900 - val_loss: 73.8150 - val_accuracy: 0.4902
# Epoch 14/100
# 7/7 [==============================] - 0s 39ms/step - loss: 1.4508e-04 - accuracy: 1.0000 - val_loss: 72.6768 - val_accuracy: 0.4902
# Epoch 15/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0521 - accuracy: 0.9950 - val_loss: 68.6956 - val_accuracy: 0.4902
# Epoch 16/100
# 7/7 [==============================] - 0s 37ms/step - loss: 9.5778e-07 - accuracy: 1.0000 - val_loss: 62.5043 - val_accuracy: 0.4902
# Epoch 17/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0641 - accuracy: 0.9950 - val_loss: 69.2177 - val_accuracy: 0.4902
# Epoch 18/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0603 - accuracy: 0.9950 - val_loss: 72.9750 - val_accuracy: 0.4902
# Epoch 19/100
# 7/7 [==============================] - 0s 38ms/step - loss: 2.2099e-04 - accuracy: 1.0000 - val_loss: 76.0404 - val_accuracy: 0.4902
# Epoch 20/100
# 7/7 [==============================] - 0s 37ms/step - loss: 4.4093e-04 - accuracy: 1.0000 - val_loss: 78.2430 - val_accuracy: 0.4902
# Epoch 21/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0041 - accuracy: 0.9950 - val_loss: 78.2478 - val_accuracy: 0.4902
# Epoch 22/100
# 7/7 [==============================] - 0s 47ms/step - loss: 1.1776e-04 - accuracy: 1.0000 - val_loss: 70.8956 - val_accuracy: 0.4902
# Epoch 23/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.2740 - accuracy: 0.9900 - val_loss: 83.1694 - val_accuracy: 0.4902
# Epoch 24/100
# 7/7 [==============================] - 0s 40ms/step - loss: 2.0849e-05 - accuracy: 1.0000 - val_loss: 91.7142 - val_accuracy: 0.4902
# Epoch 25/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.1443 - accuracy: 0.9900 - val_loss: 90.4698 - val_accuracy: 0.4902
# Epoch 26/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0216 - accuracy: 0.9900 - val_loss: 92.3190 - val_accuracy: 0.4902
# Epoch 27/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 92.9509 - val_accuracy: 0.4902
# Epoch 28/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.1295 - accuracy: 0.9950 - val_loss: 89.1283 - val_accuracy: 0.4902
# Epoch 29/100
# 7/7 [==============================] - 0s 37ms/step - loss: 3.8325e-07 - accuracy: 1.0000 - val_loss: 86.8614 - val_accuracy: 0.4902
# Epoch 30/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.1249 - accuracy: 0.9900 - val_loss: 77.9768 - val_accuracy: 0.4902
# Epoch 31/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0877 - accuracy: 0.9900 - val_loss: 88.0680 - val_accuracy: 0.4902
# Epoch 32/100
# 7/7 [==============================] - 0s 43ms/step - loss: 5.1287e-05 - accuracy: 1.0000 - val_loss: 83.1577 - val_accuracy: 0.4902
# Epoch 33/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.1153 - accuracy: 0.9950 - val_loss: 88.6151 - val_accuracy: 0.4902
# Epoch 34/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0324 - accuracy: 0.9950 - val_loss: 101.4238 - val_accuracy: 0.4902
# Epoch 35/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0595 - accuracy: 0.9950 - val_loss: 120.7540 - val_accuracy: 0.4902
# Epoch 36/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.1534 - accuracy: 0.9950 - val_loss: 116.1487 - val_accuracy: 0.4902
# Epoch 37/100
# 7/7 [==============================] - 0s 37ms/step - loss: 4.5299e-08 - accuracy: 1.0000 - val_loss: 82.5428 - val_accuracy: 0.4902
# Epoch 38/100
# 7/7 [==============================] - 0s 38ms/step - loss: 8.0466e-08 - accuracy: 1.0000 - val_loss: 69.4119 - val_accuracy: 0.4902
# Epoch 39/100
# 7/7 [==============================] - 0s 37ms/step - loss: 1.2994e-07 - accuracy: 1.0000 - val_loss: 66.4560 - val_accuracy: 0.4902
# Epoch 40/100
# 7/7 [==============================] - 0s 39ms/step - loss: 7.0929e-08 - accuracy: 1.0000 - val_loss: 67.2343 - val_accuracy: 0.4902
# Epoch 41/100
# 7/7 [==============================] - 0s 36ms/step - loss: 6.7949e-08 - accuracy: 1.0000 - val_loss: 69.0951 - val_accuracy: 0.4902
# Epoch 42/100
# 7/7 [==============================] - 0s 36ms/step - loss: 4.9472e-08 - accuracy: 1.0000 - val_loss: 71.4085 - val_accuracy: 0.4902
# Epoch 43/100
# 7/7 [==============================] - 0s 37ms/step - loss: 4.2974e-07 - accuracy: 1.0000 - val_loss: 73.0790 - val_accuracy: 0.4902
# Epoch 44/100
# 7/7 [==============================] - 0s 37ms/step - loss: 6.9141e-08 - accuracy: 1.0000 - val_loss: 74.2644 - val_accuracy: 0.4902
# Epoch 45/100
# 7/7 [==============================] - 0s 37ms/step - loss: 2.8967e-07 - accuracy: 1.0000 - val_loss: 75.2091 - val_accuracy: 0.4902
# Epoch 46/100
# 7/7 [==============================] - 0s 37ms/step - loss: 2.8014e-08 - accuracy: 1.0000 - val_loss: 75.6962 - val_accuracy: 0.4902
# Epoch 47/100
# 7/7 [==============================] - 0s 38ms/step - loss: 1.4125e-06 - accuracy: 1.0000 - val_loss: 75.8042 - val_accuracy: 0.4902
# Epoch 48/100
# 7/7 [==============================] - 0s 39ms/step - loss: 5.3048e-08 - accuracy: 1.0000 - val_loss: 75.4243 - val_accuracy: 0.4902
# Epoch 49/100
# 7/7 [==============================] - 0s 37ms/step - loss: 4.2080e-07 - accuracy: 1.0000 - val_loss: 74.6462 - val_accuracy: 0.4902
# Epoch 50/100
# 7/7 [==============================] - 0s 36ms/step - loss: 7.5102e-08 - accuracy: 1.0000 - val_loss: 73.4181 - val_accuracy: 0.4902
# Epoch 51/100
# 7/7 [==============================] - 0s 37ms/step - loss: 8.1056e-07 - accuracy: 1.0000 - val_loss: 72.0450 - val_accuracy: 0.4902
# Epoch 52/100
# 7/7 [==============================] - 0s 36ms/step - loss: 3.9935e-08 - accuracy: 1.0000 - val_loss: 70.2134 - val_accuracy: 0.4902
# Epoch 53/100
# 7/7 [==============================] - 0s 38ms/step - loss: 8.3446e-09 - accuracy: 1.0000 - val_loss: 68.2594 - val_accuracy: 0.4902
# Epoch 54/100
# 7/7 [==============================] - 0s 36ms/step - loss: 1.1384e-07 - accuracy: 1.0000 - val_loss: 65.9684 - val_accuracy: 0.4902
# Epoch 55/100
# 7/7 [==============================] - 0s 39ms/step - loss: 1.0192e-07 - accuracy: 1.0000 - val_loss: 63.4516 - val_accuracy: 0.4902
# Epoch 56/100
# 7/7 [==============================] - 0s 37ms/step - loss: 1.4543e-07 - accuracy: 1.0000 - val_loss: 60.8179 - val_accuracy: 0.5098
# Epoch 57/100
# 7/7 [==============================] - 0s 38ms/step - loss: 9.8943e-08 - accuracy: 1.0000 - val_loss: 57.9123 - val_accuracy: 0.5098
# Epoch 58/100
# 7/7 [==============================] - 0s 37ms/step - loss: 4.3511e-08 - accuracy: 1.0000 - val_loss: 54.7599 - val_accuracy: 0.5098
# Epoch 59/100
# 7/7 [==============================] - 0s 38ms/step - loss: 9.2387e-08 - accuracy: 1.0000 - val_loss: 51.6209 - val_accuracy: 0.5098
# Epoch 60/100
# 7/7 [==============================] - 0s 38ms/step - loss: 1.7226e-07 - accuracy: 1.0000 - val_loss: 48.3342 - val_accuracy: 0.5294
# Epoch 61/100
# 7/7 [==============================] - 0s 40ms/step - loss: 8.2850e-08 - accuracy: 1.0000 - val_loss: 44.9789 - val_accuracy: 0.5490
# Epoch 62/100
# 7/7 [==============================] - 0s 37ms/step - loss: 3.2484e-07 - accuracy: 1.0000 - val_loss: 41.7920 - val_accuracy: 0.5882
# Epoch 63/100
# 7/7 [==============================] - 0s 42ms/step - loss: 7.3910e-08 - accuracy: 1.0000 - val_loss: 38.3228 - val_accuracy: 0.5882
# Epoch 64/100
# 7/7 [==============================] - 0s 43ms/step - loss: 2.9265e-07 - accuracy: 1.0000 - val_loss: 35.0660 - val_accuracy: 0.5882
# Epoch 65/100
# 7/7 [==============================] - 0s 45ms/step - loss: 6.6757e-08 - accuracy: 1.0000 - val_loss: 31.8054 - val_accuracy: 0.5882
# Epoch 66/100
# 7/7 [==============================] - 0s 38ms/step - loss: 2.1994e-07 - accuracy: 1.0000 - val_loss: 28.9128 - val_accuracy: 0.6275
# Epoch 67/100
# 7/7 [==============================] - 0s 38ms/step - loss: 2.4795e-07 - accuracy: 1.0000 - val_loss: 26.2060 - val_accuracy: 0.6471
# Epoch 68/100
# 7/7 [==============================] - 0s 38ms/step - loss: 5.9605e-08 - accuracy: 1.0000 - val_loss: 23.5147 - val_accuracy: 0.6667
# Epoch 69/100
# 7/7 [==============================] - 0s 37ms/step - loss: 6.2585e-08 - accuracy: 1.0000 - val_loss: 21.0731 - val_accuracy: 0.6667
# Epoch 70/100
# 7/7 [==============================] - 0s 38ms/step - loss: 1.8358e-07 - accuracy: 1.0000 - val_loss: 18.6972 - val_accuracy: 0.7059
# Epoch 71/100
# 7/7 [==============================] - 0s 37ms/step - loss: 3.3975e-08 - accuracy: 1.0000 - val_loss: 16.7036 - val_accuracy: 0.7255
# Epoch 72/100
# 7/7 [==============================] - 0s 38ms/step - loss: 5.6624e-08 - accuracy: 1.0000 - val_loss: 14.7894 - val_accuracy: 0.7255
# Epoch 73/100
# 7/7 [==============================] - 0s 39ms/step - loss: 5.3644e-08 - accuracy: 1.0000 - val_loss: 12.8364 - val_accuracy: 0.7451
# Epoch 74/100
# 7/7 [==============================] - 0s 38ms/step - loss: 7.7486e-08 - accuracy: 1.0000 - val_loss: 10.9857 - val_accuracy: 0.7843
# Epoch 75/100
# 7/7 [==============================] - 0s 37ms/step - loss: 8.2850e-08 - accuracy: 1.0000 - val_loss: 9.3459 - val_accuracy: 0.7843
# Epoch 76/100
# 7/7 [==============================] - 0s 38ms/step - loss: 7.5698e-08 - accuracy: 1.0000 - val_loss: 7.6695 - val_accuracy: 0.8039
# Epoch 77/100
# 7/7 [==============================] - 0s 39ms/step - loss: 8.2254e-08 - accuracy: 1.0000 - val_loss: 6.4228 - val_accuracy: 0.8627
# Epoch 78/100
# 7/7 [==============================] - 0s 37ms/step - loss: 8.3099e-06 - accuracy: 1.0000 - val_loss: 5.5878 - val_accuracy: 0.8627
# Epoch 79/100
# 7/7 [==============================] - 0s 38ms/step - loss: 1.4961e-07 - accuracy: 1.0000 - val_loss: 4.6617 - val_accuracy: 0.8627
# Epoch 80/100
# 7/7 [==============================] - 0s 37ms/step - loss: 5.3641e-07 - accuracy: 1.0000 - val_loss: 3.6926 - val_accuracy: 0.8824
# Epoch 81/100
# 7/7 [==============================] - 0s 39ms/step - loss: 2.6106e-07 - accuracy: 1.0000 - val_loss: 2.8619 - val_accuracy: 0.8824
# Epoch 82/100
# 7/7 [==============================] - 0s 36ms/step - loss: 7.9870e-08 - accuracy: 1.0000 - val_loss: 2.1482 - val_accuracy: 0.8824
# Epoch 83/100
# 7/7 [==============================] - 0s 37ms/step - loss: 3.2186e-08 - accuracy: 1.0000 - val_loss: 1.6156 - val_accuracy: 0.9020
# Epoch 84/100
# 7/7 [==============================] - 0s 37ms/step - loss: 1.1146e-07 - accuracy: 1.0000 - val_loss: 1.2308 - val_accuracy: 0.9020
# Epoch 85/100
# 7/7 [==============================] - 0s 39ms/step - loss: 2.6226e-08 - accuracy: 1.0000 - val_loss: 0.8577 - val_accuracy: 0.9216
# Epoch 86/100
# 7/7 [==============================] - 0s 47ms/step - loss: 7.7486e-08 - accuracy: 1.0000 - val_loss: 0.4950 - val_accuracy: 0.9412
# Epoch 87/100
# 7/7 [==============================] - 0s 42ms/step - loss: 7.0333e-08 - accuracy: 1.0000 - val_loss: 0.3526 - val_accuracy: 0.9608
# Epoch 88/100
# 7/7 [==============================] - 0s 37ms/step - loss: 1.2457e-07 - accuracy: 1.0000 - val_loss: 0.2970 - val_accuracy: 0.9608
# Epoch 89/100
# 7/7 [==============================] - 0s 40ms/step - loss: 1.5497e-07 - accuracy: 1.0000 - val_loss: 0.2474 - val_accuracy: 0.9804
# Epoch 90/100
# 7/7 [==============================] - 0s 37ms/step - loss: 6.7353e-08 - accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.9804
# Epoch 91/100
# 7/7 [==============================] - 0s 37ms/step - loss: 1.8239e-07 - accuracy: 1.0000 - val_loss: 0.1990 - val_accuracy: 0.9608
# Epoch 92/100
# 7/7 [==============================] - 0s 37ms/step - loss: 1.5020e-07 - accuracy: 1.0000 - val_loss: 0.2258 - val_accuracy: 0.9608
# Epoch 93/100
# 7/7 [==============================] - 0s 40ms/step - loss: 5.7816e-08 - accuracy: 1.0000 - val_loss: 0.2642 - val_accuracy: 0.9412
# Epoch 94/100
# 7/7 [==============================] - 0s 38ms/step - loss: 2.1159e-07 - accuracy: 1.0000 - val_loss: 0.3041 - val_accuracy: 0.9412
# Epoch 95/100
# 7/7 [==============================] - 0s 37ms/step - loss: 2.9802e-08 - accuracy: 1.0000 - val_loss: 0.3370 - val_accuracy: 0.9412
# Epoch 96/100
# 7/7 [==============================] - 0s 37ms/step - loss: 4.3511e-08 - accuracy: 1.0000 - val_loss: 0.3831 - val_accuracy: 0.9412
# Epoch 97/100
# 7/7 [==============================] - 0s 38ms/step - loss: 9.3578e-08 - accuracy: 1.0000 - val_loss: 0.4288 - val_accuracy: 0.9608
# Epoch 98/100
# 7/7 [==============================] - 0s 36ms/step - loss: 6.8545e-08 - accuracy: 1.0000 - val_loss: 0.4775 - val_accuracy: 0.9608
# Epoch 99/100
# 7/7 [==============================] - 0s 43ms/step - loss: 1.0550e-07 - accuracy: 1.0000 - val_loss: 0.5466 - val_accuracy: 0.9608
# Epoch 100/100
# 7/7 [==============================] - 0s 45ms/step - loss: 3.1590e-08 - accuracy: 1.0000 - val_loss: 0.6059 - val_accuracy: 0.9608
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:04<00:00, 16.95it/s]
# 100%|██████████| 70/70 [00:01<00:00, 52.06it/s]
# 100%|██████████| 111/111 [00:04<00:00, 25.55it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 26.94it/s]
# 100%|██████████| 20/20 [00:00<00:00, 68.87it/s]
# 100%|██████████| 26/26 [00:00<00:00, 90.67it/s]
# No data augmentation.
# Batch_size: 32
# Epochs: 100
# Data Augmentation: False
# Epoch 1/100
# 7/7 [==============================] - 1s 78ms/step - loss: 7.0425 - accuracy: 0.7200 - val_loss: 1.8573 - val_accuracy: 0.4510
# Epoch 2/100
# 7/7 [==============================] - 0s 37ms/step - loss: 3.2838 - accuracy: 0.9000 - val_loss: 0.2722 - val_accuracy: 0.9020
# Epoch 3/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.5890 - accuracy: 0.9550 - val_loss: 2.3315 - val_accuracy: 0.4902
# Epoch 4/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.2555 - accuracy: 0.9700 - val_loss: 7.1747 - val_accuracy: 0.4902
# Epoch 5/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0408 - accuracy: 0.9950 - val_loss: 15.0092 - val_accuracy: 0.4902
# Epoch 6/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0930 - accuracy: 0.9850 - val_loss: 15.3138 - val_accuracy: 0.4902
# Epoch 7/100
# 7/7 [==============================] - 0s 38ms/step - loss: 3.9337e-05 - accuracy: 1.0000 - val_loss: 14.8237 - val_accuracy: 0.4902
# Epoch 8/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.2078 - accuracy: 0.9800 - val_loss: 27.2863 - val_accuracy: 0.4902
# Epoch 9/100
# 7/7 [==============================] - 0s 37ms/step - loss: 7.2793e-06 - accuracy: 1.0000 - val_loss: 36.8594 - val_accuracy: 0.4902
# Epoch 10/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.3681 - accuracy: 0.9950 - val_loss: 35.9462 - val_accuracy: 0.4902
# Epoch 11/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 35.0622 - val_accuracy: 0.4902
# Epoch 12/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0336 - accuracy: 0.9950 - val_loss: 45.4490 - val_accuracy: 0.4902
# Epoch 13/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 55.1233 - val_accuracy: 0.4902
# Epoch 14/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 60.5657 - val_accuracy: 0.4902
# Epoch 15/100
# 7/7 [==============================] - 0s 38ms/step - loss: 2.8696e-05 - accuracy: 1.0000 - val_loss: 64.3723 - val_accuracy: 0.4902
# Epoch 16/100
# 7/7 [==============================] - 0s 37ms/step - loss: 4.5402e-05 - accuracy: 1.0000 - val_loss: 67.4082 - val_accuracy: 0.4902
# Epoch 17/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0625 - accuracy: 0.9950 - val_loss: 63.8694 - val_accuracy: 0.4902
# Epoch 18/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 59.8145 - val_accuracy: 0.4902
# Epoch 19/100
# 7/7 [==============================] - 0s 43ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 58.5218 - val_accuracy: 0.4902
# Epoch 20/100
# 7/7 [==============================] - 0s 37ms/step - loss: 1.1503e-06 - accuracy: 1.0000 - val_loss: 58.9674 - val_accuracy: 0.4902
# Epoch 21/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0108 - accuracy: 0.9950 - val_loss: 64.8621 - val_accuracy: 0.4902
# Epoch 22/100
# 7/7 [==============================] - 0s 39ms/step - loss: 1.0192e-07 - accuracy: 1.0000 - val_loss: 68.7310 - val_accuracy: 0.4902
# Epoch 23/100
# 7/7 [==============================] - 0s 38ms/step - loss: 2.3004e-04 - accuracy: 1.0000 - val_loss: 70.9427 - val_accuracy: 0.4902
# Epoch 24/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0216 - accuracy: 0.9950 - val_loss: 73.1966 - val_accuracy: 0.4902
# Epoch 25/100
# 7/7 [==============================] - 0s 38ms/step - loss: 3.2253e-05 - accuracy: 1.0000 - val_loss: 74.6287 - val_accuracy: 0.4902
# Epoch 26/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.1141 - accuracy: 0.9900 - val_loss: 75.7644 - val_accuracy: 0.4902
# Epoch 27/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0800 - accuracy: 0.9900 - val_loss: 73.9828 - val_accuracy: 0.4902
# Epoch 28/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 68.8660 - val_accuracy: 0.4902
# Epoch 29/100
# 7/7 [==============================] - 0s 36ms/step - loss: 5.6144e-07 - accuracy: 1.0000 - val_loss: 65.0532 - val_accuracy: 0.4902
# Epoch 30/100
# 7/7 [==============================] - 0s 37ms/step - loss: 1.6062e-04 - accuracy: 1.0000 - val_loss: 63.0285 - val_accuracy: 0.4902
# Epoch 31/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0060 - accuracy: 0.9950 - val_loss: 62.5271 - val_accuracy: 0.4902
# Epoch 32/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 62.4879 - val_accuracy: 0.4902
# Epoch 33/100
# 7/7 [==============================] - 0s 37ms/step - loss: 1.3332e-04 - accuracy: 1.0000 - val_loss: 62.5782 - val_accuracy: 0.4902
# Epoch 34/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0043 - accuracy: 0.9950 - val_loss: 62.6702 - val_accuracy: 0.4902
# Epoch 35/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0040 - accuracy: 0.9950 - val_loss: 65.5304 - val_accuracy: 0.4902
# Epoch 36/100
# 7/7 [==============================] - 0s 36ms/step - loss: 1.2517e-08 - accuracy: 1.0000 - val_loss: 68.9415 - val_accuracy: 0.4902
# Epoch 37/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0450 - accuracy: 0.9950 - val_loss: 63.7514 - val_accuracy: 0.4902
# Epoch 38/100
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0400 - accuracy: 0.9900 - val_loss: 67.9626 - val_accuracy: 0.4902
# Epoch 39/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 66.1137 - val_accuracy: 0.4902
# Epoch 40/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0065 - accuracy: 0.9950 - val_loss: 53.4409 - val_accuracy: 0.4902
# Epoch 41/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.2456 - accuracy: 0.9900 - val_loss: 52.6621 - val_accuracy: 0.4902
# Epoch 42/100
# 7/7 [==============================] - 0s 37ms/step - loss: 4.7684e-09 - accuracy: 1.0000 - val_loss: 79.0525 - val_accuracy: 0.4902
# Epoch 43/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0772 - accuracy: 0.9900 - val_loss: 76.1178 - val_accuracy: 0.4902
# Epoch 44/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 44.6529 - val_accuracy: 0.4902
# Epoch 45/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 26.3661 - val_accuracy: 0.4902
# Epoch 46/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 18.0831 - val_accuracy: 0.5098
# Epoch 47/100
# 7/7 [==============================] - 0s 38ms/step - loss: 2.0266e-08 - accuracy: 1.0000 - val_loss: 14.7035 - val_accuracy: 0.5490
# Epoch 48/100
# 7/7 [==============================] - 0s 39ms/step - loss: 4.0156e-05 - accuracy: 1.0000 - val_loss: 13.4554 - val_accuracy: 0.5686
# Epoch 49/100
# 7/7 [==============================] - 0s 39ms/step - loss: 4.8876e-08 - accuracy: 1.0000 - val_loss: 12.8653 - val_accuracy: 0.5686
# Epoch 50/100
# 7/7 [==============================] - 0s 39ms/step - loss: 4.2570e-06 - accuracy: 1.0000 - val_loss: 12.4240 - val_accuracy: 0.5686
# Epoch 51/100
# 7/7 [==============================] - 0s 39ms/step - loss: 2.1458e-08 - accuracy: 1.0000 - val_loss: 11.9584 - val_accuracy: 0.5686
# Epoch 52/100
# 7/7 [==============================] - 0s 39ms/step - loss: 3.4565e-05 - accuracy: 1.0000 - val_loss: 11.4549 - val_accuracy: 0.5686
# Epoch 53/100
# 7/7 [==============================] - 0s 38ms/step - loss: 3.0994e-07 - accuracy: 1.0000 - val_loss: 10.9246 - val_accuracy: 0.5882
# Epoch 54/100
# 7/7 [==============================] - 0s 38ms/step - loss: 8.0168e-05 - accuracy: 1.0000 - val_loss: 10.9221 - val_accuracy: 0.5882
# Epoch 55/100
# 7/7 [==============================] - 0s 37ms/step - loss: 7.1526e-09 - accuracy: 1.0000 - val_loss: 10.5676 - val_accuracy: 0.5882
# Epoch 56/100
# 7/7 [==============================] - 0s 39ms/step - loss: 8.3916e-07 - accuracy: 1.0000 - val_loss: 9.9175 - val_accuracy: 0.6275
# Epoch 57/100
# 7/7 [==============================] - 0s 38ms/step - loss: 2.3842e-08 - accuracy: 1.0000 - val_loss: 9.1665 - val_accuracy: 0.6275
# Epoch 58/100
# 7/7 [==============================] - 0s 37ms/step - loss: 1.7032e-06 - accuracy: 1.0000 - val_loss: 8.2975 - val_accuracy: 0.6275
# Epoch 59/100
# 7/7 [==============================] - 0s 37ms/step - loss: 1.5914e-07 - accuracy: 1.0000 - val_loss: 7.3483 - val_accuracy: 0.6275
# Epoch 60/100
# 7/7 [==============================] - 0s 36ms/step - loss: 8.9578e-07 - accuracy: 1.0000 - val_loss: 6.4581 - val_accuracy: 0.6471
# Epoch 61/100
# 7/7 [==============================] - 0s 37ms/step - loss: 6.3654e-07 - accuracy: 1.0000 - val_loss: 5.7335 - val_accuracy: 0.7059
# Epoch 62/100
# 7/7 [==============================] - 0s 37ms/step - loss: 5.4240e-08 - accuracy: 1.0000 - val_loss: 5.1117 - val_accuracy: 0.7647
# Epoch 63/100
# 7/7 [==============================] - 0s 43ms/step - loss: 3.5763e-09 - accuracy: 1.0000 - val_loss: 4.5616 - val_accuracy: 0.7843
# Epoch 64/100
# 7/7 [==============================] - 0s 36ms/step - loss: 2.4199e-07 - accuracy: 1.0000 - val_loss: 4.1119 - val_accuracy: 0.8039
# Epoch 65/100
# 7/7 [==============================] - 0s 37ms/step - loss: 6.5565e-09 - accuracy: 1.0000 - val_loss: 3.7301 - val_accuracy: 0.8235
# Epoch 66/100
# 7/7 [==============================] - 0s 37ms/step - loss: 5.9605e-09 - accuracy: 1.0000 - val_loss: 3.3554 - val_accuracy: 0.8431
# Epoch 67/100
# 7/7 [==============================] - 0s 37ms/step - loss: 1.0785e-05 - accuracy: 1.0000 - val_loss: 3.0495 - val_accuracy: 0.8431
# Epoch 68/100
# 7/7 [==============================] - 0s 36ms/step - loss: 2.9802e-09 - accuracy: 1.0000 - val_loss: 2.7625 - val_accuracy: 0.8431
# Epoch 69/100
# 7/7 [==============================] - 0s 43ms/step - loss: 3.8743e-08 - accuracy: 1.0000 - val_loss: 2.5332 - val_accuracy: 0.8824
# Epoch 70/100
# 7/7 [==============================] - 0s 37ms/step - loss: 3.5772e-04 - accuracy: 1.0000 - val_loss: 2.6996 - val_accuracy: 0.8431
# Epoch 71/100
# 7/7 [==============================] - 0s 37ms/step - loss: 6.9141e-08 - accuracy: 1.0000 - val_loss: 3.1633 - val_accuracy: 0.8431
# Epoch 72/100
# 7/7 [==============================] - 0s 37ms/step - loss: 5.9605e-10 - accuracy: 1.0000 - val_loss: 3.1807 - val_accuracy: 0.8431
# Epoch 73/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9765 - val_accuracy: 0.8431
# Epoch 74/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.6705 - val_accuracy: 0.8431
# Epoch 75/100
# 7/7 [==============================] - 0s 45ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.3268 - val_accuracy: 0.8431
# ...
# Epoch 96/100
# 2/2 [==============================] - 0s 121ms/step - loss: 3.5763e-09 - accuracy: 1.0000 - val_loss: 74.0133 - val_accuracy: 0.4902
# Epoch 97/100
# 2/2 [==============================] - 0s 136ms/step - loss: 1.7881e-09 - accuracy: 1.0000 - val_loss: 73.9642 - val_accuracy: 0.4902
# Epoch 98/100
# 2/2 [==============================] - 0s 135ms/step - loss: 2.3842e-09 - accuracy: 1.0000 - val_loss: 73.8898 - val_accuracy: 0.4902
# Epoch 99/100
# 2/2 [==============================] - 0s 117ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 73.8195 - val_accuracy: 0.4902
# Epoch 100/100
# 2/2 [==============================] - 0s 131ms/step - loss: 1.5139e-07 - accuracy: 1.0000 - val_loss: 73.7161 - val_accuracy: 0.4902
# Loading ../input/coviddata/train
# 100%|██████████| 70/70 [00:04<00:00, 16.11it/s]
# 100%|██████████| 70/70 [00:01<00:00, 53.58it/s]
# 100%|██████████| 111/111 [00:04<00:00, 27.45it/s]
# Loading ../input/coviddata/test
# 100%|██████████| 20/20 [00:00<00:00, 29.08it/s]
# 100%|██████████| 20/20 [00:00<00:00, 72.47it/s]
# 100%|██████████| 26/26 [00:00<00:00, 94.94it/s]
# No data augmentation.
# Batch_size: 120
# Epochs: 100
# Data Augmentation: False
# Epoch 1/100
# 2/2 [==============================] - 1s 319ms/step - loss: 5.0215 - accuracy: 0.4100 - val_loss: 12.2575 - val_accuracy: 0.1961
# Epoch 2/100
# 2/2 [==============================] - 0s 137ms/step - loss: 4.7172 - accuracy: 0.8900 - val_loss: 9.3991 - val_accuracy: 0.1961
# Epoch 3/100
# 2/2 [==============================] - 0s 143ms/step - loss: 0.6166 - accuracy: 0.9500 - val_loss: 9.9903 - val_accuracy: 0.1961
# Epoch 4/100
# 2/2 [==============================] - 0s 121ms/step - loss: 1.6346 - accuracy: 0.9400 - val_loss: 8.7370 - val_accuracy: 0.1961
# Epoch 5/100
# 2/2 [==============================] - 0s 140ms/step - loss: 0.4658 - accuracy: 0.9700 - val_loss: 3.6545 - val_accuracy: 0.3922
# Epoch 6/100
# 2/2 [==============================] - 0s 121ms/step - loss: 2.1757e-06 - accuracy: 1.0000 - val_loss: 1.4278 - val_accuracy: 0.6275
# Epoch 7/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0640 - accuracy: 0.9900 - val_loss: 1.1016 - val_accuracy: 0.6863
# Epoch 8/100
# 2/2 [==============================] - 0s 138ms/step - loss: 3.3198e-06 - accuracy: 1.0000 - val_loss: 1.6460 - val_accuracy: 0.6863
# Epoch 9/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0185 - accuracy: 0.9950 - val_loss: 2.5346 - val_accuracy: 0.5490
# Epoch 10/100
# 2/2 [==============================] - 0s 122ms/step - loss: 6.7949e-08 - accuracy: 1.0000 - val_loss: 3.5999 - val_accuracy: 0.5490
# Epoch 11/100
# 2/2 [==============================] - 0s 134ms/step - loss: 4.4107e-08 - accuracy: 1.0000 - val_loss: 5.0500 - val_accuracy: 0.4902
# Epoch 12/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.8905 - val_accuracy: 0.4902
# Epoch 13/100
# 2/2 [==============================] - 0s 132ms/step - loss: 0.0040 - accuracy: 0.9950 - val_loss: 9.6087 - val_accuracy: 0.4902
# Epoch 14/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 13.1107 - val_accuracy: 0.4902
# Epoch 15/100
# 2/2 [==============================] - 0s 134ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 16.7086 - val_accuracy: 0.4902
# Epoch 16/100
# 2/2 [==============================] - 0s 132ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 20.2957 - val_accuracy: 0.4902
# Epoch 17/100
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 23.9209 - val_accuracy: 0.4902
# Epoch 18/100
# 2/2 [==============================] - 0s 133ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 27.5677 - val_accuracy: 0.4902
# Epoch 19/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 31.2050 - val_accuracy: 0.4902
# Epoch 20/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 34.8261 - val_accuracy: 0.4902
# Epoch 21/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 38.4295 - val_accuracy: 0.4902
# Epoch 22/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 41.9501 - val_accuracy: 0.4902
# Epoch 23/100
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 45.4223 - val_accuracy: 0.4902
# Epoch 24/100
# 2/2 [==============================] - 0s 133ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 48.8265 - val_accuracy: 0.4902
# Epoch 25/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 52.1570 - val_accuracy: 0.4902
# Epoch 26/100
# 2/2 [==============================] - 0s 123ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 55.4047 - val_accuracy: 0.4902
# Epoch 27/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 58.5605 - val_accuracy: 0.4902
# Epoch 28/100
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 61.6212 - val_accuracy: 0.4902
# Epoch 29/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 64.5873 - val_accuracy: 0.4902
# Epoch 30/100
# 2/2 [==============================] - 0s 123ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.4736 - val_accuracy: 0.4902
# Epoch 31/100
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 70.2682 - val_accuracy: 0.4902
# Epoch 32/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 73.0125 - val_accuracy: 0.4902
# Epoch 33/100
# 2/2 [==============================] - 0s 123ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 75.6539 - val_accuracy: 0.4902
# Epoch 34/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 78.2041 - val_accuracy: 0.4902
# Epoch 35/100
# 2/2 [==============================] - 0s 127ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 80.6887 - val_accuracy: 0.4902
# Epoch 36/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 83.0898 - val_accuracy: 0.4902
# Epoch 37/100
# 2/2 [==============================] - 0s 137ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 85.4402 - val_accuracy: 0.4902
# Epoch 38/100
# 2/2 [==============================] - 0s 138ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 87.6881 - val_accuracy: 0.4902
# Epoch 39/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 89.8995 - val_accuracy: 0.4902
# Epoch 40/100
# 2/2 [==============================] - 0s 137ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 92.0412 - val_accuracy: 0.4902
# Epoch 41/100
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 94.1129 - val_accuracy: 0.4902
# Epoch 42/100
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 96.1255 - val_accuracy: 0.4902
# Epoch 43/100
# 2/2 [==============================] - 0s 134ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 98.0666 - val_accuracy: 0.4902
# Epoch 44/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 99.9376 - val_accuracy: 0.4902
# Epoch 45/100
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 101.7775 - val_accuracy: 0.4902
# Epoch 46/100
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 103.5255 - val_accuracy: 0.4902
# Epoch 47/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 105.2636 - val_accuracy: 0.4902
# Epoch 48/100
# 2/2 [==============================] - 0s 138ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 106.9238 - val_accuracy: 0.4902
# Epoch 49/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 108.5406 - val_accuracy: 0.4902
# Epoch 50/100
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 110.0880 - val_accuracy: 0.4902
# Epoch 51/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 111.5975 - val_accuracy: 0.4902
# Epoch 52/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 113.0471 - val_accuracy: 0.4902
# Epoch 53/100
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 114.4604 - val_accuracy: 0.4902
# Epoch 54/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 115.8172 - val_accuracy: 0.4902
# Epoch 55/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 117.1237 - val_accuracy: 0.4902
# Epoch 56/100
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 118.3610 - val_accuracy: 0.4902
# Epoch 57/100
# 2/2 [==============================] - 0s 138ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 119.5715 - val_accuracy: 0.4902
# Epoch 58/100
# 2/2 [==============================] - 0s 134ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 120.7510 - val_accuracy: 0.4902
# Epoch 59/100
# 2/2 [==============================] - 0s 134ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 121.8631 - val_accuracy: 0.4902
# Epoch 60/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 122.9283 - val_accuracy: 0.4902
# Epoch 61/100
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 123.9679 - val_accuracy: 0.4902
# Epoch 62/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 124.9799 - val_accuracy: 0.4902
# Epoch 63/100
# 2/2 [==============================] - 0s 138ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 125.9510 - val_accuracy: 0.4902
# Epoch 64/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 126.8856 - val_accuracy: 0.4902
# Epoch 65/100
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 127.7812 - val_accuracy: 0.4902
# Epoch 66/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 128.6461 - val_accuracy: 0.4902
# Epoch 67/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 129.4402 - val_accuracy: 0.4902
# Epoch 68/100
# 2/2 [==============================] - 0s 124ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 130.2244 - val_accuracy: 0.4902
# Epoch 69/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 130.9673 - val_accuracy: 0.4902
# Epoch 70/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 131.6773 - val_accuracy: 0.4902
# Epoch 71/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 132.3508 - val_accuracy: 0.4902
# Epoch 72/100
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 132.9659 - val_accuracy: 0.4902
# Epoch 73/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 133.5677 - val_accuracy: 0.4902
# Epoch 74/100
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 134.1407 - val_accuracy: 0.4902
# Epoch 75/100
# 2/2 [==============================] - 0s 137ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 134.6720 - val_accuracy: 0.4902
# Epoch 76/100
# 2/2 [==============================] - 0s 124ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 135.1723 - val_accuracy: 0.4902
# Epoch 77/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 135.6577 - val_accuracy: 0.4902
# Epoch 78/100
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 136.1069 - val_accuracy: 0.4902
# Epoch 79/100
# 2/2 [==============================] - 0s 132ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 136.5226 - val_accuracy: 0.4902
# Epoch 80/100
# 2/2 [==============================] - 0s 137ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 136.9010 - val_accuracy: 0.4902
# Epoch 81/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 137.2408 - val_accuracy: 0.4902
# Epoch 82/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 137.5750 - val_accuracy: 0.4902
# Epoch 83/100
# 2/2 [==============================] - 0s 149ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 137.8587 - val_accuracy: 0.4902
# Epoch 84/100
# 2/2 [==============================] - 0s 150ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 138.1357 - val_accuracy: 0.4902
# Epoch 85/100
# 2/2 [==============================] - 0s 172ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 138.4009 - val_accuracy: 0.4902
# Epoch 86/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 138.6309 - val_accuracy: 0.4902
# Epoch 87/100
# 2/2 [==============================] - 0s 126ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 138.8199 - val_accuracy: 0.4902
# Epoch 88/100
# 2/2 [==============================] - 0s 181ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 138.9692 - val_accuracy: 0.4902
# Epoch 89/100
# 2/2 [==============================] - 0s 153ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 139.1019 - val_accuracy: 0.4902
# Epoch 90/100
# 2/2 [==============================] - 0s 150ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 139.2219 - val_accuracy: 0.4902
# Epoch 91/100
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 139.3120 - val_accuracy: 0.4902
# Epoch 92/100
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 139.3731 - val_accuracy: 0.4902
# Epoch 93/100
# 2/2 [==============================] - 0s 134ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 139.4236 - val_accuracy: 0.4902
# Epoch 94/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 139.4257 - val_accuracy: 0.4902
# Epoch 95/100
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 139.4282 - val_accuracy: 0.4902
# Epoch 96/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 139.3914 - val_accuracy: 0.4902
# Epoch 97/100
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 139.3522 - val_accuracy: 0.4902
# Epoch 98/100
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 139.3062 - val_accuracy: 0.4902
# Epoch 99/100
# 2/2 [==============================] - 0s 137ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 139.1962 - val_accuracy: 0.4902
# Epoch 100/100
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 139.0675 - val_accuracy: 0.4902

# %% [markdown]
# #### Model 3- CNN

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %%
#Model 3
def build_model_3():
    model = Sequential([
        Conv2D(filters=128, kernel_size=(5, 5), padding='valid', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Conv2D(filters=64, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Conv2D(filters=32, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Flatten(),

        Dense(units=256, activation='relu'),
        Dropout(0.5),
        Dense(units=3, activation='softmax')
    ])
    return model

# %%
for batch in batch_sizes:
    for epoch in epoch_num:
        IMG_WIDTH = 244
        IMG_HEIGHT = 244
        BATCH_SIZE = batch
        train_path="../input/coviddata/train"
        test_path="../input/coviddata/test"
        train_datagen = ImageDataGenerator(rescale=1.0/255,
                                          zoom_range=0.2,
                                          width_shift_range=0.2,
                                          height_shift_range=0.2,
                                          fill_mode='nearest')
        train_generator = train_datagen.flow_from_directory(train_path,
                                                           target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                           batch_size=BATCH_SIZE,
                                                           class_mode='categorical',
                                                           shuffle=True)
        validation_datagen = ImageDataGenerator(rescale=1.0/255,
                                                shear_range = 0.3,
                                                horizontal_flip=True,
                                                zoom_range = 0.3)
        validation_generator = validation_datagen.flow_from_directory(test_path,
                                                                     target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                                     batch_size=BATCH_SIZE,
                                                                     class_mode='categorical',
                                                                     shuffle=True)
        labels = {value: key for key, value in train_generator.class_indices.items()}

        print("Label Mappings for classes present in the training and validation datasets\n")
        for key, value in labels.items():
            print(f"{key} : {value}")
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
        optimizer = adam_v2.Adam(learning_rate=0.001)
        model=build_model_3()
        print("Batch Sizes:",batch)
        print("Epochs:",epoch)
        model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

        history = model.fit(train_generator, epochs=epoch, validation_data=validation_generator,
                               verbose=2,
                               callbacks=[reduce_lr])
        plot_accuracy_loss(history)

# %% [markdown]
# ### Resnet

# %%
batch_size = 32  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 3

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

n = 3

version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
print(model_type)

# %%
input_shape = x_train.shape[1:]
print(input_shape)

# %%
# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# %%
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=3):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=3):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=adam_v2.Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'IntelImageClass_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
# Compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied).
datagen.fit(x_train)

# %%
# Fit the model on the batches generated by datagen.flow().
model.summary()
history=model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)

# %%
scores = model.evaluate(x_test, y_test, verbose=1)

print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
plot_accuracy_loss(history)

# %%
def display_random_image(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Predicte Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
predictions = model.predict(x_test)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

display_random_image(class_names, x_test, pred_labels)

# %%
version=2
data_augmentation=True

# %%
# Fit the model on the batches generated by datagen.flow().
model.summary()
checkpoint_path = "training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
history=model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
plot_accuracy_loss(history)

# %%
predictions = model.predict(x_test)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

display_random_image(class_names, x_test, pred_labels)

# %%
version=1
data_augmentation=False

# %%
# Fit the model on the batches generated by datagen.flow().
history=model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
plot_accuracy_loss(history)

# %%
predictions = model.predict(x_test)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

display_random_image(class_names, x_test, pred_labels)
